# %% [markdown]
# # What's different?

# %% [markdown]
# ![image.png](attachment:b20b09b1-6579-4f00-972b-ae07d2e6736f.png)
#
# ![image.png](attachment:69e1527d-0ae0-47a4-9ac0-35c4f577f848.png)

# %% [markdown]
# # Results Summary

# %% [markdown]
# ## Full dataset
# ![image.png](attachment:04d64a08-1564-462c-8615-e7dd248ee3f2.png)
#
# ![Screenshot 2025-09-18 115246.png](attachment:48b441da-a0d6-4622-a4fa-75fd0fef4b89.png)
# ## 4k dataset
# ![image.png](attachment:2e0d448e-d7b8-4ab0-b8fe-1fdb9eba1f5e.png)
#
# ![image.png](attachment:a5ef4bdb-eb3f-4726-92c2-a2e6613b7543.png)
#
# ## 6k Dataset
# ![image.png](attachment:23e0b0e1-9f7b-4f71-a979-ff69daa34174.png)
# ![image.png](attachment:13738bbb-8076-4668-b229-97fc27cfa48d.png)
# ## 10k dataset
# ![image.png](attachment:b5cd1ffa-a885-4ae1-befc-9f0e18986593.png)
# ![image.png](attachment:f1e82594-92ca-4bee-8998-d57408554af9.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier
# --- 1) Load data ---
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)
print(df)

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Phase Diagram")

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))
# Out:
#           t  Ubar  Mubar       Density          Phi2        Energy  Iters  \
# 0       1.0   0.0   -5.0  1.048576e-14  1.048576e-14  2.097152e-13      8
# 1       1.0   0.0   -4.9  1.508449e-14  1.508449e-14  2.882646e-13      8
# 2       1.0   0.0   -4.8  2.186340e-14  2.186340e-14  3.987884e-13      8
# 3       1.0   0.0   -4.7  3.193733e-14  3.193733e-14  5.553901e-13      8
# 4       1.0   0.0   -4.6  4.703477e-14  4.703477e-14  7.788958e-13      8
# ...     ...   ...    ...           ...           ...           ...    ...
# 163396  1.0  25.0   59.6  3.000000e+00  8.530376e-13 -1.038000e+02     21
# 163397  1.0  25.0   59.7  3.000000e+00  7.586920e-13 -1.041000e+02     21
# 163398  1.0  25.0   59.8  3.000000e+00  6.791729e-13 -1.044000e+02     21
# 163399  1.0  25.0   59.9  3.000000e+00  6.119027e-13 -1.047000e+02     21
# 163400  1.0  25.0   60.0  3.000000e+00  5.548081e-13 -1.050000e+02     21
#
#         Phase
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 163396      0
# 163397      0
# 163398      0
# 163399      0
# 163400      0
#
# [163401 rows x 8 columns]
# Epoch 1/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.6609 - phase_accuracy: 0.8454 - phase_loss: 0.3533 - phi2_loss: 0.2314 - phi2_mae: 0.3467 - rho_loss: 0.3829 - rho_mae: 0.3638 - val_loss: 0.4214 - val_phase_accuracy: 0.7980 - val_phase_loss: 0.3405 - val_phi2_loss: 0.1083 - val_phi2_mae: 0.2613 - val_rho_loss: 0.0561 - val_rho_mae: 0.1762 - learning_rate: 0.0010
# Epoch 2/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1889 - phase_accuracy: 0.9484 - phase_loss: 0.1497 - phi2_loss: 0.0633 - phi2_mae: 0.1873 - rho_loss: 0.0149 - rho_mae: 0.0908 - val_loss: 0.2508 - val_phase_accuracy: 0.8996 - val_phase_loss: 0.2018 - val_phi2_loss: 0.0850 - val_phi2_mae: 0.2193 - val_rho_loss: 0.0152 - val_rho_mae: 0.0947 - learning_rate: 0.0010
# Epoch 3/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1200 - phase_accuracy: 0.9712 - phase_loss: 0.0976 - phi2_loss: 0.0358 - phi2_mae: 0.1372 - rho_loss: 0.0091 - rho_mae: 0.0726 - val_loss: 0.2497 - val_phase_accuracy: 0.8967 - val_phase_loss: 0.1862 - val_phi2_loss: 0.1174 - val_phi2_mae: 0.2544 - val_rho_loss: 0.0126 - val_rho_mae: 0.0898 - learning_rate: 0.0010
# Epoch 4/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0903 - phase_accuracy: 0.9804 - phase_loss: 0.0727 - phi2_loss: 0.0248 - phi2_mae: 0.1149 - rho_loss: 0.0106 - rho_mae: 0.0757 - val_loss: 0.1336 - val_phase_accuracy: 0.9525 - val_phase_loss: 0.1068 - val_phi2_loss: 0.0438 - val_phi2_mae: 0.1580 - val_rho_loss: 0.0113 - val_rho_mae: 0.0867 - learning_rate: 0.0010
# Epoch 5/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0727 - phase_accuracy: 0.9848 - phase_loss: 0.0590 - phi2_loss: 0.0202 - phi2_mae: 0.1042 - rho_loss: 0.0073 - rho_mae: 0.0641 - val_loss: 0.1519 - val_phase_accuracy: 0.9502 - val_phase_loss: 0.1023 - val_phi2_loss: 0.0924 - val_phi2_mae: 0.2128 - val_rho_loss: 0.0087 - val_rho_mae: 0.0761 - learning_rate: 0.0010
# Epoch 6/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0628 - phase_accuracy: 0.9865 - phase_loss: 0.0511 - phi2_loss: 0.0173 - phi2_mae: 0.0967 - rho_loss: 0.0061 - rho_mae: 0.0598 - val_loss: 0.0984 - val_phase_accuracy: 0.9712 - val_phase_loss: 0.0732 - val_phi2_loss: 0.0394 - val_phi2_mae: 0.1387 - val_rho_loss: 0.0120 - val_rho_mae: 0.0927 - learning_rate: 0.0010
# Epoch 7/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0576 - phase_accuracy: 0.9875 - phase_loss: 0.0463 - phi2_loss: 0.0147 - phi2_mae: 0.0888 - rho_loss: 0.0080 - rho_mae: 0.0651 - val_loss: 0.0888 - val_phase_accuracy: 0.9721 - val_phase_loss: 0.0638 - val_phi2_loss: 0.0387 - val_phi2_mae: 0.1371 - val_rho_loss: 0.0120 - val_rho_mae: 0.0907 - learning_rate: 0.0010
# Epoch 8/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0516 - phase_accuracy: 0.9878 - phase_loss: 0.0421 - phi2_loss: 0.0141 - phi2_mae: 0.0877 - rho_loss: 0.0049 - rho_mae: 0.0534 - val_loss: 0.0785 - val_phase_accuracy: 0.9807 - val_phase_loss: 0.0548 - val_phi2_loss: 0.0289 - val_phi2_mae: 0.1106 - val_rho_loss: 0.0189 - val_rho_mae: 0.1206 - learning_rate: 0.0010
# Epoch 9/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0508 - phase_accuracy: 0.9875 - phase_loss: 0.0405 - phi2_loss: 0.0146 - phi2_mae: 0.0898 - rho_loss: 0.0061 - rho_mae: 0.0606 - val_loss: 0.1075 - val_phase_accuracy: 0.9800 - val_phase_loss: 0.0566 - val_phi2_loss: 0.0966 - val_phi2_mae: 0.2200 - val_rho_loss: 0.0061 - val_rho_mae: 0.0622 - learning_rate: 0.0010
# Epoch 10/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0466 - phase_accuracy: 0.9888 - phase_loss: 0.0372 - phi2_loss: 0.0140 - phi2_mae: 0.0874 - rho_loss: 0.0048 - rho_mae: 0.0522 - val_loss: 0.0835 - val_phase_accuracy: 0.9732 - val_phase_loss: 0.0578 - val_phi2_loss: 0.0372 - val_phi2_mae: 0.1336 - val_rho_loss: 0.0149 - val_rho_mae: 0.1029 - learning_rate: 0.0010
# Epoch 11/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - phase_accuracy: 0.9896 - phase_loss: 0.0348 - phi2_loss: 0.0130 - phi2_mae: 0.0838 - rho_loss: 0.0048 - rho_mae: 0.0526 - val_loss: 0.0955 - val_phase_accuracy: 0.9788 - val_phase_loss: 0.0472 - val_phi2_loss: 0.0664 - val_phi2_mae: 0.1662 - val_rho_loss: 0.0311 - val_rho_mae: 0.1626 - learning_rate: 0.0010
# Epoch 12/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0430 - phase_accuracy: 0.9895 - phase_loss: 0.0336 - phi2_loss: 0.0144 - phi2_mae: 0.0874 - rho_loss: 0.0044 - rho_mae: 0.0502 - val_loss: 0.0644 - val_phase_accuracy: 0.9833 - val_phase_loss: 0.0442 - val_phi2_loss: 0.0320 - val_phi2_mae: 0.1162 - val_rho_loss: 0.0088 - val_rho_mae: 0.0753 - learning_rate: 0.0010
# Epoch 13/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - phase_accuracy: 0.9889 - phase_loss: 0.0332 - phi2_loss: 0.0138 - phi2_mae: 0.0863 - rho_loss: 0.0049 - rho_mae: 0.0530 - val_loss: 0.0626 - val_phase_accuracy: 0.9867 - val_phase_loss: 0.0416 - val_phi2_loss: 0.0289 - val_phi2_mae: 0.1218 - val_rho_loss: 0.0136 - val_rho_mae: 0.0942 - learning_rate: 0.0010
# Epoch 14/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - phase_accuracy: 0.9888 - phase_loss: 0.0324 - phi2_loss: 0.0127 - phi2_mae: 0.0824 - rho_loss: 0.0045 - rho_mae: 0.0506 - val_loss: 0.0771 - val_phase_accuracy: 0.9758 - val_phase_loss: 0.0508 - val_phi2_loss: 0.0408 - val_phi2_mae: 0.1337 - val_rho_loss: 0.0126 - val_rho_mae: 0.0873 - learning_rate: 0.0010
# Epoch 15/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0375 - phase_accuracy: 0.9903 - phase_loss: 0.0298 - phi2_loss: 0.0101 - phi2_mae: 0.0738 - rho_loss: 0.0053 - rho_mae: 0.0544 - val_loss: 0.1179 - val_phase_accuracy: 0.9568 - val_phase_loss: 0.0961 - val_phi2_loss: 0.0219 - val_phi2_mae: 0.0963 - val_rho_loss: 0.0223 - val_rho_mae: 0.1214 - learning_rate: 0.0010
# Epoch 16/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0369 - phase_accuracy: 0.9901 - phase_loss: 0.0295 - phi2_loss: 0.0106 - phi2_mae: 0.0759 - rho_loss: 0.0041 - rho_mae: 0.0483 - val_loss: 0.0946 - val_phase_accuracy: 0.9666 - val_phase_loss: 0.0727 - val_phi2_loss: 0.0370 - val_phi2_mae: 0.1247 - val_rho_loss: 0.0080 - val_rho_mae: 0.0697 - learning_rate: 0.0010
# Epoch 17/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0387 - phase_accuracy: 0.9892 - phase_loss: 0.0297 - phi2_loss: 0.0123 - phi2_mae: 0.0825 - rho_loss: 0.0056 - rho_mae: 0.0562 - val_loss: 0.0671 - val_phase_accuracy: 0.9818 - val_phase_loss: 0.0400 - val_phi2_loss: 0.0450 - val_phi2_mae: 0.1468 - val_rho_loss: 0.0100 - val_rho_mae: 0.0809 - learning_rate: 0.0010
# Epoch 18/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0366 - phase_accuracy: 0.9896 - phase_loss: 0.0288 - phi2_loss: 0.0115 - phi2_mae: 0.0788 - rho_loss: 0.0041 - rho_mae: 0.0486 - val_loss: 0.0973 - val_phase_accuracy: 0.9679 - val_phase_loss: 0.0725 - val_phi2_loss: 0.0399 - val_phi2_mae: 0.1621 - val_rho_loss: 0.0104 - val_rho_mae: 0.0838 - learning_rate: 0.0010
# Epoch 19/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0345 - phase_accuracy: 0.9909 - phase_loss: 0.0267 - phi2_loss: 0.0115 - phi2_mae: 0.0784 - rho_loss: 0.0042 - rho_mae: 0.0493 - val_loss: 0.0670 - val_phase_accuracy: 0.9804 - val_phase_loss: 0.0411 - val_phi2_loss: 0.0360 - val_phi2_mae: 0.1556 - val_rho_loss: 0.0160 - val_rho_mae: 0.1082 - learning_rate: 0.0010
# Epoch 20/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0351 - phase_accuracy: 0.9901 - phase_loss: 0.0275 - phi2_loss: 0.0111 - phi2_mae: 0.0769 - rho_loss: 0.0040 - rho_mae: 0.0485 - val_loss: 0.0923 - val_phase_accuracy: 0.9726 - val_phase_loss: 0.0601 - val_phi2_loss: 0.0519 - val_phi2_mae: 0.1537 - val_rho_loss: 0.0135 - val_rho_mae: 0.0971 - learning_rate: 0.0010
# Epoch 21/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0326 - phase_accuracy: 0.9907 - phase_loss: 0.0259 - phi2_loss: 0.0097 - phi2_mae: 0.0724 - rho_loss: 0.0037 - rho_mae: 0.0466 - val_loss: 0.0486 - val_phase_accuracy: 0.9867 - val_phase_loss: 0.0313 - val_phi2_loss: 0.0263 - val_phi2_mae: 0.1253 - val_rho_loss: 0.0086 - val_rho_mae: 0.0760 - learning_rate: 0.0010
# Epoch 22/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0349 - phase_accuracy: 0.9897 - phase_loss: 0.0276 - phi2_loss: 0.0103 - phi2_mae: 0.0754 - rho_loss: 0.0043 - rho_mae: 0.0497 - val_loss: 0.1289 - val_phase_accuracy: 0.9656 - val_phase_loss: 0.0906 - val_phi2_loss: 0.0689 - val_phi2_mae: 0.1683 - val_rho_loss: 0.0094 - val_rho_mae: 0.0815 - learning_rate: 0.0010
# Epoch 23/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0326 - phase_accuracy: 0.9907 - phase_loss: 0.0255 - phi2_loss: 0.0097 - phi2_mae: 0.0730 - rho_loss: 0.0045 - rho_mae: 0.0516 - val_loss: 0.0868 - val_phase_accuracy: 0.9684 - val_phase_loss: 0.0683 - val_phi2_loss: 0.0300 - val_phi2_mae: 0.1270 - val_rho_loss: 0.0081 - val_rho_mae: 0.0725 - learning_rate: 0.0010
# Epoch 24/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0315 - phase_accuracy: 0.9911 - phase_loss: 0.0251 - phi2_loss: 0.0092 - phi2_mae: 0.0715 - rho_loss: 0.0037 - rho_mae: 0.0461 - val_loss: 0.0652 - val_phase_accuracy: 0.9790 - val_phase_loss: 0.0470 - val_phi2_loss: 0.0312 - val_phi2_mae: 0.1097 - val_rho_loss: 0.0060 - val_rho_mae: 0.0617 - learning_rate: 0.0010
# Epoch 25/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0322 - phase_accuracy: 0.9903 - phase_loss: 0.0253 - phi2_loss: 0.0098 - phi2_mae: 0.0725 - rho_loss: 0.0040 - rho_mae: 0.0482 - val_loss: 0.0513 - val_phase_accuracy: 0.9817 - val_phase_loss: 0.0382 - val_phi2_loss: 0.0190 - val_phi2_mae: 0.0989 - val_rho_loss: 0.0075 - val_rho_mae: 0.0640 - learning_rate: 0.0010
# Epoch 26/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0302 - phase_accuracy: 0.9911 - phase_loss: 0.0243 - phi2_loss: 0.0086 - phi2_mae: 0.0677 - rho_loss: 0.0033 - rho_mae: 0.0442 - val_loss: 0.0530 - val_phase_accuracy: 0.9883 - val_phase_loss: 0.0305 - val_phi2_loss: 0.0324 - val_phi2_mae: 0.1109 - val_rho_loss: 0.0130 - val_rho_mae: 0.0975 - learning_rate: 0.0010
# Epoch 27/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0296 - phase_accuracy: 0.9912 - phase_loss: 0.0237 - phi2_loss: 0.0089 - phi2_mae: 0.0696 - rho_loss: 0.0031 - rho_mae: 0.0422 - val_loss: 0.0697 - val_phase_accuracy: 0.9750 - val_phase_loss: 0.0513 - val_phi2_loss: 0.0316 - val_phi2_mae: 0.1142 - val_rho_loss: 0.0059 - val_rho_mae: 0.0574 - learning_rate: 0.0010
# Epoch 28/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0296 - phase_accuracy: 0.9914 - phase_loss: 0.0236 - phi2_loss: 0.0083 - phi2_mae: 0.0669 - rho_loss: 0.0037 - rho_mae: 0.0460 - val_loss: 0.0787 - val_phase_accuracy: 0.9788 - val_phase_loss: 0.0503 - val_phi2_loss: 0.0433 - val_phi2_mae: 0.1274 - val_rho_loss: 0.0145 - val_rho_mae: 0.1020 - learning_rate: 0.0010
# Epoch 29/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0300 - phase_accuracy: 0.9914 - phase_loss: 0.0236 - phi2_loss: 0.0095 - phi2_mae: 0.0707 - rho_loss: 0.0033 - rho_mae: 0.0430 - val_loss: 0.0747 - val_phase_accuracy: 0.9732 - val_phase_loss: 0.0590 - val_phi2_loss: 0.0263 - val_phi2_mae: 0.1256 - val_rho_loss: 0.0060 - val_rho_mae: 0.0579 - learning_rate: 0.0010
# Epoch 30/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0215 - phase_accuracy: 0.9948 - phase_loss: 0.0185 - phi2_loss: 0.0048 - phi2_mae: 0.0495 - rho_loss: 0.0012 - rho_mae: 0.0271 - val_loss: 0.0634 - val_phase_accuracy: 0.9786 - val_phase_loss: 0.0498 - val_phi2_loss: 0.0233 - val_phi2_mae: 0.1175 - val_rho_loss: 0.0046 - val_rho_mae: 0.0561 - learning_rate: 5.0000e-04
# Epoch 31/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0224 - phase_accuracy: 0.9939 - phase_loss: 0.0194 - phi2_loss: 0.0048 - phi2_mae: 0.0497 - rho_loss: 0.0014 - rho_mae: 0.0285 - val_loss: 0.0321 - val_phase_accuracy: 0.9928 - val_phase_loss: 0.0223 - val_phi2_loss: 0.0156 - val_phi2_mae: 0.0744 - val_rho_loss: 0.0043 - val_rho_mae: 0.0517 - learning_rate: 5.0000e-04
# Epoch 32/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0228 - phase_accuracy: 0.9939 - phase_loss: 0.0194 - phi2_loss: 0.0054 - phi2_mae: 0.0536 - rho_loss: 0.0014 - rho_mae: 0.0296 - val_loss: 0.0469 - val_phase_accuracy: 0.9840 - val_phase_loss: 0.0352 - val_phi2_loss: 0.0199 - val_phi2_mae: 0.0973 - val_rho_loss: 0.0040 - val_rho_mae: 0.0524 - learning_rate: 5.0000e-04
# Epoch 33/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0222 - phase_accuracy: 0.9940 - phase_loss: 0.0191 - phi2_loss: 0.0051 - phi2_mae: 0.0512 - rho_loss: 0.0013 - rho_mae: 0.0276 - val_loss: 0.0445 - val_phase_accuracy: 0.9831 - val_phase_loss: 0.0328 - val_phi2_loss: 0.0195 - val_phi2_mae: 0.0823 - val_rho_loss: 0.0043 - val_rho_mae: 0.0493 - learning_rate: 5.0000e-04
# Epoch 34/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0226 - phase_accuracy: 0.9936 - phase_loss: 0.0193 - phi2_loss: 0.0052 - phi2_mae: 0.0524 - rho_loss: 0.0014 - rho_mae: 0.0288 - val_loss: 0.0472 - val_phase_accuracy: 0.9843 - val_phase_loss: 0.0332 - val_phi2_loss: 0.0247 - val_phi2_mae: 0.1042 - val_rho_loss: 0.0037 - val_rho_mae: 0.0501 - learning_rate: 5.0000e-04
# Epoch 35/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0214 - phase_accuracy: 0.9939 - phase_loss: 0.0185 - phi2_loss: 0.0047 - phi2_mae: 0.0490 - rho_loss: 0.0013 - rho_mae: 0.0278 - val_loss: 0.0763 - val_phase_accuracy: 0.9725 - val_phase_loss: 0.0656 - val_phi2_loss: 0.0186 - val_phi2_mae: 0.0855 - val_rho_loss: 0.0038 - val_rho_mae: 0.0505 - learning_rate: 5.0000e-04
# Epoch 36/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0224 - phase_accuracy: 0.9934 - phase_loss: 0.0190 - phi2_loss: 0.0053 - phi2_mae: 0.0531 - rho_loss: 0.0014 - rho_mae: 0.0291 - val_loss: 0.0353 - val_phase_accuracy: 0.9914 - val_phase_loss: 0.0235 - val_phi2_loss: 0.0198 - val_phi2_mae: 0.0994 - val_rho_loss: 0.0039 - val_rho_mae: 0.0527 - learning_rate: 5.0000e-04
# Epoch 37/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0221 - phase_accuracy: 0.9933 - phase_loss: 0.0188 - phi2_loss: 0.0054 - phi2_mae: 0.0535 - rho_loss: 0.0012 - rho_mae: 0.0273 - val_loss: 0.0489 - val_phase_accuracy: 0.9848 - val_phase_loss: 0.0363 - val_phi2_loss: 0.0223 - val_phi2_mae: 0.0853 - val_rho_loss: 0.0032 - val_rho_mae: 0.0449 - learning_rate: 5.0000e-04
# Epoch 38/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0213 - phase_accuracy: 0.9938 - phase_loss: 0.0184 - phi2_loss: 0.0046 - phi2_mae: 0.0488 - rho_loss: 0.0013 - rho_mae: 0.0274 - val_loss: 0.0306 - val_phase_accuracy: 0.9930 - val_phase_loss: 0.0218 - val_phi2_loss: 0.0144 - val_phi2_mae: 0.0808 - val_rho_loss: 0.0033 - val_rho_mae: 0.0470 - learning_rate: 5.0000e-04
# Epoch 39/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0205 - phase_accuracy: 0.9944 - phase_loss: 0.0175 - phi2_loss: 0.0047 - phi2_mae: 0.0497 - rho_loss: 0.0012 - rho_mae: 0.0265 - val_loss: 0.0637 - val_phase_accuracy: 0.9803 - val_phase_loss: 0.0510 - val_phi2_loss: 0.0223 - val_phi2_mae: 0.0980 - val_rho_loss: 0.0039 - val_rho_mae: 0.0492 - learning_rate: 5.0000e-04
# Epoch 40/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0221 - phase_accuracy: 0.9935 - phase_loss: 0.0186 - phi2_loss: 0.0056 - phi2_mae: 0.0548 - rho_loss: 0.0014 - rho_mae: 0.0292 - val_loss: 0.0433 - val_phase_accuracy: 0.9841 - val_phase_loss: 0.0341 - val_phi2_loss: 0.0142 - val_phi2_mae: 0.0730 - val_rho_loss: 0.0047 - val_rho_mae: 0.0572 - learning_rate: 5.0000e-04
# Epoch 41/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0212 - phase_accuracy: 0.9940 - phase_loss: 0.0181 - phi2_loss: 0.0049 - phi2_mae: 0.0511 - rho_loss: 0.0014 - rho_mae: 0.0287 - val_loss: 0.0391 - val_phase_accuracy: 0.9906 - val_phase_loss: 0.0237 - val_phi2_loss: 0.0269 - val_phi2_mae: 0.1115 - val_rho_loss: 0.0042 - val_rho_mae: 0.0501 - learning_rate: 5.0000e-04
# Epoch 42/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0208 - phase_accuracy: 0.9940 - phase_loss: 0.0177 - phi2_loss: 0.0049 - phi2_mae: 0.0500 - rho_loss: 0.0012 - rho_mae: 0.0264 - val_loss: 0.0337 - val_phase_accuracy: 0.9921 - val_phase_loss: 0.0255 - val_phi2_loss: 0.0138 - val_phi2_mae: 0.0696 - val_rho_loss: 0.0028 - val_rho_mae: 0.0432 - learning_rate: 5.0000e-04
# Epoch 43/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0206 - phase_accuracy: 0.9941 - phase_loss: 0.0177 - phi2_loss: 0.0046 - phi2_mae: 0.0485 - rho_loss: 0.0012 - rho_mae: 0.0265 - val_loss: 0.0547 - val_phase_accuracy: 0.9828 - val_phase_loss: 0.0393 - val_phi2_loss: 0.0259 - val_phi2_mae: 0.0843 - val_rho_loss: 0.0055 - val_rho_mae: 0.0591 - learning_rate: 5.0000e-04
# Epoch 44/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0212 - phase_accuracy: 0.9936 - phase_loss: 0.0181 - phi2_loss: 0.0050 - phi2_mae: 0.0513 - rho_loss: 0.0012 - rho_mae: 0.0265 - val_loss: 0.0424 - val_phase_accuracy: 0.9866 - val_phase_loss: 0.0331 - val_phi2_loss: 0.0153 - val_phi2_mae: 0.0856 - val_rho_loss: 0.0038 - val_rho_mae: 0.0502 - learning_rate: 5.0000e-04
# Epoch 45/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0211 - phase_accuracy: 0.9934 - phase_loss: 0.0181 - phi2_loss: 0.0048 - phi2_mae: 0.0500 - rho_loss: 0.0012 - rho_mae: 0.0273 - val_loss: 0.0405 - val_phase_accuracy: 0.9877 - val_phase_loss: 0.0304 - val_phi2_loss: 0.0147 - val_phi2_mae: 0.0925 - val_rho_loss: 0.0056 - val_rho_mae: 0.0599 - learning_rate: 5.0000e-04
# Epoch 46/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0209 - phase_accuracy: 0.9937 - phase_loss: 0.0176 - phi2_loss: 0.0054 - phi2_mae: 0.0538 - rho_loss: 0.0012 - rho_mae: 0.0268 - val_loss: 0.0551 - val_phase_accuracy: 0.9775 - val_phase_loss: 0.0480 - val_phi2_loss: 0.0118 - val_phi2_mae: 0.0700 - val_rho_loss: 0.0029 - val_rho_mae: 0.0420 - learning_rate: 5.0000e-04
# Epoch 47/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0163 - phase_accuracy: 0.9962 - phase_loss: 0.0146 - phi2_loss: 0.0029 - phi2_mae: 0.0372 - rho_loss: 5.7253e-04 - rho_mae: 0.0179 - val_loss: 0.0485 - val_phase_accuracy: 0.9850 - val_phase_loss: 0.0415 - val_phi2_loss: 0.0120 - val_phi2_mae: 0.0733 - val_rho_loss: 0.0027 - val_rho_mae: 0.0412 - learning_rate: 2.5000e-04
# Epoch 48/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0172 - phase_accuracy: 0.9956 - phase_loss: 0.0152 - phi2_loss: 0.0033 - phi2_mae: 0.0400 - rho_loss: 6.1679e-04 - rho_mae: 0.0189 - val_loss: 0.0360 - val_phase_accuracy: 0.9872 - val_phase_loss: 0.0282 - val_phi2_loss: 0.0130 - val_phi2_mae: 0.0708 - val_rho_loss: 0.0029 - val_rho_mae: 0.0448 - learning_rate: 2.5000e-04
# Epoch 49/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0167 - phase_accuracy: 0.9959 - phase_loss: 0.0149 - phi2_loss: 0.0031 - phi2_mae: 0.0385 - rho_loss: 6.3314e-04 - rho_mae: 0.0192 - val_loss: 0.0446 - val_phase_accuracy: 0.9855 - val_phase_loss: 0.0362 - val_phi2_loss: 0.0149 - val_phi2_mae: 0.0831 - val_rho_loss: 0.0026 - val_rho_mae: 0.0386 - learning_rate: 2.5000e-04
# Epoch 50/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0173 - phase_accuracy: 0.9954 - phase_loss: 0.0153 - phi2_loss: 0.0034 - phi2_mae: 0.0411 - rho_loss: 6.2252e-04 - rho_mae: 0.0189 - val_loss: 0.0287 - val_phase_accuracy: 0.9925 - val_phase_loss: 0.0203 - val_phi2_loss: 0.0141 - val_phi2_mae: 0.0768 - val_rho_loss: 0.0029 - val_rho_mae: 0.0434 - learning_rate: 2.5000e-04
# Epoch 51/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - phase_accuracy: 0.9957 - phase_loss: 0.0149 - phi2_loss: 0.0034 - phi2_mae: 0.0414 - rho_loss: 6.0855e-04 - rho_mae: 0.0187 - val_loss: 0.0335 - val_phase_accuracy: 0.9889 - val_phase_loss: 0.0269 - val_phi2_loss: 0.0113 - val_phi2_mae: 0.0632 - val_rho_loss: 0.0023 - val_rho_mae: 0.0393 - learning_rate: 2.5000e-04
# Epoch 52/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0174 - phase_accuracy: 0.9950 - phase_loss: 0.0153 - phi2_loss: 0.0035 - phi2_mae: 0.0420 - rho_loss: 6.5464e-04 - rho_mae: 0.0194 - val_loss: 0.0361 - val_phase_accuracy: 0.9881 - val_phase_loss: 0.0285 - val_phi2_loss: 0.0130 - val_phi2_mae: 0.0686 - val_rho_loss: 0.0025 - val_rho_mae: 0.0399 - learning_rate: 2.5000e-04
# Epoch 53/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - phase_accuracy: 0.9958 - phase_loss: 0.0144 - phi2_loss: 0.0029 - phi2_mae: 0.0376 - rho_loss: 5.6842e-04 - rho_mae: 0.0180 - val_loss: 0.0369 - val_phase_accuracy: 0.9870 - val_phase_loss: 0.0295 - val_phi2_loss: 0.0128 - val_phi2_mae: 0.0703 - val_rho_loss: 0.0024 - val_rho_mae: 0.0385 - learning_rate: 2.5000e-04
# Epoch 54/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0166 - phase_accuracy: 0.9956 - phase_loss: 0.0147 - phi2_loss: 0.0031 - phi2_mae: 0.0395 - rho_loss: 6.0665e-04 - rho_mae: 0.0187 - val_loss: 0.0291 - val_phase_accuracy: 0.9912 - val_phase_loss: 0.0224 - val_phi2_loss: 0.0113 - val_phi2_mae: 0.0625 - val_rho_loss: 0.0023 - val_rho_mae: 0.0382 - learning_rate: 2.5000e-04
# Epoch 55/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0163 - phase_accuracy: 0.9957 - phase_loss: 0.0145 - phi2_loss: 0.0030 - phi2_mae: 0.0382 - rho_loss: 5.9070e-04 - rho_mae: 0.0185 - val_loss: 0.0308 - val_phase_accuracy: 0.9900 - val_phase_loss: 0.0231 - val_phi2_loss: 0.0137 - val_phi2_mae: 0.0706 - val_rho_loss: 0.0022 - val_rho_mae: 0.0375 - learning_rate: 2.5000e-04
# Epoch 56/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - phase_accuracy: 0.9959 - phase_loss: 0.0143 - phi2_loss: 0.0029 - phi2_mae: 0.0373 - rho_loss: 6.2584e-04 - rho_mae: 0.0190 - val_loss: 0.0310 - val_phase_accuracy: 0.9902 - val_phase_loss: 0.0240 - val_phi2_loss: 0.0122 - val_phi2_mae: 0.0670 - val_rho_loss: 0.0021 - val_rho_mae: 0.0359 - learning_rate: 2.5000e-04
# Epoch 57/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0159 - phase_accuracy: 0.9959 - phase_loss: 0.0141 - phi2_loss: 0.0030 - phi2_mae: 0.0388 - rho_loss: 5.8992e-04 - rho_mae: 0.0184 - val_loss: 0.0374 - val_phase_accuracy: 0.9878 - val_phase_loss: 0.0303 - val_phi2_loss: 0.0119 - val_phi2_mae: 0.0677 - val_rho_loss: 0.0026 - val_rho_mae: 0.0399 - learning_rate: 2.5000e-04
# Epoch 58/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0168 - phase_accuracy: 0.9952 - phase_loss: 0.0148 - phi2_loss: 0.0033 - phi2_mae: 0.0412 - rho_loss: 5.9015e-04 - rho_mae: 0.0184 - val_loss: 0.0286 - val_phase_accuracy: 0.9920 - val_phase_loss: 0.0221 - val_phi2_loss: 0.0111 - val_phi2_mae: 0.0707 - val_rho_loss: 0.0020 - val_rho_mae: 0.0346 - learning_rate: 2.5000e-04
# Epoch 59/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0147 - phase_accuracy: 0.9968 - phase_loss: 0.0132 - phi2_loss: 0.0024 - phi2_mae: 0.0327 - rho_loss: 4.4034e-04 - rho_mae: 0.0153 - val_loss: 0.0330 - val_phase_accuracy: 0.9882 - val_phase_loss: 0.0256 - val_phi2_loss: 0.0133 - val_phi2_mae: 0.0746 - val_rho_loss: 0.0020 - val_rho_mae: 0.0354 - learning_rate: 1.2500e-04
# Epoch 60/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0143 - phase_accuracy: 0.9972 - phase_loss: 0.0130 - phi2_loss: 0.0023 - phi2_mae: 0.0316 - rho_loss: 4.2354e-04 - rho_mae: 0.0148 - val_loss: 0.0238 - val_phase_accuracy: 0.9943 - val_phase_loss: 0.0179 - val_phi2_loss: 0.0102 - val_phi2_mae: 0.0640 - val_rho_loss: 0.0019 - val_rho_mae: 0.0338 - learning_rate: 1.2500e-04
# Epoch 61/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0147 - phase_accuracy: 0.9967 - phase_loss: 0.0132 - phi2_loss: 0.0024 - phi2_mae: 0.0330 - rho_loss: 4.4327e-04 - rho_mae: 0.0154 - val_loss: 0.0297 - val_phase_accuracy: 0.9909 - val_phase_loss: 0.0231 - val_phi2_loss: 0.0114 - val_phi2_mae: 0.0671 - val_rho_loss: 0.0022 - val_rho_mae: 0.0365 - learning_rate: 1.2500e-04
# Epoch 62/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0144 - phase_accuracy: 0.9968 - phase_loss: 0.0130 - phi2_loss: 0.0024 - phi2_mae: 0.0325 - rho_loss: 4.2985e-04 - rho_mae: 0.0151 - val_loss: 0.0260 - val_phase_accuracy: 0.9918 - val_phase_loss: 0.0192 - val_phi2_loss: 0.0116 - val_phi2_mae: 0.0652 - val_rho_loss: 0.0022 - val_rho_mae: 0.0369 - learning_rate: 1.2500e-04
# Epoch 63/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0146 - phase_accuracy: 0.9967 - phase_loss: 0.0132 - phi2_loss: 0.0024 - phi2_mae: 0.0335 - rho_loss: 4.3895e-04 - rho_mae: 0.0153 - val_loss: 0.0313 - val_phase_accuracy: 0.9888 - val_phase_loss: 0.0251 - val_phi2_loss: 0.0104 - val_phi2_mae: 0.0615 - val_rho_loss: 0.0022 - val_rho_mae: 0.0370 - learning_rate: 1.2500e-04
# Epoch 64/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0148 - phase_accuracy: 0.9965 - phase_loss: 0.0133 - phi2_loss: 0.0025 - phi2_mae: 0.0337 - rho_loss: 4.4948e-04 - rho_mae: 0.0157 - val_loss: 0.0318 - val_phase_accuracy: 0.9883 - val_phase_loss: 0.0263 - val_phi2_loss: 0.0097 - val_phi2_mae: 0.0616 - val_rho_loss: 0.0018 - val_rho_mae: 0.0333 - learning_rate: 1.2500e-04
# Epoch 65/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0143 - phase_accuracy: 0.9969 - phase_loss: 0.0129 - phi2_loss: 0.0023 - phi2_mae: 0.0323 - rho_loss: 4.2558e-04 - rho_mae: 0.0151 - val_loss: 0.0353 - val_phase_accuracy: 0.9870 - val_phase_loss: 0.0284 - val_phi2_loss: 0.0121 - val_phi2_mae: 0.0692 - val_rho_loss: 0.0020 - val_rho_mae: 0.0359 - learning_rate: 1.2500e-04
# Epoch 66/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0148 - phase_accuracy: 0.9965 - phase_loss: 0.0133 - phi2_loss: 0.0025 - phi2_mae: 0.0338 - rho_loss: 4.4033e-04 - rho_mae: 0.0154 - val_loss: 0.0407 - val_phase_accuracy: 0.9850 - val_phase_loss: 0.0337 - val_phi2_loss: 0.0121 - val_phi2_mae: 0.0692 - val_rho_loss: 0.0023 - val_rho_mae: 0.0394 - learning_rate: 1.2500e-04
# Epoch 67/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0144 - phase_accuracy: 0.9968 - phase_loss: 0.0130 - phi2_loss: 0.0024 - phi2_mae: 0.0330 - rho_loss: 4.3112e-04 - rho_mae: 0.0152 - val_loss: 0.0327 - val_phase_accuracy: 0.9882 - val_phase_loss: 0.0253 - val_phi2_loss: 0.0129 - val_phi2_mae: 0.0750 - val_rho_loss: 0.0023 - val_rho_mae: 0.0394 - learning_rate: 1.2500e-04
# Epoch 68/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0143 - phase_accuracy: 0.9967 - phase_loss: 0.0129 - phi2_loss: 0.0024 - phi2_mae: 0.0334 - rho_loss: 4.2049e-04 - rho_mae: 0.0149 - val_loss: 0.0289 - val_phase_accuracy: 0.9902 - val_phase_loss: 0.0233 - val_phi2_loss: 0.0094 - val_phi2_mae: 0.0602 - val_rho_loss: 0.0020 - val_rho_mae: 0.0359 - learning_rate: 1.2500e-04
# Epoch 69/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0135 - phase_accuracy: 0.9977 - phase_loss: 0.0123 - phi2_loss: 0.0020 - phi2_mae: 0.0287 - rho_loss: 3.7696e-04 - rho_mae: 0.0137 - val_loss: 0.0260 - val_phase_accuracy: 0.9922 - val_phase_loss: 0.0205 - val_phi2_loss: 0.0094 - val_phi2_mae: 0.0610 - val_rho_loss: 0.0019 - val_rho_mae: 0.0342 - learning_rate: 6.2500e-05
# Epoch 70/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0135 - phase_accuracy: 0.9976 - phase_loss: 0.0123 - phi2_loss: 0.0020 - phi2_mae: 0.0287 - rho_loss: 3.7279e-04 - rho_mae: 0.0136 - val_loss: 0.0231 - val_phase_accuracy: 0.9936 - val_phase_loss: 0.0175 - val_phi2_loss: 0.0094 - val_phi2_mae: 0.0589 - val_rho_loss: 0.0019 - val_rho_mae: 0.0338 - learning_rate: 6.2500e-05
# Epoch 71/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0135 - phase_accuracy: 0.9974 - phase_loss: 0.0123 - phi2_loss: 0.0020 - phi2_mae: 0.0288 - rho_loss: 3.7296e-04 - rho_mae: 0.0136 - val_loss: 0.0312 - val_phase_accuracy: 0.9899 - val_phase_loss: 0.0253 - val_phi2_loss: 0.0103 - val_phi2_mae: 0.0629 - val_rho_loss: 0.0018 - val_rho_mae: 0.0329 - learning_rate: 6.2500e-05
# Epoch 72/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0134 - phase_accuracy: 0.9975 - phase_loss: 0.0122 - phi2_loss: 0.0020 - phi2_mae: 0.0291 - rho_loss: 3.7296e-04 - rho_mae: 0.0136 - val_loss: 0.0278 - val_phase_accuracy: 0.9905 - val_phase_loss: 0.0224 - val_phi2_loss: 0.0092 - val_phi2_mae: 0.0596 - val_rho_loss: 0.0019 - val_rho_mae: 0.0338 - learning_rate: 6.2500e-05
# Epoch 73/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0134 - phase_accuracy: 0.9974 - phase_loss: 0.0122 - phi2_loss: 0.0020 - phi2_mae: 0.0290 - rho_loss: 3.6655e-04 - rho_mae: 0.0135 - val_loss: 0.0348 - val_phase_accuracy: 0.9876 - val_phase_loss: 0.0297 - val_phi2_loss: 0.0090 - val_phi2_mae: 0.0594 - val_rho_loss: 0.0018 - val_rho_mae: 0.0335 - learning_rate: 6.2500e-05
# Epoch 74/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0134 - phase_accuracy: 0.9975 - phase_loss: 0.0122 - phi2_loss: 0.0020 - phi2_mae: 0.0292 - rho_loss: 3.6666e-04 - rho_mae: 0.0135 - val_loss: 0.0284 - val_phase_accuracy: 0.9902 - val_phase_loss: 0.0229 - val_phi2_loss: 0.0092 - val_phi2_mae: 0.0620 - val_rho_loss: 0.0020 - val_rho_mae: 0.0350 - learning_rate: 6.2500e-05
# Epoch 75/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0135 - phase_accuracy: 0.9975 - phase_loss: 0.0122 - phi2_loss: 0.0021 - phi2_mae: 0.0299 - rho_loss: 3.6900e-04 - rho_mae: 0.0136 - val_loss: 0.0286 - val_phase_accuracy: 0.9916 - val_phase_loss: 0.0230 - val_phi2_loss: 0.0097 - val_phi2_mae: 0.0602 - val_rho_loss: 0.0018 - val_rho_mae: 0.0337 - learning_rate: 6.2500e-05
# Epoch 76/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0133 - phase_accuracy: 0.9975 - phase_loss: 0.0121 - phi2_loss: 0.0020 - phi2_mae: 0.0291 - rho_loss: 3.6607e-04 - rho_mae: 0.0135 - val_loss: 0.0371 - val_phase_accuracy: 0.9871 - val_phase_loss: 0.0309 - val_phi2_loss: 0.0107 - val_phi2_mae: 0.0614 - val_rho_loss: 0.0020 - val_rho_mae: 0.0365 - learning_rate: 6.2500e-05
# Epoch 77/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0133 - phase_accuracy: 0.9976 - phase_loss: 0.0121 - phi2_loss: 0.0020 - phi2_mae: 0.0288 - rho_loss: 3.6623e-04 - rho_mae: 0.0135 - val_loss: 0.0301 - val_phase_accuracy: 0.9900 - val_phase_loss: 0.0247 - val_phi2_loss: 0.0093 - val_phi2_mae: 0.0605 - val_rho_loss: 0.0018 - val_rho_mae: 0.0337 - learning_rate: 6.2500e-05
# Epoch 78/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0133 - phase_accuracy: 0.9974 - phase_loss: 0.0121 - phi2_loss: 0.0020 - phi2_mae: 0.0287 - rho_loss: 3.6377e-04 - rho_mae: 0.0135 - val_loss: 0.0308 - val_phase_accuracy: 0.9897 - val_phase_loss: 0.0251 - val_phi2_loss: 0.0101 - val_phi2_mae: 0.0612 - val_rho_loss: 0.0017 - val_rho_mae: 0.0330 - learning_rate: 6.2500e-05
# Epoch 79/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - phase_accuracy: 0.9979 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0264 - rho_loss: 3.4553e-04 - rho_mae: 0.0128 - val_loss: 0.0283 - val_phase_accuracy: 0.9911 - val_phase_loss: 0.0230 - val_phi2_loss: 0.0092 - val_phi2_mae: 0.0583 - val_rho_loss: 0.0017 - val_rho_mae: 0.0328 - learning_rate: 3.1250e-05
# Epoch 80/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - phase_accuracy: 0.9982 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0265 - rho_loss: 3.4270e-04 - rho_mae: 0.0128 - val_loss: 0.0307 - val_phase_accuracy: 0.9884 - val_phase_loss: 0.0254 - val_phi2_loss: 0.0091 - val_phi2_mae: 0.0610 - val_rho_loss: 0.0019 - val_rho_mae: 0.0348 - learning_rate: 3.1250e-05
# Epoch 81/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - phase_accuracy: 0.9982 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0266 - rho_loss: 3.4488e-04 - rho_mae: 0.0128 - val_loss: 0.0371 - val_phase_accuracy: 0.9876 - val_phase_loss: 0.0314 - val_phi2_loss: 0.0101 - val_phi2_mae: 0.0620 - val_rho_loss: 0.0018 - val_rho_mae: 0.0344 - learning_rate: 3.1250e-05
# Epoch 82/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - phase_accuracy: 0.9982 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0264 - rho_loss: 3.4422e-04 - rho_mae: 0.0128 - val_loss: 0.0286 - val_phase_accuracy: 0.9909 - val_phase_loss: 0.0231 - val_phi2_loss: 0.0095 - val_phi2_mae: 0.0620 - val_rho_loss: 0.0018 - val_rho_mae: 0.0344 - learning_rate: 3.1250e-05
# Epoch 83/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0129 - phase_accuracy: 0.9981 - phase_loss: 0.0118 - phi2_loss: 0.0018 - phi2_mae: 0.0267 - rho_loss: 3.4703e-04 - rho_mae: 0.0129 - val_loss: 0.0272 - val_phase_accuracy: 0.9913 - val_phase_loss: 0.0220 - val_phi2_loss: 0.0088 - val_phi2_mae: 0.0571 - val_rho_loss: 0.0018 - val_rho_mae: 0.0341 - learning_rate: 3.1250e-05
# Epoch 84/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0129 - phase_accuracy: 0.9978 - phase_loss: 0.0118 - phi2_loss: 0.0018 - phi2_mae: 0.0268 - rho_loss: 3.4113e-04 - rho_mae: 0.0127 - val_loss: 0.0254 - val_phase_accuracy: 0.9914 - val_phase_loss: 0.0198 - val_phi2_loss: 0.0096 - val_phi2_mae: 0.0607 - val_rho_loss: 0.0018 - val_rho_mae: 0.0342 - learning_rate: 3.1250e-05
# Epoch 85/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - phase_accuracy: 0.9980 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0269 - rho_loss: 3.4331e-04 - rho_mae: 0.0128 - val_loss: 0.0256 - val_phase_accuracy: 0.9908 - val_phase_loss: 0.0204 - val_phi2_loss: 0.0087 - val_phi2_mae: 0.0577 - val_rho_loss: 0.0019 - val_rho_mae: 0.0346 - learning_rate: 3.1250e-05
# Epoch 86/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - phase_accuracy: 0.9981 - phase_loss: 0.0117 - phi2_loss: 0.0018 - phi2_mae: 0.0265 - rho_loss: 3.3924e-04 - rho_mae: 0.0126 - val_loss: 0.0341 - val_phase_accuracy: 0.9884 - val_phase_loss: 0.0289 - val_phi2_loss: 0.0092 - val_phi2_mae: 0.0647 - val_rho_loss: 0.0017 - val_rho_mae: 0.0332 - learning_rate: 3.1250e-05
# Epoch 87/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - phase_accuracy: 0.9984 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0255 - rho_loss: 3.3066e-04 - rho_mae: 0.0123 - val_loss: 0.0275 - val_phase_accuracy: 0.9901 - val_phase_loss: 0.0223 - val_phi2_loss: 0.0090 - val_phi2_mae: 0.0586 - val_rho_loss: 0.0017 - val_rho_mae: 0.0330 - learning_rate: 1.5625e-05
# Epoch 88/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9983 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0255 - rho_loss: 3.3341e-04 - rho_mae: 0.0124 - val_loss: 0.0288 - val_phase_accuracy: 0.9897 - val_phase_loss: 0.0234 - val_phi2_loss: 0.0092 - val_phi2_mae: 0.0592 - val_rho_loss: 0.0018 - val_rho_mae: 0.0336 - learning_rate: 1.5625e-05
# Epoch 89/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9983 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0256 - rho_loss: 3.3262e-04 - rho_mae: 0.0124 - val_loss: 0.0264 - val_phase_accuracy: 0.9914 - val_phase_loss: 0.0213 - val_phi2_loss: 0.0086 - val_phi2_mae: 0.0571 - val_rho_loss: 0.0018 - val_rho_mae: 0.0336 - learning_rate: 1.5625e-05
# Epoch 90/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - phase_accuracy: 0.9983 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0254 - rho_loss: 3.3256e-04 - rho_mae: 0.0124 - val_loss: 0.0303 - val_phase_accuracy: 0.9884 - val_phase_loss: 0.0250 - val_phi2_loss: 0.0089 - val_phi2_mae: 0.0586 - val_rho_loss: 0.0018 - val_rho_mae: 0.0342 - learning_rate: 1.5625e-05
# Epoch 91/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9983 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0256 - rho_loss: 3.3190e-04 - rho_mae: 0.0124 - val_loss: 0.0310 - val_phase_accuracy: 0.9894 - val_phase_loss: 0.0259 - val_phi2_loss: 0.0089 - val_phi2_mae: 0.0579 - val_rho_loss: 0.0018 - val_rho_mae: 0.0338 - learning_rate: 1.5625e-05
# Epoch 92/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9983 - phase_loss: 0.0115 - phi2_loss: 0.0018 - phi2_mae: 0.0256 - rho_loss: 3.3063e-04 - rho_mae: 0.0124 - val_loss: 0.0279 - val_phase_accuracy: 0.9908 - val_phase_loss: 0.0225 - val_phi2_loss: 0.0090 - val_phi2_mae: 0.0588 - val_rho_loss: 0.0019 - val_rho_mae: 0.0352 - learning_rate: 1.5625e-05
# Epoch 93/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9985 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0253 - rho_loss: 3.3254e-04 - rho_mae: 0.0125 - val_loss: 0.0308 - val_phase_accuracy: 0.9886 - val_phase_loss: 0.0257 - val_phi2_loss: 0.0088 - val_phi2_mae: 0.0586 - val_rho_loss: 0.0017 - val_rho_mae: 0.0333 - learning_rate: 1.5625e-05
# Epoch 94/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - phase_accuracy: 0.9984 - phase_loss: 0.0115 - phi2_loss: 0.0017 - phi2_mae: 0.0253 - rho_loss: 3.2991e-04 - rho_mae: 0.0124 - val_loss: 0.0268 - val_phase_accuracy: 0.9904 - val_phase_loss: 0.0217 - val_phi2_loss: 0.0088 - val_phi2_mae: 0.0582 - val_rho_loss: 0.0017 - val_rho_mae: 0.0330 - learning_rate: 1.5625e-05
# Epoch 95/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9986 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0248 - rho_loss: 3.2484e-04 - rho_mae: 0.0121 - val_loss: 0.0274 - val_phase_accuracy: 0.9913 - val_phase_loss: 0.0223 - val_phi2_loss: 0.0088 - val_phi2_mae: 0.0585 - val_rho_loss: 0.0018 - val_rho_mae: 0.0332 - learning_rate: 7.8125e-06
# Epoch 96/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9985 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0249 - rho_loss: 3.2478e-04 - rho_mae: 0.0121 - val_loss: 0.0295 - val_phase_accuracy: 0.9903 - val_phase_loss: 0.0246 - val_phi2_loss: 0.0084 - val_phi2_mae: 0.0574 - val_rho_loss: 0.0017 - val_rho_mae: 0.0332 - learning_rate: 7.8125e-06
# Epoch 97/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9985 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0247 - rho_loss: 3.2258e-04 - rho_mae: 0.0121 - val_loss: 0.0260 - val_phase_accuracy: 0.9912 - val_phase_loss: 0.0209 - val_phi2_loss: 0.0087 - val_phi2_mae: 0.0578 - val_rho_loss: 0.0018 - val_rho_mae: 0.0333 - learning_rate: 7.8125e-06
# Epoch 98/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9986 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0248 - rho_loss: 3.2354e-04 - rho_mae: 0.0121 - val_loss: 0.0262 - val_phase_accuracy: 0.9908 - val_phase_loss: 0.0210 - val_phi2_loss: 0.0089 - val_phi2_mae: 0.0583 - val_rho_loss: 0.0018 - val_rho_mae: 0.0339 - learning_rate: 7.8125e-06
# Epoch 99/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9986 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0249 - rho_loss: 3.2274e-04 - rho_mae: 0.0121 - val_loss: 0.0286 - val_phase_accuracy: 0.9901 - val_phase_loss: 0.0236 - val_phi2_loss: 0.0088 - val_phi2_mae: 0.0581 - val_rho_loss: 0.0017 - val_rho_mae: 0.0328 - learning_rate: 7.8125e-06
# Epoch 100/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - phase_accuracy: 0.9985 - phase_loss: 0.0114 - phi2_loss: 0.0017 - phi2_mae: 0.0247 - rho_loss: 3.2200e-04 - rho_mae: 0.0121 - val_loss: 0.0269 - val_phase_accuracy: 0.9907 - val_phase_loss: 0.0219 - val_phi2_loss: 0.0085 - val_phi2_mae: 0.0573 - val_rho_loss: 0.0017 - val_rho_mae: 0.0329 - learning_rate: 7.8125e-06
# 📊 Classification Report (Phase):
#               precision    recall  f1-score   support
#
#            0     0.9986    0.9958    0.9972     97450
#            1     0.9939    0.9979    0.9959     65951
#
#     accuracy                         0.9967    163401
#    macro avg     0.9962    0.9969    0.9965    163401
# weighted avg     0.9967    0.9967    0.9967    163401
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23660\825025126.py:186: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_labels = df["Phase"].astype(int).ravel()

# %% [markdown]
# # Reduced Dataset

# %% [markdown]
# ## 6.6k Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(3000, len(df_MI))
n_SF = min(3000, len(df_SF))
n_boundary = min(6000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('6k-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))
# Out:
#           t  Ubar  Mubar       Density          Phi2        Energy  Iters  \
# 0       1.0   0.0   -5.0  1.048576e-14  1.048576e-14  2.097152e-13      8
# 1       1.0   0.0   -4.9  1.508449e-14  1.508449e-14  2.882646e-13      8
# 2       1.0   0.0   -4.8  2.186340e-14  2.186340e-14  3.987884e-13      8
# 3       1.0   0.0   -4.7  3.193733e-14  3.193733e-14  5.553901e-13      8
# 4       1.0   0.0   -4.6  4.703477e-14  4.703477e-14  7.788958e-13      8
# ...     ...   ...    ...           ...           ...           ...    ...
# 163396  1.0  25.0   59.6  3.000000e+00  8.530376e-13 -1.038000e+02     21
# 163397  1.0  25.0   59.7  3.000000e+00  7.586920e-13 -1.041000e+02     21
# 163398  1.0  25.0   59.8  3.000000e+00  6.791729e-13 -1.044000e+02     21
# 163399  1.0  25.0   59.9  3.000000e+00  6.119027e-13 -1.047000e+02     21
# 163400  1.0  25.0   60.0  3.000000e+00  5.548081e-13 -1.050000e+02     21
#
#         Phase
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 163396      0
# 163397      0
# 163398      0
# 163399      0
# 163400      0
#
# [163401 rows x 8 columns]
#         t  Ubar  Mubar       Density          Phi2        Energy  Iters  Phase
# 0     1.0  24.4   13.4  1.000000e+00  6.034134e-14 -1.340000e+01      9      0
# 1     1.0  16.0   -1.1  8.624612e-11  8.624612e-11  9.487073e-12    101      0
# 2     1.0  22.4    6.0  1.000000e+00  5.328648e-14 -6.000000e+00     10      0
# 3     1.0  14.2   22.4  2.000000e+00  6.649626e-12 -3.060000e+01     37      0
# 4     1.0  22.0    7.5  1.000000e+00  1.363996e-14 -7.500000e+00     10      0
# ...   ...   ...    ...           ...           ...           ...    ...    ...
# 6679  1.0   3.6   -1.0  8.456767e-05  8.456471e-05  4.598585e-09   4589      1
# 6680  1.0   5.3   26.2  4.999955e+00  2.254263e-04 -7.800000e+01   7465      1
# 6681  1.0  10.9   17.5  2.000244e+00  2.100670e-03 -2.410000e+01   2451      1
# 6682  1.0  16.3   -1.0  6.803388e-05  6.803021e-05  4.123775e-09   4118      1
# 6683  1.0   5.1   25.4  4.999955e+00  2.261209e-04 -7.600000e+01   7477      1
#
# [6684 rows x 8 columns]
# Reduced dataset summary:
# Phase
# 1    3684
# 0    3000
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 197
#     185     model.compile(
#     186         optimizer=keras.optimizers.Adam(1e-3),
#     187         loss={
#    (...)    193         metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
#     194     )
#     195     return model
# --> 197 multi_model = make_multitask_nn()
#     198 # --- 4) Train PINN ---
#     199 y_targets = {
#     200     "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
#     201     "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
#     202     "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
#     203 }
#
# Cell In[1], line 176, in make_multitask_nn(hidden)
#     174 x = inp
#     175 for h in hidden:
# --> 176     x = layers.Dense(h, activation="relu")(x)
#     178 # Three heads
#     179 phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
#
# NameError: name 'layers' is not defined

# %% [markdown]
# ##  6k extra

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(3000, len(df_MI))
n_SF = min(3000, len(df_SF))
n_boundary = min(6000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 40, 200)
mu_vals = np.linspace(0, 70, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('6k-extra-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))

# %% [markdown]
# ##  4k dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVCimport numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(2000, len(df_MI))
n_SF = min(2000, len(df_SF))
n_boundary = min(4000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('4k-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))


from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import kerasimport numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(2000, len(df_MI))
n_SF = min(2000, len(df_SF))
n_boundary = min(4000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('4k-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))


from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
#Smart sampling strategy
#------------------------------
n_MI = min(2000, len(df_MI))             # cap deep MI
n_SF = min(2000, len(df_SF))             # cap deep SF
n_boundary = min(6000, len(df_boundary)) # oversample boundary

# # n_MI = min(5000, len(df_MI))
# # n_SF = min(5000, len(df_SF))
# # n_boundary = min(10000, len(df_boundary))

# n_MI = min(3000, len(df_MI))
# n_SF = min(3000, len(df_SF))
# n_boundary = min(6000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# %%
# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Phase Diagram")

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))
# Out:
# Epoch 1/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 3.2086 - phase_accuracy: 0.4619 - phase_loss: 0.7907 - phi2_loss: 3.3060 - phi2_mae: 1.3476 - rho_loss: 1.4513 - rho_mae: 0.9008 - val_loss: 2.0992 - val_phase_accuracy: 0.0000e+00 - val_phase_loss: 0.9340 - val_phi2_loss: 0.9910 - val_phi2_mae: 0.8835 - val_rho_loss: 1.3347 - val_rho_mae: 0.7693 - learning_rate: 0.0010
# Epoch 2/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7239 - phase_accuracy: 0.6001 - phase_loss: 0.6693 - phi2_loss: 0.8245 - phi2_mae: 0.7224 - rho_loss: 1.2790 - rho_mae: 0.8228 - val_loss: 1.6179 - val_phase_accuracy: 0.2191 - val_phase_loss: 0.8756 - val_phi2_loss: 0.1658 - val_phi2_mae: 0.3086 - val_rho_loss: 1.3079 - val_rho_mae: 0.6946 - learning_rate: 0.0010
# Epoch 3/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5014 - phase_accuracy: 0.7023 - phase_loss: 0.6307 - phi2_loss: 0.5434 - phi2_mae: 0.5568 - rho_loss: 1.1933 - rho_mae: 0.7780 - val_loss: 1.6673 - val_phase_accuracy: 0.2162 - val_phase_loss: 0.9813 - val_phi2_loss: 0.1018 - val_phi2_mae: 0.2180 - val_rho_loss: 1.2594 - val_rho_mae: 0.6881 - learning_rate: 0.0010
# Epoch 4/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4218 - phase_accuracy: 0.7375 - phase_loss: 0.6056 - phi2_loss: 0.4997 - phi2_mae: 0.5071 - rho_loss: 1.1297 - rho_mae: 0.7487 - val_loss: 1.6994 - val_phase_accuracy: 0.2034 - val_phase_loss: 1.0318 - val_phi2_loss: 0.1160 - val_phi2_mae: 0.2166 - val_rho_loss: 1.2080 - val_rho_mae: 0.7084 - learning_rate: 0.0010
# Epoch 5/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3493 - phase_accuracy: 0.7390 - phase_loss: 0.5815 - phi2_loss: 0.4591 - phi2_mae: 0.4779 - rho_loss: 1.0769 - rho_mae: 0.7267 - val_loss: 1.6717 - val_phase_accuracy: 0.2148 - val_phase_loss: 1.0155 - val_phi2_loss: 0.1880 - val_phi2_mae: 0.2741 - val_rho_loss: 1.1138 - val_rho_mae: 0.6541 - learning_rate: 0.0010
# Epoch 6/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2913 - phase_accuracy: 0.7516 - phase_loss: 0.5615 - phi2_loss: 0.4371 - phi2_mae: 0.4620 - rho_loss: 1.0126 - rho_mae: 0.7048 - val_loss: 1.5854 - val_phase_accuracy: 0.2361 - val_phase_loss: 0.9586 - val_phi2_loss: 0.1686 - val_phi2_mae: 0.2737 - val_rho_loss: 1.0730 - val_rho_mae: 0.6686 - learning_rate: 0.0010
# Epoch 7/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2360 - phase_accuracy: 0.7571 - phase_loss: 0.5427 - phi2_loss: 0.4242 - phi2_mae: 0.4523 - rho_loss: 0.9627 - rho_mae: 0.6796 - val_loss: 1.5964 - val_phase_accuracy: 0.2105 - val_phase_loss: 1.0037 - val_phi2_loss: 0.1458 - val_phi2_mae: 0.2411 - val_rho_loss: 1.0271 - val_rho_mae: 0.6655 - learning_rate: 0.0010
# Epoch 8/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1825 - phase_accuracy: 0.7681 - phase_loss: 0.5256 - phi2_loss: 0.4104 - phi2_mae: 0.4461 - rho_loss: 0.8959 - rho_mae: 0.6534 - val_loss: 1.5463 - val_phase_accuracy: 0.2048 - val_phase_loss: 0.9798 - val_phi2_loss: 0.1484 - val_phi2_mae: 0.2567 - val_rho_loss: 0.9717 - val_rho_mae: 0.6334 - learning_rate: 0.0010
# Epoch 9/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1260 - phase_accuracy: 0.7807 - phase_loss: 0.5083 - phi2_loss: 0.3988 - phi2_mae: 0.4413 - rho_loss: 0.8320 - rho_mae: 0.6259 - val_loss: 1.4398 - val_phase_accuracy: 0.3115 - val_phase_loss: 0.8527 - val_phi2_loss: 0.1886 - val_phi2_mae: 0.3158 - val_rho_loss: 0.9726 - val_rho_mae: 0.6560 - learning_rate: 0.0010
# Epoch 10/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0740 - phase_accuracy: 0.8043 - phase_loss: 0.4922 - phi2_loss: 0.3930 - phi2_mae: 0.4372 - rho_loss: 0.7779 - rho_mae: 0.6026 - val_loss: 1.3413 - val_phase_accuracy: 0.2973 - val_phase_loss: 0.8350 - val_phi2_loss: 0.1532 - val_phi2_mae: 0.2635 - val_rho_loss: 0.8467 - val_rho_mae: 0.6124 - learning_rate: 0.0010
# Epoch 11/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0265 - phase_accuracy: 0.8209 - phase_loss: 0.4733 - phi2_loss: 0.3698 - phi2_mae: 0.4289 - rho_loss: 0.7252 - rho_mae: 0.5863 - val_loss: 1.3121 - val_phase_accuracy: 0.4211 - val_phase_loss: 0.7934 - val_phi2_loss: 0.1706 - val_phi2_mae: 0.3247 - val_rho_loss: 0.8541 - val_rho_mae: 0.6441 - learning_rate: 0.0010
# Epoch 12/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9618 - phase_accuracy: 0.8355 - phase_loss: 0.4568 - phi2_loss: 0.3585 - phi2_mae: 0.4237 - rho_loss: 0.6497 - rho_mae: 0.5471 - val_loss: 1.3492 - val_phase_accuracy: 0.2333 - val_phase_loss: 0.8690 - val_phi2_loss: 0.1764 - val_phi2_mae: 0.3148 - val_rho_loss: 0.7718 - val_rho_mae: 0.5868 - learning_rate: 0.0010
# Epoch 13/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9037 - phase_accuracy: 0.8400 - phase_loss: 0.4439 - phi2_loss: 0.3418 - phi2_mae: 0.4149 - rho_loss: 0.5779 - rho_mae: 0.5096 - val_loss: 1.3098 - val_phase_accuracy: 0.2575 - val_phase_loss: 0.8436 - val_phi2_loss: 0.1905 - val_phi2_mae: 0.3335 - val_rho_loss: 0.7307 - val_rho_mae: 0.5550 - learning_rate: 0.0010
# Epoch 14/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8426 - phase_accuracy: 0.8531 - phase_loss: 0.4295 - phi2_loss: 0.3212 - phi2_mae: 0.4059 - rho_loss: 0.5026 - rho_mae: 0.4733 - val_loss: 1.2088 - val_phase_accuracy: 0.5676 - val_phase_loss: 0.7735 - val_phi2_loss: 0.2226 - val_phi2_mae: 0.3724 - val_rho_loss: 0.6370 - val_rho_mae: 0.5402 - learning_rate: 0.0010
# Epoch 15/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7797 - phase_accuracy: 0.8573 - phase_loss: 0.4162 - phi2_loss: 0.3002 - phi2_mae: 0.3971 - rho_loss: 0.4203 - rho_mae: 0.4289 - val_loss: 1.1483 - val_phase_accuracy: 0.5562 - val_phase_loss: 0.7295 - val_phi2_loss: 0.2511 - val_phi2_mae: 0.4270 - val_rho_loss: 0.5759 - val_rho_mae: 0.5400 - learning_rate: 0.0010
# Epoch 16/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7259 - phase_accuracy: 0.8583 - phase_loss: 0.4037 - phi2_loss: 0.2805 - phi2_mae: 0.3857 - rho_loss: 0.3659 - rho_mae: 0.3977 - val_loss: 1.0678 - val_phase_accuracy: 0.6003 - val_phase_loss: 0.7249 - val_phi2_loss: 0.1436 - val_phi2_mae: 0.2990 - val_rho_loss: 0.5315 - val_rho_mae: 0.5103 - learning_rate: 0.0010
# Epoch 17/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6744 - phase_accuracy: 0.8586 - phase_loss: 0.3938 - phi2_loss: 0.2602 - phi2_mae: 0.3755 - rho_loss: 0.3048 - rho_mae: 0.3574 - val_loss: 1.0722 - val_phase_accuracy: 0.6458 - val_phase_loss: 0.7176 - val_phi2_loss: 0.2560 - val_phi2_mae: 0.4274 - val_rho_loss: 0.4446 - val_rho_mae: 0.4568 - learning_rate: 0.0010
# Epoch 18/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6286 - phase_accuracy: 0.8716 - phase_loss: 0.3785 - phi2_loss: 0.2390 - phi2_mae: 0.3618 - rho_loss: 0.2579 - rho_mae: 0.3375 - val_loss: 1.1326 - val_phase_accuracy: 0.4723 - val_phase_loss: 0.8244 - val_phi2_loss: 0.2138 - val_phi2_mae: 0.3764 - val_rho_loss: 0.3937 - val_rho_mae: 0.4405 - learning_rate: 0.0010
# Epoch 19/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5940 - phase_accuracy: 0.8716 - phase_loss: 0.3686 - phi2_loss: 0.2268 - phi2_mae: 0.3577 - rho_loss: 0.2248 - rho_mae: 0.3225 - val_loss: 1.0661 - val_phase_accuracy: 0.5149 - val_phase_loss: 0.7751 - val_phi2_loss: 0.1949 - val_phi2_mae: 0.3542 - val_rho_loss: 0.3784 - val_rho_mae: 0.4438 - learning_rate: 0.0010
# Epoch 20/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5614 - phase_accuracy: 0.8724 - phase_loss: 0.3564 - phi2_loss: 0.2123 - phi2_mae: 0.3495 - rho_loss: 0.1954 - rho_mae: 0.3068 - val_loss: 1.0006 - val_phase_accuracy: 0.5590 - val_phase_loss: 0.7462 - val_phi2_loss: 0.1935 - val_phi2_mae: 0.3537 - val_rho_loss: 0.3068 - val_rho_mae: 0.4019 - learning_rate: 0.0010
# Epoch 21/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5279 - phase_accuracy: 0.8744 - phase_loss: 0.3483 - phi2_loss: 0.1950 - phi2_mae: 0.3362 - rho_loss: 0.1633 - rho_mae: 0.2805 - val_loss: 1.1073 - val_phase_accuracy: 0.4495 - val_phase_loss: 0.8526 - val_phi2_loss: 0.2501 - val_phi2_mae: 0.3963 - val_rho_loss: 0.2512 - val_rho_mae: 0.3552 - learning_rate: 0.0010
# Epoch 22/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4958 - phase_accuracy: 0.8724 - phase_loss: 0.3382 - phi2_loss: 0.1847 - phi2_mae: 0.3263 - rho_loss: 0.1305 - rho_mae: 0.2508 - val_loss: 0.8485 - val_phase_accuracy: 0.7397 - val_phase_loss: 0.6175 - val_phi2_loss: 0.2511 - val_phi2_mae: 0.3824 - val_rho_loss: 0.2044 - val_rho_mae: 0.3143 - learning_rate: 0.0010
# Epoch 23/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4770 - phase_accuracy: 0.8792 - phase_loss: 0.3324 - phi2_loss: 0.1779 - phi2_mae: 0.3199 - rho_loss: 0.1119 - rho_mae: 0.2322 - val_loss: 0.9509 - val_phase_accuracy: 0.5761 - val_phase_loss: 0.7235 - val_phi2_loss: 0.2897 - val_phi2_mae: 0.4345 - val_rho_loss: 0.1584 - val_rho_mae: 0.2749 - learning_rate: 0.0010
# Epoch 24/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4542 - phase_accuracy: 0.8764 - phase_loss: 0.3215 - phi2_loss: 0.1666 - phi2_mae: 0.3115 - rho_loss: 0.0948 - rho_mae: 0.2150 - val_loss: 0.8965 - val_phase_accuracy: 0.6358 - val_phase_loss: 0.6821 - val_phi2_loss: 0.2718 - val_phi2_mae: 0.4090 - val_rho_loss: 0.1506 - val_rho_mae: 0.2817 - learning_rate: 0.0010
# Epoch 25/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4380 - phase_accuracy: 0.8779 - phase_loss: 0.3154 - phi2_loss: 0.1586 - phi2_mae: 0.3039 - rho_loss: 0.0843 - rho_mae: 0.2032 - val_loss: 0.9660 - val_phase_accuracy: 0.4680 - val_phase_loss: 0.7566 - val_phi2_loss: 0.2881 - val_phi2_mae: 0.4382 - val_rho_loss: 0.1246 - val_rho_mae: 0.2479 - learning_rate: 0.0010
# Epoch 26/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4207 - phase_accuracy: 0.8829 - phase_loss: 0.3077 - phi2_loss: 0.1513 - phi2_mae: 0.2966 - rho_loss: 0.0755 - rho_mae: 0.1940 - val_loss: 0.9418 - val_phase_accuracy: 0.5292 - val_phase_loss: 0.7420 - val_phi2_loss: 0.2845 - val_phi2_mae: 0.4204 - val_rho_loss: 0.1095 - val_rho_mae: 0.2555 - learning_rate: 0.0010
# Epoch 27/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4117 - phase_accuracy: 0.8799 - phase_loss: 0.3018 - phi2_loss: 0.1528 - phi2_mae: 0.2957 - rho_loss: 0.0682 - rho_mae: 0.1869 - val_loss: 0.8588 - val_phase_accuracy: 0.6159 - val_phase_loss: 0.6649 - val_phi2_loss: 0.2672 - val_phi2_mae: 0.4187 - val_rho_loss: 0.1151 - val_rho_mae: 0.2706 - learning_rate: 0.0010
# Epoch 28/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3948 - phase_accuracy: 0.8804 - phase_loss: 0.2935 - phi2_loss: 0.1374 - phi2_mae: 0.2816 - rho_loss: 0.0644 - rho_mae: 0.1878 - val_loss: 0.8240 - val_phase_accuracy: 0.6159 - val_phase_loss: 0.6609 - val_phi2_loss: 0.2280 - val_phi2_mae: 0.3488 - val_rho_loss: 0.0924 - val_rho_mae: 0.2338 - learning_rate: 0.0010
# Epoch 29/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3836 - phase_accuracy: 0.8850 - phase_loss: 0.2867 - phi2_loss: 0.1355 - phi2_mae: 0.2803 - rho_loss: 0.0557 - rho_mae: 0.1754 - val_loss: 0.6957 - val_phase_accuracy: 0.8122 - val_phase_loss: 0.5228 - val_phi2_loss: 0.2757 - val_phi2_mae: 0.4046 - val_rho_loss: 0.0656 - val_rho_mae: 0.1982 - learning_rate: 0.0010
# Epoch 30/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3697 - phase_accuracy: 0.8852 - phase_loss: 0.2821 - phi2_loss: 0.1281 - phi2_mae: 0.2693 - rho_loss: 0.0479 - rho_mae: 0.1611 - val_loss: 0.8718 - val_phase_accuracy: 0.4637 - val_phase_loss: 0.7151 - val_phi2_loss: 0.2396 - val_phi2_mae: 0.3707 - val_rho_loss: 0.0681 - val_rho_mae: 0.2085 - learning_rate: 0.0010
# Epoch 31/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3596 - phase_accuracy: 0.8922 - phase_loss: 0.2773 - phi2_loss: 0.1205 - phi2_mae: 0.2580 - rho_loss: 0.0449 - rho_mae: 0.1560 - val_loss: 0.8809 - val_phase_accuracy: 0.4708 - val_phase_loss: 0.7001 - val_phi2_loss: 0.2977 - val_phi2_mae: 0.4095 - val_rho_loss: 0.0586 - val_rho_mae: 0.2008 - learning_rate: 0.0010
# Epoch 32/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3535 - phase_accuracy: 0.8857 - phase_loss: 0.2692 - phi2_loss: 0.1249 - phi2_mae: 0.2636 - rho_loss: 0.0414 - rho_mae: 0.1502 - val_loss: 0.8065 - val_phase_accuracy: 0.6188 - val_phase_loss: 0.6726 - val_phi2_loss: 0.2030 - val_phi2_mae: 0.3204 - val_rho_loss: 0.0593 - val_rho_mae: 0.1937 - learning_rate: 0.0010
# Epoch 33/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3439 - phase_accuracy: 0.8895 - phase_loss: 0.2648 - phi2_loss: 0.1172 - phi2_mae: 0.2575 - rho_loss: 0.0396 - rho_mae: 0.1515 - val_loss: 0.8085 - val_phase_accuracy: 0.5007 - val_phase_loss: 0.6736 - val_phi2_loss: 0.2102 - val_phi2_mae: 0.3321 - val_rho_loss: 0.0542 - val_rho_mae: 0.1764 - learning_rate: 0.0010
# Epoch 34/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3328 - phase_accuracy: 0.8973 - phase_loss: 0.2596 - phi2_loss: 0.1093 - phi2_mae: 0.2452 - rho_loss: 0.0377 - rho_mae: 0.1456 - val_loss: 0.7929 - val_phase_accuracy: 0.6714 - val_phase_loss: 0.6499 - val_phi2_loss: 0.1979 - val_phi2_mae: 0.3459 - val_rho_loss: 0.0828 - val_rho_mae: 0.2513 - learning_rate: 0.0010
# Epoch 35/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3282 - phase_accuracy: 0.8973 - phase_loss: 0.2544 - phi2_loss: 0.1091 - phi2_mae: 0.2444 - rho_loss: 0.0380 - rho_mae: 0.1517 - val_loss: 0.7749 - val_phase_accuracy: 0.5263 - val_phase_loss: 0.6162 - val_phi2_loss: 0.2533 - val_phi2_mae: 0.3923 - val_rho_loss: 0.0597 - val_rho_mae: 0.2146 - learning_rate: 0.0010
# Epoch 36/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3184 - phase_accuracy: 0.8975 - phase_loss: 0.2512 - phi2_loss: 0.0987 - phi2_mae: 0.2337 - rho_loss: 0.0337 - rho_mae: 0.1389 - val_loss: 0.7584 - val_phase_accuracy: 0.6714 - val_phase_loss: 0.6289 - val_phi2_loss: 0.2007 - val_phi2_mae: 0.3601 - val_rho_loss: 0.0532 - val_rho_mae: 0.2027 - learning_rate: 0.0010
# Epoch 37/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3166 - phase_accuracy: 0.8983 - phase_loss: 0.2479 - phi2_loss: 0.1016 - phi2_mae: 0.2373 - rho_loss: 0.0355 - rho_mae: 0.1464 - val_loss: 0.8285 - val_phase_accuracy: 0.5064 - val_phase_loss: 0.6787 - val_phi2_loss: 0.2496 - val_phi2_mae: 0.3871 - val_rho_loss: 0.0453 - val_rho_mae: 0.1740 - learning_rate: 0.0010
# Epoch 38/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3047 - phase_accuracy: 0.9043 - phase_loss: 0.2428 - phi2_loss: 0.0931 - phi2_mae: 0.2235 - rho_loss: 0.0314 - rho_mae: 0.1363 - val_loss: 0.7181 - val_phase_accuracy: 0.7482 - val_phase_loss: 0.5790 - val_phi2_loss: 0.2301 - val_phi2_mae: 0.3778 - val_rho_loss: 0.0437 - val_rho_mae: 0.1889 - learning_rate: 5.0000e-04
# Epoch 39/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3011 - phase_accuracy: 0.9013 - phase_loss: 0.2405 - phi2_loss: 0.0918 - phi2_mae: 0.2219 - rho_loss: 0.0287 - rho_mae: 0.1304 - val_loss: 0.7617 - val_phase_accuracy: 0.7340 - val_phase_loss: 0.6220 - val_phi2_loss: 0.2386 - val_phi2_mae: 0.3935 - val_rho_loss: 0.0364 - val_rho_mae: 0.1676 - learning_rate: 5.0000e-04
# Epoch 40/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2985 - phase_accuracy: 0.9066 - phase_loss: 0.2400 - phi2_loss: 0.0913 - phi2_mae: 0.2206 - rho_loss: 0.0283 - rho_mae: 0.1299 - val_loss: 0.7672 - val_phase_accuracy: 0.5050 - val_phase_loss: 0.6408 - val_phi2_loss: 0.2006 - val_phi2_mae: 0.3385 - val_rho_loss: 0.0471 - val_rho_mae: 0.1964 - learning_rate: 5.0000e-04
# Epoch 41/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2949 - phase_accuracy: 0.9020 - phase_loss: 0.2371 - phi2_loss: 0.0874 - phi2_mae: 0.2149 - rho_loss: 0.0276 - rho_mae: 0.1276 - val_loss: 0.7625 - val_phase_accuracy: 0.7297 - val_phase_loss: 0.6272 - val_phi2_loss: 0.2145 - val_phi2_mae: 0.3504 - val_rho_loss: 0.0515 - val_rho_mae: 0.2030 - learning_rate: 5.0000e-04
# Epoch 42/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2955 - phase_accuracy: 0.9033 - phase_loss: 0.2365 - phi2_loss: 0.0879 - phi2_mae: 0.2174 - rho_loss: 0.0292 - rho_mae: 0.1332 - val_loss: 0.7514 - val_phase_accuracy: 0.7269 - val_phase_loss: 0.6338 - val_phi2_loss: 0.1933 - val_phi2_mae: 0.3316 - val_rho_loss: 0.0371 - val_rho_mae: 0.1557 - learning_rate: 5.0000e-04
# Epoch 43/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2907 - phase_accuracy: 0.9081 - phase_loss: 0.2334 - phi2_loss: 0.0842 - phi2_mae: 0.2124 - rho_loss: 0.0289 - rho_mae: 0.1325 - val_loss: 0.7587 - val_phase_accuracy: 0.6970 - val_phase_loss: 0.6283 - val_phi2_loss: 0.2165 - val_phi2_mae: 0.3708 - val_rho_loss: 0.0396 - val_rho_mae: 0.1761 - learning_rate: 5.0000e-04
# Epoch 44/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2861 - phase_accuracy: 0.9086 - phase_loss: 0.2316 - phi2_loss: 0.0827 - phi2_mae: 0.2077 - rho_loss: 0.0257 - rho_mae: 0.1227 - val_loss: 0.7439 - val_phase_accuracy: 0.7283 - val_phase_loss: 0.6107 - val_phi2_loss: 0.2294 - val_phi2_mae: 0.3753 - val_rho_loss: 0.0328 - val_rho_mae: 0.1607 - learning_rate: 5.0000e-04
# Epoch 45/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2853 - phase_accuracy: 0.9081 - phase_loss: 0.2310 - phi2_loss: 0.0828 - phi2_mae: 0.2082 - rho_loss: 0.0267 - rho_mae: 0.1278 - val_loss: 0.7327 - val_phase_accuracy: 0.7411 - val_phase_loss: 0.5987 - val_phi2_loss: 0.2211 - val_phi2_mae: 0.3715 - val_rho_loss: 0.0426 - val_rho_mae: 0.1771 - learning_rate: 5.0000e-04
# Epoch 46/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2816 - phase_accuracy: 0.9086 - phase_loss: 0.2289 - phi2_loss: 0.0814 - phi2_mae: 0.2043 - rho_loss: 0.0254 - rho_mae: 0.1231 - val_loss: 0.7348 - val_phase_accuracy: 0.7425 - val_phase_loss: 0.6015 - val_phi2_loss: 0.2257 - val_phi2_mae: 0.3661 - val_rho_loss: 0.0367 - val_rho_mae: 0.1726 - learning_rate: 2.5000e-04
# Epoch 47/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2804 - phase_accuracy: 0.9061 - phase_loss: 0.2291 - phi2_loss: 0.0798 - phi2_mae: 0.2036 - rho_loss: 0.0242 - rho_mae: 0.1204 - val_loss: 0.7827 - val_phase_accuracy: 0.6942 - val_phase_loss: 0.6536 - val_phi2_loss: 0.2173 - val_phi2_mae: 0.3726 - val_rho_loss: 0.0361 - val_rho_mae: 0.1707 - learning_rate: 2.5000e-04
# Epoch 48/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2789 - phase_accuracy: 0.9098 - phase_loss: 0.2276 - phi2_loss: 0.0791 - phi2_mae: 0.2022 - rho_loss: 0.0249 - rho_mae: 0.1220 - val_loss: 0.7206 - val_phase_accuracy: 0.7411 - val_phase_loss: 0.6062 - val_phi2_loss: 0.1856 - val_phi2_mae: 0.3282 - val_rho_loss: 0.0384 - val_rho_mae: 0.1766 - learning_rate: 2.5000e-04
# Epoch 49/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2778 - phase_accuracy: 0.9098 - phase_loss: 0.2276 - phi2_loss: 0.0788 - phi2_mae: 0.2022 - rho_loss: 0.0240 - rho_mae: 0.1198 - val_loss: 0.7213 - val_phase_accuracy: 0.7468 - val_phase_loss: 0.6123 - val_phi2_loss: 0.1732 - val_phi2_mae: 0.3201 - val_rho_loss: 0.0401 - val_rho_mae: 0.1806 - learning_rate: 2.5000e-04
# Epoch 50/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2766 - phase_accuracy: 0.9068 - phase_loss: 0.2252 - phi2_loss: 0.0784 - phi2_mae: 0.2005 - rho_loss: 0.0240 - rho_mae: 0.1205 - val_loss: 0.7693 - val_phase_accuracy: 0.7240 - val_phase_loss: 0.6435 - val_phi2_loss: 0.2102 - val_phi2_mae: 0.3525 - val_rho_loss: 0.0367 - val_rho_mae: 0.1704 - learning_rate: 2.5000e-04
# Epoch 51/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2749 - phase_accuracy: 0.9113 - phase_loss: 0.2237 - phi2_loss: 0.0764 - phi2_mae: 0.1995 - rho_loss: 0.0236 - rho_mae: 0.1191 - val_loss: 0.7494 - val_phase_accuracy: 0.7226 - val_phase_loss: 0.6358 - val_phi2_loss: 0.1888 - val_phi2_mae: 0.3356 - val_rho_loss: 0.0337 - val_rho_mae: 0.1620 - learning_rate: 2.5000e-04
# Epoch 52/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2738 - phase_accuracy: 0.9106 - phase_loss: 0.2230 - phi2_loss: 0.0759 - phi2_mae: 0.1967 - rho_loss: 0.0232 - rho_mae: 0.1184 - val_loss: 0.7440 - val_phase_accuracy: 0.7312 - val_phase_loss: 0.6331 - val_phi2_loss: 0.1803 - val_phi2_mae: 0.3194 - val_rho_loss: 0.0369 - val_rho_mae: 0.1712 - learning_rate: 2.5000e-04
# Epoch 53/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2729 - phase_accuracy: 0.9133 - phase_loss: 0.2227 - phi2_loss: 0.0763 - phi2_mae: 0.1975 - rho_loss: 0.0232 - rho_mae: 0.1184 - val_loss: 0.7346 - val_phase_accuracy: 0.7383 - val_phase_loss: 0.6095 - val_phi2_loss: 0.2142 - val_phi2_mae: 0.3597 - val_rho_loss: 0.0317 - val_rho_mae: 0.1541 - learning_rate: 2.5000e-04
# Epoch 54/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2725 - phase_accuracy: 0.9098 - phase_loss: 0.2226 - phi2_loss: 0.0765 - phi2_mae: 0.1979 - rho_loss: 0.0232 - rho_mae: 0.1191 - val_loss: 0.7577 - val_phase_accuracy: 0.7368 - val_phase_loss: 0.6280 - val_phi2_loss: 0.2192 - val_phi2_mae: 0.3707 - val_rho_loss: 0.0357 - val_rho_mae: 0.1692 - learning_rate: 1.2500e-04
# Epoch 55/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2711 - phase_accuracy: 0.9116 - phase_loss: 0.2211 - phi2_loss: 0.0754 - phi2_mae: 0.1965 - rho_loss: 0.0230 - rho_mae: 0.1178 - val_loss: 0.7271 - val_phase_accuracy: 0.7440 - val_phase_loss: 0.6082 - val_phi2_loss: 0.1970 - val_phi2_mae: 0.3442 - val_rho_loss: 0.0363 - val_rho_mae: 0.1724 - learning_rate: 1.2500e-04
# Epoch 56/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2699 - phase_accuracy: 0.9111 - phase_loss: 0.2217 - phi2_loss: 0.0743 - phi2_mae: 0.1947 - rho_loss: 0.0226 - rho_mae: 0.1171 - val_loss: 0.7486 - val_phase_accuracy: 0.7326 - val_phase_loss: 0.6306 - val_phi2_loss: 0.1968 - val_phi2_mae: 0.3415 - val_rho_loss: 0.0346 - val_rho_mae: 0.1631 - learning_rate: 1.2500e-04
# Epoch 57/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2694 - phase_accuracy: 0.9123 - phase_loss: 0.2216 - phi2_loss: 0.0739 - phi2_mae: 0.1942 - rho_loss: 0.0224 - rho_mae: 0.1160 - val_loss: 0.7468 - val_phase_accuracy: 0.7340 - val_phase_loss: 0.6309 - val_phi2_loss: 0.1911 - val_phi2_mae: 0.3419 - val_rho_loss: 0.0359 - val_rho_mae: 0.1704 - learning_rate: 1.2500e-04
# Epoch 58/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2684 - phase_accuracy: 0.9131 - phase_loss: 0.2188 - phi2_loss: 0.0727 - phi2_mae: 0.1931 - rho_loss: 0.0225 - rho_mae: 0.1169 - val_loss: 0.7311 - val_phase_accuracy: 0.7411 - val_phase_loss: 0.6152 - val_phi2_loss: 0.1922 - val_phi2_mae: 0.3380 - val_rho_loss: 0.0348 - val_rho_mae: 0.1658 - learning_rate: 1.2500e-04
# Epoch 59/200
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2680 - phase_accuracy: 0.9121 - phase_loss: 0.2200 - phi2_loss: 0.0727 - phi2_mae: 0.1928 - rho_loss: 0.0223 - rho_mae: 0.1161 - val_loss: 0.7386 - val_phase_accuracy: 0.7340 - val_phase_loss: 0.6181 - val_phi2_loss: 0.2021 - val_phi2_mae: 0.3490 - val_rho_loss: 0.0343 - val_rho_mae: 0.1651 - learning_rate: 1.2500e-04
# 📊 Classification Report (Phase):
#               precision    recall  f1-score   support
#
#            0     0.9163    0.7775    0.8412      2000
#            1     0.8510    0.9471    0.8965      2684
#
#     accuracy                         0.8747      4684
#    macro avg     0.8837    0.8623    0.8689      4684
# weighted avg     0.8789    0.8747    0.8729      4684
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23660\1202470403.py:138: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_labels = df["Phase"].astype(int).ravel()

# %% [markdown]
# ## 4k extra

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVCimport numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(2000, len(df_MI))
n_SF = min(2000, len(df_SF))
n_boundary = min(4000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('4k-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))


from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import kerasimport numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
# Smart sampling strategy
# ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# n_MI = min(5000, len(df_MI))
# n_SF = min(5000, len(df_SF))
# n_boundary = min(10000, len(df_boundary))

n_MI = min(2000, len(df_MI))
n_SF = min(2000, len(df_SF))
n_boundary = min(4000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()

# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 40, 200)
mu_vals = np.linspace(0, 70, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title(f"Phase Diagram for Multi-task NN",fontsize=12, fontweight="bold")
plt.savefig('4k-extra-multi-nn', dpi=300, bbox_inches='tight')
plt.grid(True)
plt.show()

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))


from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
#Smart sampling strategy
#------------------------------
n_MI = min(2000, len(df_MI))             # cap deep MI
n_SF = min(2000, len(df_SF))             # cap deep SF
n_boundary = min(6000, len(df_boundary)) # oversample boundary

# # n_MI = min(5000, len(df_MI))
# # n_SF = min(5000, len(df_SF))
# # n_boundary = min(10000, len(df_boundary))

# n_MI = min(3000, len(df_MI))
# n_SF = min(3000, len(df_SF))
# n_boundary = min(6000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()
# Out:
#   Cell In[2], line 9
#     from sklearn.svm import SVCimport numpy as np
#                                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 10k dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superfluid

        
# # ---------- 1) Load and label ----------
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Label: 1 = Superfluid, 0 = Mott
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )


# # Apply physics-based labeling
# df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # Features and target: **only** Ubar, Mubar
# X = df[["Ubar", "Mubar"]].copy()
# y = df["Phase"].copy()

# # Train/test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y,
#     test_size=0.25, random_state=42,
#     stratify=y
# )

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)




# --- pick deep MI (phi2 ≈ 0, density ~ integer) ---



df_MI = df[
    (df["Phi2"] < 1e-8) &
    (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
]

# --- pick deep SF (large phi2) ---
df_SF = df[df["Phi2"] > 1e-2]

# --- pick boundary (ambiguous region) ---
df_boundary = df[
    (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
]

# ------------------------------
#Smart sampling strategy
#------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

n_MI = min(5000, len(df_MI))
n_SF = min(5000, len(df_SF))
n_boundary = min(10000, len(df_boundary))

# n_MI = min(3000, len(df_MI))
# n_SF = min(3000, len(df_SF))
# n_boundary = min(6000, len(df_boundary))


df_reduced = pd.concat([
    df_MI.sample(n_MI, random_state=42),
    df_SF.sample(n_SF, random_state=42),
    df_boundary.sample(n_boundary, random_state=42)
])
print(df)
df_reduced = df_reduced.reset_index(drop=True)
# Use reduced dataset
df = df_reduced.reset_index(drop=True)
print(df)


print("Reduced dataset summary:")
print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()
# Out:
#           t  Ubar  Mubar       Density          Phi2        Energy  Iters  \
# 0       1.0   0.0   -5.0  1.048576e-14  1.048576e-14  2.097152e-13      8
# 1       1.0   0.0   -4.9  1.508449e-14  1.508449e-14  2.882646e-13      8
# 2       1.0   0.0   -4.8  2.186340e-14  2.186340e-14  3.987884e-13      8
# 3       1.0   0.0   -4.7  3.193733e-14  3.193733e-14  5.553901e-13      8
# 4       1.0   0.0   -4.6  4.703477e-14  4.703477e-14  7.788958e-13      8
# ...     ...   ...    ...           ...           ...           ...    ...
# 163396  1.0  25.0   59.6  3.000000e+00  8.530376e-13 -1.038000e+02     21
# 163397  1.0  25.0   59.7  3.000000e+00  7.586920e-13 -1.041000e+02     21
# 163398  1.0  25.0   59.8  3.000000e+00  6.791729e-13 -1.044000e+02     21
# 163399  1.0  25.0   59.9  3.000000e+00  6.119027e-13 -1.047000e+02     21
# 163400  1.0  25.0   60.0  3.000000e+00  5.548081e-13 -1.050000e+02     21
#
#         Phase
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 163396      0
# 163397      0
# 163398      0
# 163399      0
# 163400      0
#
# [163401 rows x 8 columns]
#          t  Ubar  Mubar       Density          Phi2        Energy  Iters  \
# 0      1.0  24.4   13.4  1.000000e+00  6.034134e-14 -1.340000e+01      9
# 1      1.0  16.0   -1.1  8.624612e-11  8.624612e-11  9.487073e-12    101
# 2      1.0  22.4    6.0  1.000000e+00  5.328648e-14 -6.000000e+00     10
# 3      1.0  14.2   22.4  2.000000e+00  6.649626e-12 -3.060000e+01     37
# 4      1.0  22.0    7.5  1.000000e+00  1.363996e-14 -7.500000e+00     10
# ...    ...   ...    ...           ...           ...           ...    ...
# 10679  1.0   3.6   -1.0  8.456767e-05  8.456471e-05  4.598585e-09   4589
# 10680  1.0   5.3   26.2  4.999955e+00  2.254263e-04 -7.800000e+01   7465
# 10681  1.0  10.9   17.5  2.000244e+00  2.100670e-03 -2.410000e+01   2451
# 10682  1.0  16.3   -1.0  6.803388e-05  6.803021e-05  4.123775e-09   4118
# 10683  1.0   5.1   25.4  4.999955e+00  2.261209e-04 -7.600000e+01   7477
#
#        Phase
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 10679      1
# 10680      1
# 10681      1
# 10682      1
# 10683      1
#
# [10684 rows x 8 columns]
# Reduced dataset summary:
# Phase
# 1    5684
# 0    5000
# Name: count, dtype: int64

# %%
# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# --- 2) Build Multi-task NN ---
def make_multitask_nn(hidden=(128,64)):
    inp = keras.Input(shape=(2,), name="input")   # (Ū, μ̄)

    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)

    # Three heads
    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="linear", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="linear", name="rho")(x)

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out])

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss={
            "phase": "binary_crossentropy",
            "phi2": "mse",
            "rho": "mse"
        },
        loss_weights={"phase": 1.0, "phi2": 0.5, "rho": 0.5},
        metrics={"phase": "accuracy", "phi2": "mae", "rho": "mae"}
    )
    return model

multi_model = make_multitask_nn()
# --- 4) Train PINN ---
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1).astype(np.float32),
    "phi2":  df["Phi2"].values.reshape(-1,1).astype(np.float32),
    "rho":   df["Density"].values.reshape(-1,1).astype(np.float32)
}


# --- 3) Train ---
history = multi_model.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
    ],
    verbose=1
)

# --- 4) Predict on grid ---
U_vals = np.linspace(0, 25, 200)
mu_vals = np.linspace(0, 60, 200)
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

y_pred_grid = multi_model.predict(X_grid, verbose=0)
phase_pred, phi2_pred, rho_pred = y_pred_grid

phase_pred = phase_pred.reshape(UU.shape)
phi2_pred  = phi2_pred.reshape(UU.shape)
rho_pred   = rho_pred.reshape(UU.shape)
phase_pred_class = (phase_pred > 0.5).astype(int)

# --- 5) Plot results ---
plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
mappable = plt.contourf(UU, MU, phase_pred_class,
                        levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase")
plt.contour(UU, MU, phase_pred, levels=[0.5], colors="k", linewidths=1.2)
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Phase Diagram")

plt.subplot(1,3,2)
mappable = plt.contourf(UU, MU, phi2_pred, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Condensate fraction φ²")

plt.subplot(1,3,3)
mappable = plt.contourf(UU, MU, rho_pred, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Density ρ")

plt.tight_layout(); plt.show()

# Ground truth


# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()


# --- 6) Classification report on training data ---
from sklearn.metrics import classification_report
y_pred_phase, _, _ = multi_model.predict(X, verbose=0)
y_pred_labels = (y_pred_phase > 0.5).astype(int).ravel()
y_true_labels = df["Phase"].astype(int).ravel()

print("\n📊 Classification Report (Phase):")
print(classification_report(y_true_labels, y_pred_labels, digits=4))
# Out:
# Epoch 1/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.0857 - phase_accuracy: 0.5919 - phase_loss: 0.8525 - phi2_loss: 3.9972 - phi2_mae: 1.4909 - rho_loss: 6.3315 - rho_mae: 1.6953 - val_loss: 1.7607 - val_phase_accuracy: 0.6781 - val_phase_loss: 0.8195 - val_phi2_loss: 0.5089 - val_phi2_mae: 0.5471 - val_rho_loss: 1.4014 - val_rho_mae: 0.8392 - learning_rate: 0.0010
# Epoch 2/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4211 - phase_accuracy: 0.7143 - phase_loss: 0.5636 - phi2_loss: 0.4977 - phi2_mae: 0.5020 - rho_loss: 1.2137 - rho_mae: 0.7877 - val_loss: 1.7536 - val_phase_accuracy: 0.4629 - val_phase_loss: 0.9234 - val_phi2_loss: 0.4231 - val_phi2_mae: 0.4631 - val_rho_loss: 1.2519 - val_rho_mae: 0.7835 - learning_rate: 0.0010
# Epoch 3/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2795 - phase_accuracy: 0.7445 - phase_loss: 0.5263 - phi2_loss: 0.4231 - phi2_mae: 0.4308 - rho_loss: 1.0877 - rho_mae: 0.7275 - val_loss: 1.6711 - val_phase_accuracy: 0.4523 - val_phase_loss: 0.8803 - val_phi2_loss: 0.4223 - val_phi2_mae: 0.4631 - val_rho_loss: 1.1617 - val_rho_mae: 0.7414 - learning_rate: 0.0010
# Epoch 4/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2012 - phase_accuracy: 0.7859 - phase_loss: 0.4999 - phi2_loss: 0.4047 - phi2_mae: 0.4172 - rho_loss: 0.9966 - rho_mae: 0.6924 - val_loss: 1.5110 - val_phase_accuracy: 0.5090 - val_phase_loss: 0.7706 - val_phi2_loss: 0.4124 - val_phi2_mae: 0.4567 - val_rho_loss: 1.0725 - val_rho_mae: 0.7117 - learning_rate: 0.0010
# Epoch 5/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1303 - phase_accuracy: 0.7923 - phase_loss: 0.4780 - phi2_loss: 0.3952 - phi2_mae: 0.4079 - rho_loss: 0.9078 - rho_mae: 0.6570 - val_loss: 1.4900 - val_phase_accuracy: 0.4959 - val_phase_loss: 0.8126 - val_phi2_loss: 0.4047 - val_phi2_mae: 0.4628 - val_rho_loss: 0.9677 - val_rho_mae: 0.6670 - learning_rate: 0.0010
# Epoch 6/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0650 - phase_accuracy: 0.8105 - phase_loss: 0.4567 - phi2_loss: 0.3885 - phi2_mae: 0.4038 - rho_loss: 0.8277 - rho_mae: 0.6219 - val_loss: 1.4170 - val_phase_accuracy: 0.4648 - val_phase_loss: 0.7870 - val_phi2_loss: 0.3951 - val_phi2_mae: 0.4571 - val_rho_loss: 0.8736 - val_rho_mae: 0.6319 - learning_rate: 0.0010
# Epoch 7/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9692 - phase_accuracy: 0.8361 - phase_loss: 0.4375 - phi2_loss: 0.3598 - phi2_mae: 0.3991 - rho_loss: 0.7022 - rho_mae: 0.5668 - val_loss: 1.2814 - val_phase_accuracy: 0.4891 - val_phase_loss: 0.7732 - val_phi2_loss: 0.3534 - val_phi2_mae: 0.4501 - val_rho_loss: 0.6861 - val_rho_mae: 0.5491 - learning_rate: 0.0010
# Epoch 8/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8405 - phase_accuracy: 0.8534 - phase_loss: 0.4152 - phi2_loss: 0.3185 - phi2_mae: 0.3827 - rho_loss: 0.5307 - rho_mae: 0.4831 - val_loss: 1.1344 - val_phase_accuracy: 0.5652 - val_phase_loss: 0.7323 - val_phi2_loss: 0.3311 - val_phi2_mae: 0.4472 - val_rho_loss: 0.5086 - val_rho_mae: 0.4657 - learning_rate: 0.0010
# Epoch 9/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7062 - phase_accuracy: 0.8670 - phase_loss: 0.3919 - phi2_loss: 0.2748 - phi2_mae: 0.3719 - rho_loss: 0.3551 - rho_mae: 0.3974 - val_loss: 0.8756 - val_phase_accuracy: 0.7299 - val_phase_loss: 0.5744 - val_phi2_loss: 0.2918 - val_phi2_mae: 0.4404 - val_rho_loss: 0.3401 - val_rho_mae: 0.3965 - learning_rate: 0.0010
# Epoch 10/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5916 - phase_accuracy: 0.8729 - phase_loss: 0.3692 - phi2_loss: 0.2310 - phi2_mae: 0.3599 - rho_loss: 0.2127 - rho_mae: 0.3215 - val_loss: 0.9613 - val_phase_accuracy: 0.5434 - val_phase_loss: 0.7396 - val_phi2_loss: 0.2630 - val_phi2_mae: 0.4194 - val_rho_loss: 0.2290 - val_rho_mae: 0.3493 - learning_rate: 0.0010
# Epoch 11/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5202 - phase_accuracy: 0.8687 - phase_loss: 0.3480 - phi2_loss: 0.2072 - phi2_mae: 0.3511 - rho_loss: 0.1381 - rho_mae: 0.2729 - val_loss: 0.7765 - val_phase_accuracy: 0.6925 - val_phase_loss: 0.5951 - val_phi2_loss: 0.2607 - val_phi2_mae: 0.4140 - val_rho_loss: 0.1562 - val_rho_mae: 0.2991 - learning_rate: 0.0010
# Epoch 12/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4743 - phase_accuracy: 0.8655 - phase_loss: 0.3294 - phi2_loss: 0.1924 - phi2_mae: 0.3443 - rho_loss: 0.0962 - rho_mae: 0.2388 - val_loss: 0.6590 - val_phase_accuracy: 0.7860 - val_phase_loss: 0.4815 - val_phi2_loss: 0.2770 - val_phi2_mae: 0.4276 - val_rho_loss: 0.1253 - val_rho_mae: 0.2796 - learning_rate: 0.0010
# Epoch 13/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4433 - phase_accuracy: 0.8680 - phase_loss: 0.3154 - phi2_loss: 0.1836 - phi2_mae: 0.3384 - rho_loss: 0.0725 - rho_mae: 0.2111 - val_loss: 0.6488 - val_phase_accuracy: 0.7467 - val_phase_loss: 0.4995 - val_phi2_loss: 0.2456 - val_phi2_mae: 0.3983 - val_rho_loss: 0.1017 - val_rho_mae: 0.2705 - learning_rate: 0.0010
# Epoch 14/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4142 - phase_accuracy: 0.8692 - phase_loss: 0.3019 - phi2_loss: 0.1752 - phi2_mae: 0.3279 - rho_loss: 0.0501 - rho_mae: 0.1758 - val_loss: 0.5646 - val_phase_accuracy: 0.8284 - val_phase_loss: 0.4380 - val_phi2_loss: 0.2357 - val_phi2_mae: 0.3829 - val_rho_loss: 0.0609 - val_rho_mae: 0.1925 - learning_rate: 0.0010
# Epoch 15/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3877 - phase_accuracy: 0.8736 - phase_loss: 0.2901 - phi2_loss: 0.1624 - phi2_mae: 0.3182 - rho_loss: 0.0322 - rho_mae: 0.1396 - val_loss: 0.6784 - val_phase_accuracy: 0.6606 - val_phase_loss: 0.5730 - val_phi2_loss: 0.2247 - val_phi2_mae: 0.3643 - val_rho_loss: 0.0480 - val_rho_mae: 0.1707 - learning_rate: 0.0010
# Epoch 16/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3667 - phase_accuracy: 0.8753 - phase_loss: 0.2787 - phi2_loss: 0.1507 - phi2_mae: 0.3042 - rho_loss: 0.0262 - rho_mae: 0.1248 - val_loss: 0.5058 - val_phase_accuracy: 0.8372 - val_phase_loss: 0.3964 - val_phi2_loss: 0.2291 - val_phi2_mae: 0.3589 - val_rho_loss: 0.0373 - val_rho_mae: 0.1502 - learning_rate: 0.0010
# Epoch 17/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3542 - phase_accuracy: 0.8799 - phase_loss: 0.2725 - phi2_loss: 0.1429 - phi2_mae: 0.2947 - rho_loss: 0.0236 - rho_mae: 0.1183 - val_loss: 0.6064 - val_phase_accuracy: 0.7336 - val_phase_loss: 0.5269 - val_phi2_loss: 0.1874 - val_phi2_mae: 0.3332 - val_rho_loss: 0.0422 - val_rho_mae: 0.1598 - learning_rate: 0.0010
# Epoch 18/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3307 - phase_accuracy: 0.8851 - phase_loss: 0.2592 - phi2_loss: 0.1204 - phi2_mae: 0.2671 - rho_loss: 0.0215 - rho_mae: 0.1117 - val_loss: 0.5559 - val_phase_accuracy: 0.7823 - val_phase_loss: 0.4712 - val_phi2_loss: 0.1749 - val_phi2_mae: 0.3165 - val_rho_loss: 0.0419 - val_rho_mae: 0.1607 - learning_rate: 0.0010
# Epoch 19/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3115 - phase_accuracy: 0.8908 - phase_loss: 0.2497 - phi2_loss: 0.1039 - phi2_mae: 0.2430 - rho_loss: 0.0197 - rho_mae: 0.1072 - val_loss: 0.5625 - val_phase_accuracy: 0.7043 - val_phase_loss: 0.4840 - val_phi2_loss: 0.1869 - val_phi2_mae: 0.3208 - val_rho_loss: 0.0242 - val_rho_mae: 0.1173 - learning_rate: 0.0010
# Epoch 20/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2996 - phase_accuracy: 0.8908 - phase_loss: 0.2418 - phi2_loss: 0.0958 - phi2_mae: 0.2300 - rho_loss: 0.0186 - rho_mae: 0.1042 - val_loss: 0.5570 - val_phase_accuracy: 0.7336 - val_phase_loss: 0.4864 - val_phi2_loss: 0.1820 - val_phi2_mae: 0.3211 - val_rho_loss: 0.0296 - val_rho_mae: 0.1293 - learning_rate: 0.0010
# Epoch 21/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2848 - phase_accuracy: 0.8973 - phase_loss: 0.2348 - phi2_loss: 0.0812 - phi2_mae: 0.2095 - rho_loss: 0.0170 - rho_mae: 0.0979 - val_loss: 0.4654 - val_phase_accuracy: 0.8272 - val_phase_loss: 0.4068 - val_phi2_loss: 0.1444 - val_phi2_mae: 0.2851 - val_rho_loss: 0.0238 - val_rho_mae: 0.1138 - learning_rate: 0.0010
# Epoch 22/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2766 - phase_accuracy: 0.8994 - phase_loss: 0.2303 - phi2_loss: 0.0762 - phi2_mae: 0.2031 - rho_loss: 0.0163 - rho_mae: 0.0960 - val_loss: 0.5005 - val_phase_accuracy: 0.7692 - val_phase_loss: 0.4500 - val_phi2_loss: 0.1335 - val_phi2_mae: 0.2772 - val_rho_loss: 0.0251 - val_rho_mae: 0.1219 - learning_rate: 0.0010
# Epoch 23/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2662 - phase_accuracy: 0.9021 - phase_loss: 0.2229 - phi2_loss: 0.0701 - phi2_mae: 0.1926 - rho_loss: 0.0160 - rho_mae: 0.0949 - val_loss: 0.5287 - val_phase_accuracy: 0.7087 - val_phase_loss: 0.4800 - val_phi2_loss: 0.1341 - val_phi2_mae: 0.2734 - val_rho_loss: 0.0247 - val_rho_mae: 0.1191 - learning_rate: 0.0010
# Epoch 24/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2592 - phase_accuracy: 0.9052 - phase_loss: 0.2189 - phi2_loss: 0.0649 - phi2_mae: 0.1842 - rho_loss: 0.0170 - rho_mae: 0.0996 - val_loss: 0.5559 - val_phase_accuracy: 0.6900 - val_phase_loss: 0.5186 - val_phi2_loss: 0.1318 - val_phi2_mae: 0.2761 - val_rho_loss: 0.0205 - val_rho_mae: 0.1082 - learning_rate: 0.0010
# Epoch 25/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2527 - phase_accuracy: 0.9110 - phase_loss: 0.2127 - phi2_loss: 0.0632 - phi2_mae: 0.1807 - rho_loss: 0.0163 - rho_mae: 0.0975 - val_loss: 0.4447 - val_phase_accuracy: 0.8172 - val_phase_loss: 0.4046 - val_phi2_loss: 0.1067 - val_phi2_mae: 0.2463 - val_rho_loss: 0.0234 - val_rho_mae: 0.1159 - learning_rate: 0.0010
# Epoch 26/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2471 - phase_accuracy: 0.9072 - phase_loss: 0.2098 - phi2_loss: 0.0608 - phi2_mae: 0.1761 - rho_loss: 0.0141 - rho_mae: 0.0910 - val_loss: 0.6427 - val_phase_accuracy: 0.6326 - val_phase_loss: 0.6231 - val_phi2_loss: 0.1042 - val_phi2_mae: 0.2473 - val_rho_loss: 0.0230 - val_rho_mae: 0.1103 - learning_rate: 0.0010
# Epoch 27/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2436 - phase_accuracy: 0.9139 - phase_loss: 0.2045 - phi2_loss: 0.0640 - phi2_mae: 0.1830 - rho_loss: 0.0151 - rho_mae: 0.0946 - val_loss: 0.4269 - val_phase_accuracy: 0.8284 - val_phase_loss: 0.3743 - val_phi2_loss: 0.1353 - val_phi2_mae: 0.2823 - val_rho_loss: 0.0203 - val_rho_mae: 0.1086 - learning_rate: 0.0010
# Epoch 28/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2369 - phase_accuracy: 0.9162 - phase_loss: 0.1990 - phi2_loss: 0.0620 - phi2_mae: 0.1800 - rho_loss: 0.0138 - rho_mae: 0.0912 - val_loss: 0.4258 - val_phase_accuracy: 0.7873 - val_phase_loss: 0.3890 - val_phi2_loss: 0.1116 - val_phi2_mae: 0.2636 - val_rho_loss: 0.0207 - val_rho_mae: 0.1060 - learning_rate: 0.0010
# Epoch 29/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2307 - phase_accuracy: 0.9181 - phase_loss: 0.1940 - phi2_loss: 0.0574 - phi2_mae: 0.1725 - rho_loss: 0.0147 - rho_mae: 0.0932 - val_loss: 0.6023 - val_phase_accuracy: 0.6962 - val_phase_loss: 0.5921 - val_phi2_loss: 0.0957 - val_phi2_mae: 0.2354 - val_rho_loss: 0.0227 - val_rho_mae: 0.1088 - learning_rate: 0.0010
# Epoch 30/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2236 - phase_accuracy: 0.9216 - phase_loss: 0.1911 - phi2_loss: 0.0526 - phi2_mae: 0.1632 - rho_loss: 0.0134 - rho_mae: 0.0901 - val_loss: 0.4409 - val_phase_accuracy: 0.7617 - val_phase_loss: 0.4130 - val_phi2_loss: 0.0897 - val_phi2_mae: 0.2321 - val_rho_loss: 0.0210 - val_rho_mae: 0.1086 - learning_rate: 0.0010
# Epoch 31/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2197 - phase_accuracy: 0.9238 - phase_loss: 0.1870 - phi2_loss: 0.0528 - phi2_mae: 0.1638 - rho_loss: 0.0130 - rho_mae: 0.0884 - val_loss: 0.5324 - val_phase_accuracy: 0.6563 - val_phase_loss: 0.5117 - val_phi2_loss: 0.0955 - val_phi2_mae: 0.2388 - val_rho_loss: 0.0198 - val_rho_mae: 0.1072 - learning_rate: 0.0010
# Epoch 32/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2159 - phase_accuracy: 0.9228 - phase_loss: 0.1833 - phi2_loss: 0.0504 - phi2_mae: 0.1617 - rho_loss: 0.0131 - rho_mae: 0.0891 - val_loss: 0.5190 - val_phase_accuracy: 0.6606 - val_phase_loss: 0.4975 - val_phi2_loss: 0.0920 - val_phi2_mae: 0.2283 - val_rho_loss: 0.0221 - val_rho_mae: 0.1141 - learning_rate: 0.0010
# Epoch 33/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2150 - phase_accuracy: 0.9269 - phase_loss: 0.1814 - phi2_loss: 0.0526 - phi2_mae: 0.1661 - rho_loss: 0.0145 - rho_mae: 0.0921 - val_loss: 0.5097 - val_phase_accuracy: 0.6887 - val_phase_loss: 0.4901 - val_phi2_loss: 0.0821 - val_phi2_mae: 0.2195 - val_rho_loss: 0.0214 - val_rho_mae: 0.1143 - learning_rate: 0.0010
# Epoch 34/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2069 - phase_accuracy: 0.9315 - phase_loss: 0.1743 - phi2_loss: 0.0512 - phi2_mae: 0.1603 - rho_loss: 0.0132 - rho_mae: 0.0898 - val_loss: 0.3864 - val_phase_accuracy: 0.8391 - val_phase_loss: 0.3635 - val_phi2_loss: 0.0799 - val_phi2_mae: 0.2187 - val_rho_loss: 0.0194 - val_rho_mae: 0.1056 - learning_rate: 0.0010
# Epoch 35/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2000 - phase_accuracy: 0.9329 - phase_loss: 0.1695 - phi2_loss: 0.0471 - phi2_mae: 0.1535 - rho_loss: 0.0123 - rho_mae: 0.0864 - val_loss: 0.3772 - val_phase_accuracy: 0.8883 - val_phase_loss: 0.3347 - val_phi2_loss: 0.1164 - val_phi2_mae: 0.2537 - val_rho_loss: 0.0202 - val_rho_mae: 0.1103 - learning_rate: 0.0010
# Epoch 36/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1963 - phase_accuracy: 0.9338 - phase_loss: 0.1672 - phi2_loss: 0.0474 - phi2_mae: 0.1539 - rho_loss: 0.0126 - rho_mae: 0.0869 - val_loss: 0.5512 - val_phase_accuracy: 0.6737 - val_phase_loss: 0.5396 - val_phi2_loss: 0.0911 - val_phi2_mae: 0.2282 - val_rho_loss: 0.0206 - val_rho_mae: 0.1067 - learning_rate: 0.0010
# Epoch 37/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1934 - phase_accuracy: 0.9350 - phase_loss: 0.1636 - phi2_loss: 0.0463 - phi2_mae: 0.1517 - rho_loss: 0.0119 - rho_mae: 0.0849 - val_loss: 0.3828 - val_phase_accuracy: 0.8478 - val_phase_loss: 0.3575 - val_phi2_loss: 0.0898 - val_phi2_mae: 0.2260 - val_rho_loss: 0.0201 - val_rho_mae: 0.1082 - learning_rate: 0.0010
# Epoch 38/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1897 - phase_accuracy: 0.9381 - phase_loss: 0.1601 - phi2_loss: 0.0469 - phi2_mae: 0.1533 - rho_loss: 0.0123 - rho_mae: 0.0864 - val_loss: 0.4090 - val_phase_accuracy: 0.8440 - val_phase_loss: 0.3695 - val_phi2_loss: 0.1259 - val_phi2_mae: 0.2647 - val_rho_loss: 0.0180 - val_rho_mae: 0.0997 - learning_rate: 0.0010
# Epoch 39/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1859 - phase_accuracy: 0.9413 - phase_loss: 0.1568 - phi2_loss: 0.0466 - phi2_mae: 0.1529 - rho_loss: 0.0120 - rho_mae: 0.0852 - val_loss: 0.4737 - val_phase_accuracy: 0.6781 - val_phase_loss: 0.4624 - val_phi2_loss: 0.0811 - val_phi2_mae: 0.2163 - val_rho_loss: 0.0192 - val_rho_mae: 0.1034 - learning_rate: 0.0010
# Epoch 40/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1823 - phase_accuracy: 0.9424 - phase_loss: 0.1526 - phi2_loss: 0.0466 - phi2_mae: 0.1537 - rho_loss: 0.0122 - rho_mae: 0.0859 - val_loss: 0.5002 - val_phase_accuracy: 0.6706 - val_phase_loss: 0.4836 - val_phi2_loss: 0.1023 - val_phi2_mae: 0.2441 - val_rho_loss: 0.0176 - val_rho_mae: 0.0987 - learning_rate: 0.0010
# Epoch 41/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1774 - phase_accuracy: 0.9451 - phase_loss: 0.1492 - phi2_loss: 0.0447 - phi2_mae: 0.1483 - rho_loss: 0.0121 - rho_mae: 0.0858 - val_loss: 0.4365 - val_phase_accuracy: 0.7561 - val_phase_loss: 0.4307 - val_phi2_loss: 0.0730 - val_phi2_mae: 0.2071 - val_rho_loss: 0.0205 - val_rho_mae: 0.0991 - learning_rate: 0.0010
# Epoch 42/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1766 - phase_accuracy: 0.9465 - phase_loss: 0.1460 - phi2_loss: 0.0484 - phi2_mae: 0.1579 - rho_loss: 0.0124 - rho_mae: 0.0864 - val_loss: 0.3685 - val_phase_accuracy: 0.8546 - val_phase_loss: 0.3364 - val_phi2_loss: 0.1008 - val_phi2_mae: 0.2340 - val_rho_loss: 0.0202 - val_rho_mae: 0.1111 - learning_rate: 0.0010
# Epoch 43/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1714 - phase_accuracy: 0.9486 - phase_loss: 0.1426 - phi2_loss: 0.0456 - phi2_mae: 0.1542 - rho_loss: 0.0119 - rho_mae: 0.0853 - val_loss: 0.5523 - val_phase_accuracy: 0.6931 - val_phase_loss: 0.5479 - val_phi2_loss: 0.0895 - val_phi2_mae: 0.2251 - val_rho_loss: 0.0184 - val_rho_mae: 0.1056 - learning_rate: 0.0010
# Epoch 44/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1682 - phase_accuracy: 0.9501 - phase_loss: 0.1398 - phi2_loss: 0.0449 - phi2_mae: 0.1505 - rho_loss: 0.0114 - rho_mae: 0.0832 - val_loss: 0.4024 - val_phase_accuracy: 0.7879 - val_phase_loss: 0.3818 - val_phi2_loss: 0.0928 - val_phi2_mae: 0.2299 - val_rho_loss: 0.0168 - val_rho_mae: 0.0972 - learning_rate: 0.0010
# Epoch 45/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1647 - phase_accuracy: 0.9542 - phase_loss: 0.1368 - phi2_loss: 0.0448 - phi2_mae: 0.1515 - rho_loss: 0.0107 - rho_mae: 0.0801 - val_loss: 0.4315 - val_phase_accuracy: 0.7686 - val_phase_loss: 0.4179 - val_phi2_loss: 0.0766 - val_phi2_mae: 0.2195 - val_rho_loss: 0.0196 - val_rho_mae: 0.1096 - learning_rate: 0.0010
# Epoch 46/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1632 - phase_accuracy: 0.9550 - phase_loss: 0.1346 - phi2_loss: 0.0468 - phi2_mae: 0.1536 - rho_loss: 0.0110 - rho_mae: 0.0806 - val_loss: 0.4596 - val_phase_accuracy: 0.7580 - val_phase_loss: 0.4604 - val_phi2_loss: 0.0725 - val_phi2_mae: 0.2104 - val_rho_loss: 0.0160 - val_rho_mae: 0.0976 - learning_rate: 0.0010
# Epoch 47/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1570 - phase_accuracy: 0.9572 - phase_loss: 0.1313 - phi2_loss: 0.0394 - phi2_mae: 0.1401 - rho_loss: 0.0113 - rho_mae: 0.0818 - val_loss: 0.5477 - val_phase_accuracy: 0.6007 - val_phase_loss: 0.5415 - val_phi2_loss: 0.0885 - val_phi2_mae: 0.2218 - val_rho_loss: 0.0169 - val_rho_mae: 0.0989 - learning_rate: 0.0010
# Epoch 48/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1540 - phase_accuracy: 0.9557 - phase_loss: 0.1275 - phi2_loss: 0.0419 - phi2_mae: 0.1487 - rho_loss: 0.0107 - rho_mae: 0.0797 - val_loss: 0.3204 - val_phase_accuracy: 0.8927 - val_phase_loss: 0.3027 - val_phi2_loss: 0.0709 - val_phi2_mae: 0.1982 - val_rho_loss: 0.0170 - val_rho_mae: 0.1024 - learning_rate: 0.0010
# Epoch 49/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1495 - phase_accuracy: 0.9616 - phase_loss: 0.1247 - phi2_loss: 0.0381 - phi2_mae: 0.1380 - rho_loss: 0.0111 - rho_mae: 0.0812 - val_loss: 0.4803 - val_phase_accuracy: 0.7286 - val_phase_loss: 0.4594 - val_phi2_loss: 0.0994 - val_phi2_mae: 0.2319 - val_rho_loss: 0.0192 - val_rho_mae: 0.1083 - learning_rate: 0.0010
# Epoch 50/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1494 - phase_accuracy: 0.9616 - phase_loss: 0.1228 - phi2_loss: 0.0441 - phi2_mae: 0.1499 - rho_loss: 0.0105 - rho_mae: 0.0792 - val_loss: 0.4138 - val_phase_accuracy: 0.8029 - val_phase_loss: 0.4017 - val_phi2_loss: 0.0731 - val_phi2_mae: 0.2020 - val_rho_loss: 0.0190 - val_rho_mae: 0.1048 - learning_rate: 0.0010
# Epoch 51/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1455 - phase_accuracy: 0.9634 - phase_loss: 0.1185 - phi2_loss: 0.0439 - phi2_mae: 0.1489 - rho_loss: 0.0106 - rho_mae: 0.0799 - val_loss: 0.4342 - val_phase_accuracy: 0.7268 - val_phase_loss: 0.4275 - val_phi2_loss: 0.0773 - val_phi2_mae: 0.2171 - val_rho_loss: 0.0169 - val_rho_mae: 0.0981 - learning_rate: 0.0010
# Epoch 52/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1418 - phase_accuracy: 0.9627 - phase_loss: 0.1168 - phi2_loss: 0.0409 - phi2_mae: 0.1396 - rho_loss: 0.0096 - rho_mae: 0.0752 - val_loss: 0.4854 - val_phase_accuracy: 0.7049 - val_phase_loss: 0.4910 - val_phi2_loss: 0.0606 - val_phi2_mae: 0.1869 - val_rho_loss: 0.0205 - val_rho_mae: 0.1148 - learning_rate: 0.0010
# Epoch 53/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1435 - phase_accuracy: 0.9622 - phase_loss: 0.1157 - phi2_loss: 0.0432 - phi2_mae: 0.1494 - rho_loss: 0.0124 - rho_mae: 0.0866 - val_loss: 0.4356 - val_phase_accuracy: 0.7767 - val_phase_loss: 0.4288 - val_phi2_loss: 0.0701 - val_phi2_mae: 0.2091 - val_rho_loss: 0.0163 - val_rho_mae: 0.1005 - learning_rate: 0.0010
# Epoch 54/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1389 - phase_accuracy: 0.9632 - phase_loss: 0.1123 - phi2_loss: 0.0425 - phi2_mae: 0.1502 - rho_loss: 0.0099 - rho_mae: 0.0767 - val_loss: 0.4033 - val_phase_accuracy: 0.8384 - val_phase_loss: 0.3573 - val_phi2_loss: 0.1470 - val_phi2_mae: 0.2828 - val_rho_loss: 0.0148 - val_rho_mae: 0.0912 - learning_rate: 0.0010
# Epoch 55/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1331 - phase_accuracy: 0.9685 - phase_loss: 0.1079 - phi2_loss: 0.0395 - phi2_mae: 0.1413 - rho_loss: 0.0105 - rho_mae: 0.0795 - val_loss: 0.5066 - val_phase_accuracy: 0.7342 - val_phase_loss: 0.5198 - val_phi2_loss: 0.0674 - val_phi2_mae: 0.1901 - val_rho_loss: 0.0140 - val_rho_mae: 0.0931 - learning_rate: 0.0010
# Epoch 56/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1318 - phase_accuracy: 0.9703 - phase_loss: 0.1065 - phi2_loss: 0.0408 - phi2_mae: 0.1433 - rho_loss: 0.0095 - rho_mae: 0.0754 - val_loss: 0.4079 - val_phase_accuracy: 0.7817 - val_phase_loss: 0.4114 - val_phi2_loss: 0.0570 - val_phi2_mae: 0.1876 - val_rho_loss: 0.0149 - val_rho_mae: 0.0947 - learning_rate: 0.0010
# Epoch 57/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1271 - phase_accuracy: 0.9726 - phase_loss: 0.1042 - phi2_loss: 0.0380 - phi2_mae: 0.1386 - rho_loss: 0.0077 - rho_mae: 0.0679 - val_loss: 0.3708 - val_phase_accuracy: 0.7754 - val_phase_loss: 0.3620 - val_phi2_loss: 0.0817 - val_phi2_mae: 0.2079 - val_rho_loss: 0.0124 - val_rho_mae: 0.0840 - learning_rate: 5.0000e-04
# Epoch 58/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1231 - phase_accuracy: 0.9725 - phase_loss: 0.1015 - phi2_loss: 0.0341 - phi2_mae: 0.1265 - rho_loss: 0.0075 - rho_mae: 0.0660 - val_loss: 0.4394 - val_phase_accuracy: 0.6687 - val_phase_loss: 0.4455 - val_phi2_loss: 0.0609 - val_phi2_mae: 0.1814 - val_rho_loss: 0.0134 - val_rho_mae: 0.0899 - learning_rate: 5.0000e-04
# Epoch 59/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1220 - phase_accuracy: 0.9732 - phase_loss: 0.1013 - phi2_loss: 0.0347 - phi2_mae: 0.1288 - rho_loss: 0.0072 - rho_mae: 0.0646 - val_loss: 0.3638 - val_phase_accuracy: 0.7991 - val_phase_loss: 0.3599 - val_phi2_loss: 0.0684 - val_phi2_mae: 0.1919 - val_rho_loss: 0.0133 - val_rho_mae: 0.0846 - learning_rate: 5.0000e-04
# Epoch 60/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1202 - phase_accuracy: 0.9726 - phase_loss: 0.0997 - phi2_loss: 0.0335 - phi2_mae: 0.1245 - rho_loss: 0.0069 - rho_mae: 0.0632 - val_loss: 0.3670 - val_phase_accuracy: 0.8528 - val_phase_loss: 0.3657 - val_phi2_loss: 0.0600 - val_phi2_mae: 0.1893 - val_rho_loss: 0.0122 - val_rho_mae: 0.0832 - learning_rate: 5.0000e-04
# Epoch 61/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1190 - phase_accuracy: 0.9747 - phase_loss: 0.0983 - phi2_loss: 0.0341 - phi2_mae: 0.1272 - rho_loss: 0.0069 - rho_mae: 0.0637 - val_loss: 0.3990 - val_phase_accuracy: 0.7729 - val_phase_loss: 0.3941 - val_phi2_loss: 0.0784 - val_phi2_mae: 0.2133 - val_rho_loss: 0.0120 - val_rho_mae: 0.0793 - learning_rate: 5.0000e-04
# Epoch 62/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1177 - phase_accuracy: 0.9738 - phase_loss: 0.0971 - phi2_loss: 0.0333 - phi2_mae: 0.1235 - rho_loss: 0.0069 - rho_mae: 0.0630 - val_loss: 0.3578 - val_phase_accuracy: 0.8503 - val_phase_loss: 0.3430 - val_phi2_loss: 0.0904 - val_phi2_mae: 0.2256 - val_rho_loss: 0.0123 - val_rho_mae: 0.0851 - learning_rate: 5.0000e-04
# Epoch 63/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1170 - phase_accuracy: 0.9751 - phase_loss: 0.0962 - phi2_loss: 0.0353 - phi2_mae: 0.1317 - rho_loss: 0.0068 - rho_mae: 0.0626 - val_loss: 0.4721 - val_phase_accuracy: 0.6513 - val_phase_loss: 0.4762 - val_phi2_loss: 0.0722 - val_phi2_mae: 0.1991 - val_rho_loss: 0.0112 - val_rho_mae: 0.0782 - learning_rate: 5.0000e-04
# Epoch 64/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1154 - phase_accuracy: 0.9741 - phase_loss: 0.0950 - phi2_loss: 0.0338 - phi2_mae: 0.1258 - rho_loss: 0.0069 - rho_mae: 0.0630 - val_loss: 0.3921 - val_phase_accuracy: 0.7523 - val_phase_loss: 0.3934 - val_phi2_loss: 0.0675 - val_phi2_mae: 0.1993 - val_rho_loss: 0.0120 - val_rho_mae: 0.0842 - learning_rate: 5.0000e-04
# Epoch 65/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1126 - phase_accuracy: 0.9747 - phase_loss: 0.0935 - phi2_loss: 0.0317 - phi2_mae: 0.1196 - rho_loss: 0.0065 - rho_mae: 0.0609 - val_loss: 0.3776 - val_phase_accuracy: 0.7879 - val_phase_loss: 0.3772 - val_phi2_loss: 0.0644 - val_phi2_mae: 0.1860 - val_rho_loss: 0.0114 - val_rho_mae: 0.0803 - learning_rate: 2.5000e-04
# Epoch 66/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1112 - phase_accuracy: 0.9765 - phase_loss: 0.0920 - phi2_loss: 0.0314 - phi2_mae: 0.1200 - rho_loss: 0.0062 - rho_mae: 0.0592 - val_loss: 0.3635 - val_phase_accuracy: 0.8253 - val_phase_loss: 0.3661 - val_phi2_loss: 0.0571 - val_phi2_mae: 0.1752 - val_rho_loss: 0.0117 - val_rho_mae: 0.0840 - learning_rate: 2.5000e-04
# Epoch 67/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1108 - phase_accuracy: 0.9759 - phase_loss: 0.0919 - phi2_loss: 0.0314 - phi2_mae: 0.1201 - rho_loss: 0.0065 - rho_mae: 0.0609 - val_loss: 0.3852 - val_phase_accuracy: 0.7979 - val_phase_loss: 0.3868 - val_phi2_loss: 0.0558 - val_phi2_mae: 0.1782 - val_rho_loss: 0.0131 - val_rho_mae: 0.0832 - learning_rate: 2.5000e-04
# Epoch 68/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1102 - phase_accuracy: 0.9765 - phase_loss: 0.0918 - phi2_loss: 0.0309 - phi2_mae: 0.1165 - rho_loss: 0.0065 - rho_mae: 0.0604 - val_loss: 0.3753 - val_phase_accuracy: 0.8178 - val_phase_loss: 0.3724 - val_phi2_loss: 0.0699 - val_phi2_mae: 0.2039 - val_rho_loss: 0.0117 - val_rho_mae: 0.0783 - learning_rate: 2.5000e-04
# Epoch 69/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1087 - phase_accuracy: 0.9779 - phase_loss: 0.0906 - phi2_loss: 0.0307 - phi2_mae: 0.1171 - rho_loss: 0.0061 - rho_mae: 0.0581 - val_loss: 0.3837 - val_phase_accuracy: 0.8116 - val_phase_loss: 0.3846 - val_phi2_loss: 0.0603 - val_phi2_mae: 0.1861 - val_rho_loss: 0.0114 - val_rho_mae: 0.0820 - learning_rate: 2.5000e-04
# Epoch 70/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1079 - phase_accuracy: 0.9771 - phase_loss: 0.0899 - phi2_loss: 0.0300 - phi2_mae: 0.1158 - rho_loss: 0.0061 - rho_mae: 0.0584 - val_loss: 0.4234 - val_phase_accuracy: 0.7224 - val_phase_loss: 0.4289 - val_phi2_loss: 0.0610 - val_phi2_mae: 0.1897 - val_rho_loss: 0.0116 - val_rho_mae: 0.0826 - learning_rate: 2.5000e-04
# Epoch 71/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1075 - phase_accuracy: 0.9774 - phase_loss: 0.0894 - phi2_loss: 0.0298 - phi2_mae: 0.1146 - rho_loss: 0.0066 - rho_mae: 0.0612 - val_loss: 0.4279 - val_phase_accuracy: 0.6800 - val_phase_loss: 0.4370 - val_phi2_loss: 0.0572 - val_phi2_mae: 0.1793 - val_rho_loss: 0.0113 - val_rho_mae: 0.0797 - learning_rate: 2.5000e-04
# Epoch 72/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1063 - phase_accuracy: 0.9793 - phase_loss: 0.0885 - phi2_loss: 0.0295 - phi2_mae: 0.1133 - rho_loss: 0.0061 - rho_mae: 0.0582 - val_loss: 0.3540 - val_phase_accuracy: 0.8559 - val_phase_loss: 0.3532 - val_phi2_loss: 0.0589 - val_phi2_mae: 0.1832 - val_rho_loss: 0.0120 - val_rho_mae: 0.0847 - learning_rate: 2.5000e-04
# Epoch 73/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1055 - phase_accuracy: 0.9791 - phase_loss: 0.0876 - phi2_loss: 0.0294 - phi2_mae: 0.1123 - rho_loss: 0.0058 - rho_mae: 0.0565 - val_loss: 0.3623 - val_phase_accuracy: 0.8366 - val_phase_loss: 0.3602 - val_phi2_loss: 0.0640 - val_phi2_mae: 0.1906 - val_rho_loss: 0.0114 - val_rho_mae: 0.0815 - learning_rate: 1.2500e-04
# Epoch 74/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1058 - phase_accuracy: 0.9793 - phase_loss: 0.0882 - phi2_loss: 0.0296 - phi2_mae: 0.1131 - rho_loss: 0.0058 - rho_mae: 0.0563 - val_loss: 0.3770 - val_phase_accuracy: 0.8097 - val_phase_loss: 0.3803 - val_phi2_loss: 0.0574 - val_phi2_mae: 0.1806 - val_rho_loss: 0.0115 - val_rho_mae: 0.0810 - learning_rate: 1.2500e-04
# Epoch 75/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1052 - phase_accuracy: 0.9785 - phase_loss: 0.0880 - phi2_loss: 0.0294 - phi2_mae: 0.1123 - rho_loss: 0.0059 - rho_mae: 0.0567 - val_loss: 0.3561 - val_phase_accuracy: 0.8578 - val_phase_loss: 0.3561 - val_phi2_loss: 0.0606 - val_phi2_mae: 0.1845 - val_rho_loss: 0.0112 - val_rho_mae: 0.0810 - learning_rate: 1.2500e-04
# Epoch 76/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1043 - phase_accuracy: 0.9784 - phase_loss: 0.0873 - phi2_loss: 0.0294 - phi2_mae: 0.1131 - rho_loss: 0.0058 - rho_mae: 0.0559 - val_loss: 0.3897 - val_phase_accuracy: 0.7835 - val_phase_loss: 0.3947 - val_phi2_loss: 0.0549 - val_phi2_mae: 0.1761 - val_rho_loss: 0.0113 - val_rho_mae: 0.0814 - learning_rate: 1.2500e-04
# Epoch 77/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1048 - phase_accuracy: 0.9797 - phase_loss: 0.0873 - phi2_loss: 0.0293 - phi2_mae: 0.1135 - rho_loss: 0.0059 - rho_mae: 0.0574 - val_loss: 0.3557 - val_phase_accuracy: 0.8397 - val_phase_loss: 0.3542 - val_phi2_loss: 0.0638 - val_phi2_mae: 0.1873 - val_rho_loss: 0.0111 - val_rho_mae: 0.0798 - learning_rate: 1.2500e-04
# Epoch 78/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045 - phase_accuracy: 0.9793 - phase_loss: 0.0867 - phi2_loss: 0.0292 - phi2_mae: 0.1149 - rho_loss: 0.0059 - rho_mae: 0.0572 - val_loss: 0.4203 - val_phase_accuracy: 0.6850 - val_phase_loss: 0.4288 - val_phi2_loss: 0.0558 - val_phi2_mae: 0.1765 - val_rho_loss: 0.0111 - val_rho_mae: 0.0809 - learning_rate: 1.2500e-04
# 📊 Classification Report (Phase):
#               precision    recall  f1-score   support
#
#            0     0.9573    0.9362    0.9466      5000
#            1     0.9449    0.9632    0.9540      5684
#
#     accuracy                         0.9506     10684
#    macro avg     0.9511    0.9497    0.9503     10684
# weighted avg     0.9507    0.9506    0.9505     10684
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23660\1202470403.py:138: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_labels = df["Phase"].astype(int).ravel()
