# %%
# ====== Cluster Mean-Field Bose-Hubbard (2x2 plaquette) ======
# Working code, last touched on 22-Oct-2020

import numpy as np
import math
from math import sqrt, factorial
from scipy.sparse import coo_matrix, csr_matrix, eye
from scipy.sparse.linalg import eigsh   # iterative sparse eigensolver
from scipy.linalg import eigh           # dense solver (not really used here)

# >>> storage additions >>>
import csv
from pathlib import Path
from joblib import Parallel, delayed
import os

# <<< storage additions <<<

# --------------------------------------------------------------
# PRECOMPUTED SQUARE ROOTS OF PRIMES
# --------------------------------------------------------------
primesqt = np.array([
    1.41421356, 1.73205080, 2.23606797, 2.64575131, 3.31662479,
    3.60555127, 4.12310562, 4.35889894, 4.79583152, 5.38516480,
    5.56776436, 6.08276253, 6.40312423, 6.55743852, 6.85565460,
    7.28010988, 7.68114574, 7.81024967, 8.18535277, 8.42614977,
    8.54400374, 8.88819441, 9.11043357, 9.43398113, 9.84885780,
    10.04987562, 10.14889156, 10.34408043, 10.44030650, 10.63014581,
    11.26942766, 11.44552314, 11.70469991, 11.78982612, 12.20655561,
    12.28820572, 12.52996408, 12.76714533, 12.92284798, 13.15294643,
    13.37908816, 13.45362404, 13.82027496, 13.89244398, 14.03566884,
    14.10673597, 14.52583904, 14.93318452, 15.06651917, 15.13274595
])

# --------------------------------------------------------------
# PHYSICAL PARAMETERS
# --------------------------------------------------------------
tx = 1.0   # hopping in x
ty = 1.0   # hopping in y
# U  = 25.0  # on-site interaction strength

# Instead of fixed U, we define a sweep
U_min, U_max, dU = 0.0, 25.0, 1.0   # <-- choose your U range + step

# chemical potential scan
mu_min, mu_max, dmu = -5.0, 40.0, 0.2

# cluster geometry (2x2 plaquette)
xlen, ylen = 2, 2
m = xlen * ylen   # total number of sites = 4

nmax = 4          # maximum occupation per site

# Hilbert space dimension:
dim = (nmax+1)**m

def get_filename(tx, U_end, U_step, mu_end, mu_step, suffix):
    """
    Generate a compact filename for the 2x2 cluster results.
    Example:
    phase_tx1.0_U25.0-(1.0)_Mu40.0-(0.2).csv
    """
    return f"phase_tx{tx:.1f}_U{U_end:.1f}-({U_step})_Mu{mu_end:.1f}-({mu_step}){suffix}"

# --------------------------------------------------------------
# BASIS GENERATION
# --------------------------------------------------------------
def basis_gen(n, k, min_elem, max_elem):
    allowed = range(max_elem, min_elem-1, -1)
    def helper(n, k, t):
        if k == 0:
            if n == 0:
                yield t
        elif k == 1:
            if n in allowed:
                yield t + (n,)
        elif min_elem * k <= n <= max_elem * k:
            for v in allowed:
                yield from helper(n - v, k - 1, t + (v,))
    return helper(n, k, ())

# --------------------------------------------------------------
# Binary search lookup
# --------------------------------------------------------------
def BinarySearch(lys, val):  
    first, last, index = 0, len(lys)-1, -1
    while (first <= last) and (index == -1):
        mid = (first+last)//2
        if lys[mid] == val:
            index = mid
        elif val < lys[mid]:
            last = mid -1
        else:
            first = mid +1
    return index

# --------------------------------------------------------------
# LATTICE STRUCTURE: 2x2 PLAQUETTE
# --------------------------------------------------------------
lattice = np.zeros((ylen,xlen),int)
lat_ind = 0
for yy in range(ylen):
    for xx in range(xlen):
        lattice[yy][xx] = lat_ind
        lat_ind += 1

row_pair = []
for yy in range(ylen):
    for xx in range(xlen-1):
        row_pair.append([lattice[yy][xx], lattice[yy][xx+1]])

col_pair = []
for xx in range(xlen):
    for yy in range(ylen-1):
        col_pair.append([lattice[yy][xx], lattice[yy+1][xx]])

# --------------------------------------------------------------
# BOUNDARY SITES
# --------------------------------------------------------------
lbs = [xlen * x for x in range(0, ylen)]
rbs = [(xlen * (x+1))-1 for x in range(0, ylen)]
tbs = [x for x in range(lbs[0], rbs[0]+1)]
bbs = [x for x in range(lbs[-1], rbs[-1]+1)]
all_bs = list(set().union(lbs, rbs, tbs, bbs))
lr_zip = list(zip(lbs, rbs))
tb_zip = list(zip(tbs, bbs))
bds = lr_zip + tb_zip
nds = len(all_bs)

# --------------------------------------------------------------
# BASIS CONSTRUCTION
# --------------------------------------------------------------
a = []
for n in range(0, (nmax*m)+1):
    for x in basis_gen(n, m, 0, nmax):
        a.append(x)
bscount = len(a)

T = np.zeros(dim)
for ii in range(dim):
    for jj in range(m):
        T[ii] += primesqt[jj]*float(a[ii][jj])

ind = np.argsort(T)
T   = sorted(T)

# --------------------------------------------------------------
# OPERATOR MATRICES
# --------------------------------------------------------------
a_mat_dic = {}
for ii in all_bs:
    row, col, val = [], [], []
    for vv in range(dim):
        Tg = 0
        if a[vv][ii]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiD = sqrt(float(ket[ii]+1.0))
            ket[ii] = ket[ii]+1
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiD)
    a_mat = (coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()).getH()
    a_mat_dic[ii] = a_mat

n_mat_dic = {}
for ii in range(m):
    row, col, val = [], [], []
    for vv in range(dim):
        if a[vv][ii] > 0:
            ket = np.copy(a[vv])
            diag = float(ket[ii])
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(diag)
    n_mat = coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()
    n_mat_dic[ii] = n_mat

# --------------------------------------------------------------
# HOPPING TERM (exact inside cluster)
# --------------------------------------------------------------
row, col, val = [], [], []
for ii in row_pair:
    for vv in range(dim):
        if a[vv][ii[1]] >= 1.0 and a[vv][ii[0]]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiDaj = -tx*sqrt(float((ket[ii[0]]+1.0)*ket[ii[1]]))
            ket[ii[0]] += 1; ket[ii[1]] -= 1
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiDaj)

for ii in col_pair:
    for vv in range(dim):
        if a[vv][ii[1]] >= 1.0 and a[vv][ii[0]]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiDaj = -ty*sqrt(float((ket[ii[0]]+1.0)*ket[ii[1]]))
            ket[ii[0]] += 1; ket[ii[1]] -= 1
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiDaj)

hop_mat = coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()
hop_mat = hop_mat + hop_mat.getH()

# --------------------------------------------------------------
# SELF-CONSISTENT MEAN FIELD LOOP
# --------------------------------------------------------------
phi, phi_new, diff, accuracy = {}, {}, {}, {}
gs = np.zeros(dim, dtype='float64')
for bsi in all_bs:
    accuracy[bsi] = 1e-6

phi_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()
psq_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()
int_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()

# >>> storage additions >>>
results = []
# <<< storage additions <<<

#np.arange(start, stop, step) goes up to but not including stop.
#So if you write
# --- Parallel sweep over (U, mu) ---------------------------------------------

# Build grids (inclusive of endpoints, like your current arange + d step)
U_vals  = np.arange(U_min, U_max + dU, dU)
mu_vals = np.arange(mu_min, mu_max + dmu, dmu)

def solve_point(U, mu):
    """
    Self-consistent mean-field solve for a single (U, mu).
    Uses read-only globals: a_mat_dic, n_mat_dic, hop_mat, etc.
    Creates fresh local dicts to avoid race conditions.
    Returns one results row.
    """
    phi, phi_new, diff = {}, {}, {}
    for bsi in all_bs:
        phi[bsi] = 0.0
        phi_new[bsi] = 0.3
        diff[bsi] = abs(phi[bsi] - phi_new[bsi])

    iteration = 0
    # local working matrices (start as zeros)
    phi_mat = 0.0
    psq_mat = 0.0
    int_mat = 0.0

    while all(diff[bsi] > accuracy[bsi] for bsi in all_bs):
        H_mat = 0.0
        phi_mat = 0.0
        psq_mat = 0.0
        int_mat = 0.0

        # update phi from last iteration
        for bsi in all_bs:
            phi[bsi] = phi_new[bsi]

        # mean-field boundary couplings
        for xx in lr_zip:
            phi_mat += - tx*phi[xx[0]]*(a_mat_dic[xx[1]].getH() + a_mat_dic[xx[1]])
            phi_mat += - tx*phi[xx[1]]*(a_mat_dic[xx[0]].getH() + a_mat_dic[xx[0]])
            psq_mat += + 2.0*tx*phi[xx[0]]*phi[xx[1]]*eye(dim, dtype=np.double, format='csr')
        for yy in tb_zip:
            phi_mat += - ty*phi[yy[0]]*(a_mat_dic[yy[1]].getH() + a_mat_dic[yy[1]])
            phi_mat += - ty*phi[yy[1]]*(a_mat_dic[yy[0]].getH() + a_mat_dic[yy[0]])
            psq_mat += + 2.0*ty*phi[yy[0]]*phi[yy[1]]*eye(dim, dtype=np.double, format='csr')

        # on-site interaction + chemical potential
        for ii in range(m):
            int_mat += (U/2.0)*n_mat_dic[ii]*(n_mat_dic[ii]-eye(dim, dtype=np.double, format='csr'))
            int_mat += - mu*n_mat_dic[ii]

        H_mat = hop_mat + int_mat + psq_mat + phi_mat

        nev = min(dim, 3)
        if nev == 1:
            eigenvalues = H_mat[0, 0]
            eigenvectors = eye(dim, dtype=np.double, format='csr')
        else:
            eigenvalues, eigenvectors = eigsh(H_mat, k=3, which='SA')

        gs = eigenvectors[:, 0]

        for bsi in all_bs:
            phi_new[bsi] = gs.transpose().dot(a_mat_dic[bsi].dot(gs))
            diff[bsi] = abs(phi[bsi] - phi_new[bsi])

        iteration += 1
        if iteration > 10000:
            break

    rho = {}
    for bsi in all_bs:
        rho[bsi] = gs.transpose().dot(n_mat_dic[bsi].dot(gs))

    # print line (optional; printing from parallel workers can be noisy)
    # print(f"{tx:3.2f} {U:6.2f} {mu:6.2f} "
    #       f"{rho[0]:8.4f} {rho[1]:8.4f} {rho[2]:8.4f} {rho[3]:8.4f} "
    #       f"{phi_new[0]**2:8.4f} {phi_new[1]**2:8.4f} {phi_new[2]**2:8.4f} {phi_new[3]**2:8.4f} "
    #       f"{eigenvalues[0]:12.6f} {iteration:6d}")

    return [
        round(tx, 2), round(U, 2), round(mu, 2),
        round(rho[0], 4), round(rho[1], 4), round(rho[2], 4), round(rho[3], 4),
        round(phi_new[0]**2, 4), round(phi_new[1]**2, 4), round(phi_new[2]**2, 4), round(phi_new[3]**2, 4),
        round(float(eigenvalues[0]), 6), int(iteration)
    ]

# Optional: prevent BLAS oversubscription inside each process
os.environ.setdefault("OMP_NUM_THREADS", "1")


# Run grid in parallel
results = Parallel(n_jobs=-1, backend="loky", verbose=10)(
    delayed(solve_point)(U, mu)
    for U in U_vals
    for mu in mu_vals
)
# Keep rows ordered (U major, then mu)
results.sort(key=lambda r: (r[1], r[2]))

# --- Save CSV/NPZ with dynamic filenames ------------------------------------
csv_name = get_filename(tx, U_max, dU, mu_max, dmu, ".csv")
npz_name = get_filename(tx, U_max, dU, mu_max, dmu, ".npz")


# --- Save CSV/NPZ exactly like before ----------------------------------------
headers = [
    "tx","U","mu",
    "rho0","rho1","rho2","rho3",
    "phi0_sq","phi1_sq","phi2_sq","phi3_sq",
    "E0","iters"
]
out_csv = Path(csv_name)
with out_csv.open("w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(results)

# Save NPZ
np.savez_compressed(
    npz_name,
    headers=np.array(headers, dtype=object),
    data=np.array(results, dtype=float)
)

print(f"\n✅ Saved results to {csv_name} and {npz_name}")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 181 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 202 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 225 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 248 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 273 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19680313447086212s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 298 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 335 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 387 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 445 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 503 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 565 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.003361357051279s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 627 tasks      | elapsed:   11.1s
# [Parallel(n_jobs=-1)]: Done 693 tasks      | elapsed:   12.0s
# [Parallel(n_jobs=-1)]: Done 730 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1986341411496961s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 769 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0326068262334847s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 839 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=-1)]: Done 899 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 936 tasks      | elapsed:   17.4s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19992891124222567s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 975 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Batch computation too slow (5.221175670623779s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 1024 tasks      | elapsed:   18.2s
# [Parallel(n_jobs=-1)]: Done 1076 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=-1)]: Done 1117 tasks      | elapsed:   22.7s
# [Parallel(n_jobs=-1)]: Done 1160 tasks      | elapsed:   23.6s
# [Parallel(n_jobs=-1)]: Done 1203 tasks      | elapsed:   24.0s
# [Parallel(n_jobs=-1)]: Done 1248 tasks      | elapsed:   24.4s
# [Parallel(n_jobs=-1)]: Done 1293 tasks      | elapsed:   26.1s
# [Parallel(n_jobs=-1)]: Done 1340 tasks      | elapsed:   30.0s
# [Parallel(n_jobs=-1)]: Done 1387 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=-1)]: Done 1436 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 1485 tasks      | elapsed:   32.9s
# [Parallel(n_jobs=-1)]: Done 1536 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=-1)]: Done 1587 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=-1)]: Done 1640 tasks      | elapsed:   43.8s
# [Parallel(n_jobs=-1)]: Done 1693 tasks      | elapsed:   44.7s
# [Parallel(n_jobs=-1)]: Done 1748 tasks      | elapsed:   46.2s
# [Parallel(n_jobs=-1)]: Done 1803 tasks      | elapsed:   58.9s
# [Parallel(n_jobs=-1)]: Done 1860 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 1917 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 1976 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 2035 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 2096 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 2158 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 2221 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 2284 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 2351 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 2416 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2483 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 2550 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 2619 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 2688 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done 2760 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 2831 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 2904 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 2978 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 3053 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 3128 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 3205 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 3282 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 3361 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 3440 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 3521 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 3602 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 3685 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 3768 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 3853 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 3938 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 4025 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done 4112 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 4201 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 4290 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 4381 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 4472 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 4565 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 4658 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 4753 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 4848 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 4945 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 5042 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 5141 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done 5240 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 5341 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 5442 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 5545 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 5648 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 5753 tasks      | elapsed:  5.1min
# ✅ Saved results to phase_tx1.0_U25.0-(1.0)_Mu40.0-(0.2).csv and phase_tx1.0_U25.0-(1.0)_Mu40.0-(0.2).npz
# [Parallel(n_jobs=-1)]: Done 5876 out of 5876 | elapsed:  6.2min finished

# %%
import pandas as pd

# Assuming you've already loaded them
# df_big   = full big CSV
# df_small = results CSV

# Filter big file where U=25.0
df_big_U25 = df_big[df_big["U"] == 25.0].reset_index(drop=True)
df_small   = df_small.reset_index(drop=True)

print("Big file (U=25.0) shape:", df_big_U25.shape)
print("Small file shape:", df_small.shape)


# Now check if they match
comparison = df_big_U25_clean.equals(df_small_clean)
print("Do the cleaned DataFrames match?", comparison)


# Now check if they match row by row
if df_big_U25.shape == df_small.shape:
    comparison = df_big_U25.equals(df_small)
    print("\nDo the dataframes match?", comparison)

    if not comparison:
        diffs = (df_big_U25 != df_small)
        diff_rows = diffs.any(axis=1)
        print("\nMismatched rows:\n", df_big_U25[diff_rows])
        print("\nCorresponding rows in small file:\n", df_small[diff_rows])
else:
    print("⚠️ Shapes differ, cannot compare directly.")
    print("Extra rows in big file:")
    display(df_big_U25[~df_big_U25.apply(tuple,1).isin(df_small.apply(tuple,1))])
    print("\nExtra rows in small file:")
    display(df_small[~df_small.apply(tuple,1).isin(df_big_U25.apply(tuple,1))])
# Out:
# Big file (U=25.0) shape: (226, 13)
# Small file shape: (225, 13)
# ⚠️ Shapes differ, cannot compare directly.
# Extra rows in big file:
#       tx     U    mu    rho0    rho1    rho2    rho3  phi0_sq  phi1_sq  \
# 225  1.0  25.0  40.0  2.1343  2.1343  2.1343  2.1343   0.9693   0.9693
#
#      phi2_sq  phi3_sq         E0  iters
# 225   0.9693   0.9693 -224.98827     13
# Extra rows in small file:
# Empty DataFrame
# Columns: [tx, U, mu, rho0, rho1, rho2, rho3, phi0_sq, phi1_sq, phi2_sq, phi3_sq, E0, iters]
# Index: []

# %%
# Drop the extra row from big file (mu=40.0)
df_big_U25_clean = df_big_U25[df_big_U25["mu"] != 40.0].reset_index(drop=True)
df_small_clean = df_small.reset_index(drop=True)
# Now check if they match
comparison = df_big_U25_clean.equals(df_small_clean)
print("Do the cleaned DataFrames match?", comparison)
# Out:
# Do the cleaned DataFrames match? True

# %%
import numpy as np
import pandas as pd

# Load npz file
data = np.load("phase_tx1.0_U25.0-(1.0)_Mu40.0-(0.2).npz")
# This will show what arrays are inside
print(data.files)

# Load csv file
df = pd.read_csv("phase_tx1.0_U25.0-(1.0)_Mu40.0-(0.2).csv")
print(df.head())

# %% [markdown]
# # Dataset( main)

# %%
# ====== Cluster Mean-Field Bose-Hubbard (2x2 plaquette) ======
# Working code, last touched on 22-Oct-2020

import numpy as np
import math
from math import sqrt, factorial
from scipy.sparse import coo_matrix, csr_matrix, eye
from scipy.sparse.linalg import eigsh   # iterative sparse eigensolver
from scipy.linalg import eigh           # dense solver (not really used here)

# >>> storage additions >>>
import csv
from pathlib import Path
from joblib import Parallel, delayed
import os

# <<< storage additions <<<

# --------------------------------------------------------------
# PRECOMPUTED SQUARE ROOTS OF PRIMES
# --------------------------------------------------------------
primesqt = np.array([
    1.41421356, 1.73205080, 2.23606797, 2.64575131, 3.31662479,
    3.60555127, 4.12310562, 4.35889894, 4.79583152, 5.38516480,
    5.56776436, 6.08276253, 6.40312423, 6.55743852, 6.85565460,
    7.28010988, 7.68114574, 7.81024967, 8.18535277, 8.42614977,
    8.54400374, 8.88819441, 9.11043357, 9.43398113, 9.84885780,
    10.04987562, 10.14889156, 10.34408043, 10.44030650, 10.63014581,
    11.26942766, 11.44552314, 11.70469991, 11.78982612, 12.20655561,
    12.28820572, 12.52996408, 12.76714533, 12.92284798, 13.15294643,
    13.37908816, 13.45362404, 13.82027496, 13.89244398, 14.03566884,
    14.10673597, 14.52583904, 14.93318452, 15.06651917, 15.13274595
])

# --------------------------------------------------------------
# PHYSICAL PARAMETERS
# --------------------------------------------------------------
tx = 1.0   # hopping in x
ty = 1.0   # hopping in y
# U  = 25.0  # on-site interaction strength

# Instead of fixed U, we define a sweep
U_min, U_max, dU = 0.0, 25.0, 0.01  # <-- choose your U range + step

# chemical potential scan
mu_min, mu_max, dmu = -5.0, 40.0, 0.1

# cluster geometry (2x2 plaquette)
xlen, ylen = 2, 2
m = xlen * ylen   # total number of sites = 4

nmax = 4          # maximum occupation per site

# Hilbert space dimension:
dim = (nmax+1)**m


def get_filename(tx, U_start, U_end, U_step, mu_start, mu_end, mu_step, suffix):
    """
    Generate a compact filename for the 2x2 cluster results.

    Example:
    phase_tx1.0_U(0.0-25.0)-(1.0)_Mu(0.0-40.0)-(0.2).csv
    """
    return (
        f"phase_tx{tx:.1f}_"
        f"U({U_start:.1f}-{U_end:.1f})-({U_step})_"
        f"Mu({mu_start:.1f}-{mu_end:.1f})-({mu_step})"
        f"{suffix}"
    )


# --------------------------------------------------------------
# BASIS GENERATION
# --------------------------------------------------------------
def basis_gen(n, k, min_elem, max_elem):
    allowed = range(max_elem, min_elem-1, -1)
    def helper(n, k, t):
        if k == 0:
            if n == 0:
                yield t
        elif k == 1:
            if n in allowed:
                yield t + (n,)
        elif min_elem * k <= n <= max_elem * k:
            for v in allowed:
                yield from helper(n - v, k - 1, t + (v,))
    return helper(n, k, ())

# --------------------------------------------------------------
# Binary search lookup
# --------------------------------------------------------------
def BinarySearch(lys, val):  
    first, last, index = 0, len(lys)-1, -1
    while (first <= last) and (index == -1):
        mid = (first+last)//2
        if lys[mid] == val:
            index = mid
        elif val < lys[mid]:
            last = mid -1
        else:
            first = mid +1
    return index

# --------------------------------------------------------------
# LATTICE STRUCTURE: 2x2 PLAQUETTE
# --------------------------------------------------------------
lattice = np.zeros((ylen,xlen),int)
lat_ind = 0
for yy in range(ylen):
    for xx in range(xlen):
        lattice[yy][xx] = lat_ind
        lat_ind += 1

row_pair = []
for yy in range(ylen):
    for xx in range(xlen-1):
        row_pair.append([lattice[yy][xx], lattice[yy][xx+1]])

col_pair = []
for xx in range(xlen):
    for yy in range(ylen-1):
        col_pair.append([lattice[yy][xx], lattice[yy+1][xx]])

# --------------------------------------------------------------
# BOUNDARY SITES
# --------------------------------------------------------------
lbs = [xlen * x for x in range(0, ylen)]
rbs = [(xlen * (x+1))-1 for x in range(0, ylen)]
tbs = [x for x in range(lbs[0], rbs[0]+1)]
bbs = [x for x in range(lbs[-1], rbs[-1]+1)]
all_bs = list(set().union(lbs, rbs, tbs, bbs))
lr_zip = list(zip(lbs, rbs))
tb_zip = list(zip(tbs, bbs))
bds = lr_zip + tb_zip
nds = len(all_bs)

# --------------------------------------------------------------
# BASIS CONSTRUCTION
# --------------------------------------------------------------
a = []
for n in range(0, (nmax*m)+1):
    for x in basis_gen(n, m, 0, nmax):
        a.append(x)
bscount = len(a)

T = np.zeros(dim)
for ii in range(dim):
    for jj in range(m):
        T[ii] += primesqt[jj]*float(a[ii][jj])

ind = np.argsort(T)
T   = sorted(T)

# --------------------------------------------------------------
# OPERATOR MATRICES
# --------------------------------------------------------------
a_mat_dic = {}
for ii in all_bs:
    row, col, val = [], [], []
    for vv in range(dim):
        Tg = 0
        if a[vv][ii]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiD = sqrt(float(ket[ii]+1.0))
            ket[ii] = ket[ii]+1
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiD)
    a_mat = (coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()).getH()
    a_mat_dic[ii] = a_mat

n_mat_dic = {}
for ii in range(m):
    row, col, val = [], [], []
    for vv in range(dim):
        if a[vv][ii] > 0:
            ket = np.copy(a[vv])
            diag = float(ket[ii])
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(diag)
    n_mat = coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()
    n_mat_dic[ii] = n_mat

# --------------------------------------------------------------
# HOPPING TERM (exact inside cluster)
# --------------------------------------------------------------
row, col, val = [], [], []
for ii in row_pair:
    for vv in range(dim):
        if a[vv][ii[1]] >= 1.0 and a[vv][ii[0]]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiDaj = -tx*sqrt(float((ket[ii[0]]+1.0)*ket[ii[1]]))
            ket[ii[0]] += 1; ket[ii[1]] -= 1
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiDaj)

for ii in col_pair:
    for vv in range(dim):
        if a[vv][ii[1]] >= 1.0 and a[vv][ii[0]]+1 < nmax+1:
            ket = np.copy(a[vv])
            aiDaj = -ty*sqrt(float((ket[ii[0]]+1.0)*ket[ii[1]]))
            ket[ii[0]] += 1; ket[ii[1]] -= 1
            Tg = 0
            for jj in range(m):
                Tg += float((primesqt[jj])*ket[jj])
            location = BinarySearch(T, Tg)
            uu = ind[location]
            row.append(uu); col.append(vv); val.append(aiDaj)

hop_mat = coo_matrix((val, (row, col)), shape=(dim, dim)).tocsr()
hop_mat = hop_mat + hop_mat.getH()

# --------------------------------------------------------------
# SELF-CONSISTENT MEAN FIELD LOOP
# --------------------------------------------------------------
phi, phi_new, diff, accuracy = {}, {}, {}, {}
gs = np.zeros(dim, dtype='float64')
for bsi in all_bs:
    accuracy[bsi] = 1e-6

phi_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()
psq_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()
int_mat = coo_matrix((dim, dim), dtype=np.double).tocsr()

# >>> storage additions >>>
results = []
# <<< storage additions <<<

#np.arange(start, stop, step) goes up to but not including stop.
#So if you write
# --- Parallel sweep over (U, mu) ---------------------------------------------

# Build grids (inclusive of endpoints, like your current arange + d step)
U_vals  = np.arange(U_min, U_max + dU, dU)
mu_vals = np.arange(mu_min, mu_max, dmu)

def solve_point(U, mu):
    """
    Self-consistent mean-field solve for a single (U, mu).
    Uses read-only globals: a_mat_dic, n_mat_dic, hop_mat, etc.
    Creates fresh local dicts to avoid race conditions.
    Returns one results row.
    """
    phi, phi_new, diff = {}, {}, {}
    for bsi in all_bs:
        phi[bsi] = 0.0
        phi_new[bsi] = 0.3
        diff[bsi] = abs(phi[bsi] - phi_new[bsi])

    iteration = 0
    # local working matrices (start as zeros)
    phi_mat = 0.0
    psq_mat = 0.0
    int_mat = 0.0

    while all(diff[bsi] > accuracy[bsi] for bsi in all_bs):
        H_mat = 0.0
        phi_mat = 0.0
        psq_mat = 0.0
        int_mat = 0.0

        # update phi from last iteration
        for bsi in all_bs:
            phi[bsi] = phi_new[bsi]

        # mean-field boundary couplings
        for xx in lr_zip:
            phi_mat += - tx*phi[xx[0]]*(a_mat_dic[xx[1]].getH() + a_mat_dic[xx[1]])
            phi_mat += - tx*phi[xx[1]]*(a_mat_dic[xx[0]].getH() + a_mat_dic[xx[0]])
            psq_mat += + 2.0*tx*phi[xx[0]]*phi[xx[1]]*eye(dim, dtype=np.double, format='csr')
        for yy in tb_zip:
            phi_mat += - ty*phi[yy[0]]*(a_mat_dic[yy[1]].getH() + a_mat_dic[yy[1]])
            phi_mat += - ty*phi[yy[1]]*(a_mat_dic[yy[0]].getH() + a_mat_dic[yy[0]])
            psq_mat += + 2.0*ty*phi[yy[0]]*phi[yy[1]]*eye(dim, dtype=np.double, format='csr')

        # on-site interaction + chemical potential
        for ii in range(m):
            int_mat += (U/2.0)*n_mat_dic[ii]*(n_mat_dic[ii]-eye(dim, dtype=np.double, format='csr'))
            int_mat += - mu*n_mat_dic[ii]

        H_mat = hop_mat + int_mat + psq_mat + phi_mat

        nev = min(dim, 3)
        if nev == 1:
            eigenvalues = H_mat[0, 0]
            eigenvectors = eye(dim, dtype=np.double, format='csr')
        else:
            eigenvalues, eigenvectors = eigsh(H_mat, k=3, which='SA')

        gs = eigenvectors[:, 0]

        for bsi in all_bs:
            phi_new[bsi] = gs.transpose().dot(a_mat_dic[bsi].dot(gs))
            diff[bsi] = abs(phi[bsi] - phi_new[bsi])

        iteration += 1
        if iteration > 10000:
            break

    rho = {}
    for bsi in all_bs:
        rho[bsi] = gs.transpose().dot(n_mat_dic[bsi].dot(gs))

    # print line (optional; printing from parallel workers can be noisy)
    # print(f"{tx:3.2f} {U:6.2f} {mu:6.2f} "
    #       f"{rho[0]:8.4f} {rho[1]:8.4f} {rho[2]:8.4f} {rho[3]:8.4f} "
    #       f"{phi_new[0]**2:8.4f} {phi_new[1]**2:8.4f} {phi_new[2]**2:8.4f} {phi_new[3]**2:8.4f} "
    #       f"{eigenvalues[0]:12.6f} {iteration:6d}")

    return [
        round(tx, 2), round(U, 2), round(mu, 2),
        round(rho[0], 4), round(rho[1], 4), round(rho[2], 4), round(rho[3], 4),
        round(phi_new[0]**2, 4), round(phi_new[1]**2, 4), round(phi_new[2]**2, 4), round(phi_new[3]**2, 4),
        round(float(eigenvalues[0]), 6), int(iteration)
    ]

# Optional: prevent BLAS oversubscription inside each process
os.environ.setdefault("OMP_NUM_THREADS", "1")

# Run grid in parallel
results = Parallel(n_jobs=-1, backend="loky", verbose=10)(
    delayed(solve_point)(U, mu)
    for U in U_vals
    for mu in mu_vals
)

# Keep rows ordered (U major, then mu)
results.sort(key=lambda r: (r[1], r[2]))

# --- Save CSV/NPZ with dynamic filenames ------------------------------------
csv_name = get_filename(tx,U_min/4, U_max/4, dU,mu_min/4,  mu_max/4, dmu, ".csv")
npz_name = get_filename(tx,U_min, U_max, dU,mu_min, mu_max, dmu, ".npz")


# --- Save CSV/NPZ exactly like before ----------------------------------------
headers = [
    "tx","U","mu",
    "rho0","rho1","rho2","rho3",
    "phi0_sq","phi1_sq","phi2_sq","phi3_sq",
    "E0","iters"
]
out_csv = Path(csv_name)
with out_csv.open("w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(headers)
    writer.writerows(results)

# Save NPZ
np.savez_compressed(
    npz_name,
    headers=np.array(headers, dtype=object),
    data=np.array(results, dtype=float)
)

print(f"\n✅ Saved results to {csv_name} and {npz_name}")
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19680159406361875s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0573040769642703s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 221 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 263 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 297 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 320 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 343 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 370 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=-1)]: Done 395 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=-1)]: Done 422 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 449 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 479 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19722940781222614s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 546 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 607 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.089621667340271s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 672 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 731 tasks      | elapsed:   13.0s
# [Parallel(n_jobs=-1)]: Done 767 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 803 tasks      | elapsed:   13.9s
# [Parallel(n_jobs=-1)]: Done 841 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 879 tasks      | elapsed:   14.6s
# [Parallel(n_jobs=-1)]: Done 918 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1947586200100615s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 957 tasks      | elapsed:   15.8s
# [Parallel(n_jobs=-1)]: Done 1007 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0119470368896097s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 1088 tasks      | elapsed:   17.6s
# [Parallel(n_jobs=-1)]: Done 1159 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 1203 tasks      | elapsed:   21.6s
# [Parallel(n_jobs=-1)]: Done 1248 tasks      | elapsed:   22.2s
# [Parallel(n_jobs=-1)]: Done 1294 tasks      | elapsed:   22.6s
# [Parallel(n_jobs=-1)]: Done 1341 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 1388 tasks      | elapsed:   24.1s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19756178333606927s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 1448 tasks      | elapsed:   24.6s
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.790966071098719s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 1544 tasks      | elapsed:   27.1s
# [Parallel(n_jobs=-1)]: Done 1636 tasks      | elapsed:   30.8s
# [Parallel(n_jobs=-1)]: Done 1688 tasks      | elapsed:   31.5s
# [Parallel(n_jobs=-1)]: Done 1741 tasks      | elapsed:   32.2s
# [Parallel(n_jobs=-1)]: Done 1794 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19567470075445748s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 1849 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 1922 tasks      | elapsed:   34.7s
# [Parallel(n_jobs=-1)]: Batch computation too slow (5.133727606642918s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 2035 tasks      | elapsed:   39.8s
# [Parallel(n_jobs=-1)]: Done 2097 tasks      | elapsed:   41.0s
# [Parallel(n_jobs=-1)]: Done 2156 tasks      | elapsed:   42.0s
# [Parallel(n_jobs=-1)]: Done 2215 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=-1)]: Done 2277 tasks      | elapsed:   44.9s
# [Parallel(n_jobs=-1)]: Done 2338 tasks      | elapsed:   45.5s
# [Parallel(n_jobs=-1)]: Done 2401 tasks      | elapsed:   46.6s
# [Parallel(n_jobs=-1)]: Done 2466 tasks      | elapsed:   53.4s
# [Parallel(n_jobs=-1)]: Done 2531 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done 2596 tasks      | elapsed:   57.0s
# [Parallel(n_jobs=-1)]: Done 2663 tasks      | elapsed:   58.1s
# [Parallel(n_jobs=-1)]: Done 2730 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 2799 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 2868 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 2939 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 3010 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 3083 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 3156 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 3231 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 3307 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 3384 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 3461 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3540 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3620 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 3701 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 3782 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 3865 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done 3948 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 4033 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 4118 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 4205 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 4292 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 4381 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 4470 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 4561 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 4652 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done 4745 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done 4838 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 4933 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done 5028 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 5125 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 5222 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 5321 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 5420 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 5521 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done 5622 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done 5725 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 5828 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=-1)]: Done 5933 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 6038 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done 6145 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 6252 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done 6361 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 6470 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 6581 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 6692 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done 6805 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 6918 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 7033 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 7148 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done 7265 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 7382 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 7501 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 7620 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done 7741 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done 7862 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 7985 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 8108 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 8233 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done 8358 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done 8485 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 8612 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 8741 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done 8870 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 9001 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=-1)]: Done 9132 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done 9265 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done 9398 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 9533 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done 9668 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done 9805 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done 9942 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 10081 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=-1)]: Done 10220 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 10361 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 10502 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 10645 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=-1)]: Done 10788 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 10933 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done 11078 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 11225 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done 11372 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=-1)]: Done 11521 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 11670 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=-1)]: Done 11821 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done 11972 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 12125 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done 12278 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done 12433 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=-1)]: Done 12588 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done 12745 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=-1)]: Done 12902 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 13061 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 13220 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done 13381 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 13542 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=-1)]: Done 13705 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done 13868 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=-1)]: Done 14033 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=-1)]: Done 14198 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done 14365 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done 14532 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done 14701 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done 14870 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 15041 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=-1)]: Done 15212 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done 15385 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done 15558 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done 15733 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=-1)]: Done 15908 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done 16085 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 16262 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done 16441 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done 16620 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=-1)]: Done 16801 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 16982 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done 17165 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done 17348 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 17533 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 17718 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 17905 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=-1)]: Done 18092 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=-1)]: Done 18281 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done 18470 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done 18661 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done 18852 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 19045 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=-1)]: Done 19238 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=-1)]: Done 19433 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done 19628 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done 19825 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done 20022 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done 20221 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done 20420 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=-1)]: Done 20621 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 20822 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=-1)]: Done 21025 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done 21228 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done 21433 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=-1)]: Done 21638 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=-1)]: Done 21845 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done 22052 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=-1)]: Done 22261 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=-1)]: Done 22470 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done 22681 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 22892 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 23105 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 23318 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 23533 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done 23748 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done 23965 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=-1)]: Done 24182 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done 24401 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done 24620 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done 24841 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done 25062 tasks      | elapsed: 16.3min
# [Parallel(n_jobs=-1)]: Done 25285 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done 25508 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done 25733 tasks      | elapsed: 16.6min
# [Parallel(n_jobs=-1)]: Done 25958 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done 26185 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done 26412 tasks      | elapsed: 17.1min
# [Parallel(n_jobs=-1)]: Done 26641 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done 26870 tasks      | elapsed: 17.4min
# [Parallel(n_jobs=-1)]: Done 27101 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=-1)]: Done 27332 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 27565 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done 27798 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 28033 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done 28268 tasks      | elapsed: 18.3min
# [Parallel(n_jobs=-1)]: Done 28505 tasks      | elapsed: 18.4min
# [Parallel(n_jobs=-1)]: Done 28742 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done 28981 tasks      | elapsed: 18.7min
# [Parallel(n_jobs=-1)]: Done 29220 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done 29461 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done 29702 tasks      | elapsed: 19.2min
# [Parallel(n_jobs=-1)]: Done 29945 tasks      | elapsed: 19.3min
# [Parallel(n_jobs=-1)]: Done 30188 tasks      | elapsed: 19.5min
# [Parallel(n_jobs=-1)]: Done 30433 tasks      | elapsed: 19.6min
# [Parallel(n_jobs=-1)]: Done 30678 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done 30925 tasks      | elapsed: 19.9min
# [Parallel(n_jobs=-1)]: Done 31172 tasks      | elapsed: 20.0min
# [Parallel(n_jobs=-1)]: Done 31421 tasks      | elapsed: 20.2min
# [Parallel(n_jobs=-1)]: Done 31670 tasks      | elapsed: 20.3min
# [Parallel(n_jobs=-1)]: Done 31921 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done 32172 tasks      | elapsed: 20.6min
# [Parallel(n_jobs=-1)]: Done 32425 tasks      | elapsed: 20.8min
# [Parallel(n_jobs=-1)]: Done 32678 tasks      | elapsed: 20.9min
# [Parallel(n_jobs=-1)]: Done 32933 tasks      | elapsed: 21.1min
# [Parallel(n_jobs=-1)]: Done 33188 tasks      | elapsed: 21.3min
# [Parallel(n_jobs=-1)]: Done 33445 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done 33702 tasks      | elapsed: 21.6min
# [Parallel(n_jobs=-1)]: Done 33961 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done 34220 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done 34481 tasks      | elapsed: 22.1min
# [Parallel(n_jobs=-1)]: Done 34742 tasks      | elapsed: 22.2min
# [Parallel(n_jobs=-1)]: Done 35005 tasks      | elapsed: 22.4min
# [Parallel(n_jobs=-1)]: Done 35268 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done 35533 tasks      | elapsed: 22.7min
# [Parallel(n_jobs=-1)]: Done 35798 tasks      | elapsed: 22.9min
# [Parallel(n_jobs=-1)]: Done 36065 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done 36332 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 36601 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done 36870 tasks      | elapsed: 23.5min
# [Parallel(n_jobs=-1)]: Done 37141 tasks      | elapsed: 23.7min
# [Parallel(n_jobs=-1)]: Done 37412 tasks      | elapsed: 23.8min
# [Parallel(n_jobs=-1)]: Done 37685 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 37958 tasks      | elapsed: 24.1min
# [Parallel(n_jobs=-1)]: Done 38233 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done 38508 tasks      | elapsed: 24.5min
# [Parallel(n_jobs=-1)]: Done 38785 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=-1)]: Done 39062 tasks      | elapsed: 24.8min
# [Parallel(n_jobs=-1)]: Done 39341 tasks      | elapsed: 24.9min
# [Parallel(n_jobs=-1)]: Done 39620 tasks      | elapsed: 25.2min
# [Parallel(n_jobs=-1)]: Done 39901 tasks      | elapsed: 25.3min
# [Parallel(n_jobs=-1)]: Done 40182 tasks      | elapsed: 25.4min
# [Parallel(n_jobs=-1)]: Done 40465 tasks      | elapsed: 25.6min
# [Parallel(n_jobs=-1)]: Done 40748 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done 41033 tasks      | elapsed: 25.9min
# [Parallel(n_jobs=-1)]: Done 41318 tasks      | elapsed: 26.1min
# [Parallel(n_jobs=-1)]: Done 41605 tasks      | elapsed: 26.2min
# [Parallel(n_jobs=-1)]: Done 41892 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done 42181 tasks      | elapsed: 26.7min
# [Parallel(n_jobs=-1)]: Done 42470 tasks      | elapsed: 26.8min
# [Parallel(n_jobs=-1)]: Done 42761 tasks      | elapsed: 27.0min
# [Parallel(n_jobs=-1)]: Done 43052 tasks      | elapsed: 27.2min
# [Parallel(n_jobs=-1)]: Done 43345 tasks      | elapsed: 27.3min
# [Parallel(n_jobs=-1)]: Done 43638 tasks      | elapsed: 27.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1969843530103432s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.193090003059975s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 44031 tasks      | elapsed: 27.7min
# [Parallel(n_jobs=-1)]: Done 44327 tasks      | elapsed: 27.9min
# [Parallel(n_jobs=-1)]: Done 44624 tasks      | elapsed: 28.0min
# [Parallel(n_jobs=-1)]: Done 44922 tasks      | elapsed: 28.2min
# [Parallel(n_jobs=-1)]: Done 45221 tasks      | elapsed: 28.3min
# [Parallel(n_jobs=-1)]: Done 45520 tasks      | elapsed: 28.5min
# [Parallel(n_jobs=-1)]: Done 45821 tasks      | elapsed: 28.8min
# [Parallel(n_jobs=-1)]: Done 46122 tasks      | elapsed: 28.9min
# [Parallel(n_jobs=-1)]: Done 46425 tasks      | elapsed: 29.1min
# [Parallel(n_jobs=-1)]: Done 46728 tasks      | elapsed: 29.3min
# [Parallel(n_jobs=-1)]: Done 47033 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done 47338 tasks      | elapsed: 29.7min
# [Parallel(n_jobs=-1)]: Done 47645 tasks      | elapsed: 29.9min
# [Parallel(n_jobs=-1)]: Done 47952 tasks      | elapsed: 30.1min
# [Parallel(n_jobs=-1)]: Done 48261 tasks      | elapsed: 30.3min
# [Parallel(n_jobs=-1)]: Done 48570 tasks      | elapsed: 30.5min
# [Parallel(n_jobs=-1)]: Done 48881 tasks      | elapsed: 30.7min
# [Parallel(n_jobs=-1)]: Done 49192 tasks      | elapsed: 30.8min
# [Parallel(n_jobs=-1)]: Done 49505 tasks      | elapsed: 31.0min
# [Parallel(n_jobs=-1)]: Done 49818 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-1)]: Done 50133 tasks      | elapsed: 31.3min
# [Parallel(n_jobs=-1)]: Done 50448 tasks      | elapsed: 31.6min
# [Parallel(n_jobs=-1)]: Done 50765 tasks      | elapsed: 31.8min
# [Parallel(n_jobs=-1)]: Done 51082 tasks      | elapsed: 31.9min
# [Parallel(n_jobs=-1)]: Done 51401 tasks      | elapsed: 32.2min
# [Parallel(n_jobs=-1)]: Done 51720 tasks      | elapsed: 32.5min
# [Parallel(n_jobs=-1)]: Done 52041 tasks      | elapsed: 32.7min
# [Parallel(n_jobs=-1)]: Done 52362 tasks      | elapsed: 32.9min
# [Parallel(n_jobs=-1)]: Done 52685 tasks      | elapsed: 33.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1994670932982295s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0770141726887617s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 53106 tasks      | elapsed: 33.3min
# [Parallel(n_jobs=-1)]: Done 53432 tasks      | elapsed: 33.5min
# [Parallel(n_jobs=-1)]: Done 53758 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done 54085 tasks      | elapsed: 33.8min
# [Parallel(n_jobs=-1)]: Done 54412 tasks      | elapsed: 34.0min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1997854025834705s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1275871403089357s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 54839 tasks      | elapsed: 34.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19990544048430475s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0434328042859238s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 55268 tasks      | elapsed: 34.5min
# [Parallel(n_jobs=-1)]: Done 55600 tasks      | elapsed: 34.8min
# [Parallel(n_jobs=-1)]: Done 55932 tasks      | elapsed: 34.9min
# [Parallel(n_jobs=-1)]: Done 56265 tasks      | elapsed: 35.2min
# [Parallel(n_jobs=-1)]: Done 56598 tasks      | elapsed: 35.4min
# [Parallel(n_jobs=-1)]: Done 56933 tasks      | elapsed: 35.5min
# [Parallel(n_jobs=-1)]: Done 57268 tasks      | elapsed: 35.7min
# [Parallel(n_jobs=-1)]: Done 57605 tasks      | elapsed: 36.0min
# [Parallel(n_jobs=-1)]: Done 57942 tasks      | elapsed: 36.2min
# [Parallel(n_jobs=-1)]: Done 58281 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19923936519767224s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 58630 tasks      | elapsed: 36.5min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0527920653720053s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 59059 tasks      | elapsed: 36.8min
# [Parallel(n_jobs=-1)]: Done 59401 tasks      | elapsed: 37.1min
# [Parallel(n_jobs=-1)]: Done 59744 tasks      | elapsed: 37.3min
# [Parallel(n_jobs=-1)]: Done 60087 tasks      | elapsed: 37.4min
# [Parallel(n_jobs=-1)]: Done 60432 tasks      | elapsed: 37.6min
# [Parallel(n_jobs=-1)]: Done 60777 tasks      | elapsed: 37.9min
# [Parallel(n_jobs=-1)]: Done 61125 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1987709018399109s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1306254483918217s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 61570 tasks      | elapsed: 38.3min
# [Parallel(n_jobs=-1)]: Done 61920 tasks      | elapsed: 38.5min
# [Parallel(n_jobs=-1)]: Done 62269 tasks      | elapsed: 38.7min
# [Parallel(n_jobs=-1)]: Done 62621 tasks      | elapsed: 38.9min
# [Parallel(n_jobs=-1)]: Done 62972 tasks      | elapsed: 39.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19529326447669232s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1356288115726554s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 63423 tasks      | elapsed: 39.3min
# [Parallel(n_jobs=-1)]: Done 63777 tasks      | elapsed: 39.5min
# [Parallel(n_jobs=-1)]: Done 64132 tasks      | elapsed: 39.7min
# [Parallel(n_jobs=-1)]: Done 64487 tasks      | elapsed: 39.9min
# [Parallel(n_jobs=-1)]: Done 64844 tasks      | elapsed: 40.1min
# [Parallel(n_jobs=-1)]: Done 65201 tasks      | elapsed: 40.4min
# [Parallel(n_jobs=-1)]: Done 65560 tasks      | elapsed: 40.6min
# [Parallel(n_jobs=-1)]: Done 65919 tasks      | elapsed: 40.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19928016349678548s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 66292 tasks      | elapsed: 41.0min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.001459873688994s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 66741 tasks      | elapsed: 41.2min
# [Parallel(n_jobs=-1)]: Done 67104 tasks      | elapsed: 41.5min
# [Parallel(n_jobs=-1)]: Done 67468 tasks      | elapsed: 41.7min
# [Parallel(n_jobs=-1)]: Done 67833 tasks      | elapsed: 41.9min
# [Parallel(n_jobs=-1)]: Done 68198 tasks      | elapsed: 42.1min
# [Parallel(n_jobs=-1)]: Done 68565 tasks      | elapsed: 42.3min
# [Parallel(n_jobs=-1)]: Done 68932 tasks      | elapsed: 42.5min
# [Parallel(n_jobs=-1)]: Done 69301 tasks      | elapsed: 42.8min
# [Parallel(n_jobs=-1)]: Done 69670 tasks      | elapsed: 43.0min
# [Parallel(n_jobs=-1)]: Done 70041 tasks      | elapsed: 43.2min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19995944356867792s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.2399179123826976s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 70507 tasks      | elapsed: 43.5min
# [Parallel(n_jobs=-1)]: Done 70884 tasks      | elapsed: 43.6min
# [Parallel(n_jobs=-1)]: Done 71257 tasks      | elapsed: 43.8min
# [Parallel(n_jobs=-1)]: Done 71633 tasks      | elapsed: 44.1min
# [Parallel(n_jobs=-1)]: Done 72008 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1990779175436288s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.037838513862818s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 72484 tasks      | elapsed: 44.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19924651895620699s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0103009862948253s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 72960 tasks      | elapsed: 44.8min
# [Parallel(n_jobs=-1)]: Done 73340 tasks      | elapsed: 45.1min
# [Parallel(n_jobs=-1)]: Done 73719 tasks      | elapsed: 45.3min
# [Parallel(n_jobs=-1)]: Done 74100 tasks      | elapsed: 45.6min
# [Parallel(n_jobs=-1)]: Done 74481 tasks      | elapsed: 45.8min
# [Parallel(n_jobs=-1)]: Done 74864 tasks      | elapsed: 46.0min
# [Parallel(n_jobs=-1)]: Done 75248 tasks      | elapsed: 46.2min
# [Parallel(n_jobs=-1)]: Done 75633 tasks      | elapsed: 46.5min
# [Parallel(n_jobs=-1)]: Done 76018 tasks      | elapsed: 46.7min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19930825565753696s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1557328816951777s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 76503 tasks      | elapsed: 47.0min
# [Parallel(n_jobs=-1)]: Done 76891 tasks      | elapsed: 47.2min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19970987249165276s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.168518152493432s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 77379 tasks      | elapsed: 47.4min
# [Parallel(n_jobs=-1)]: Done 77770 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 78161 tasks      | elapsed: 47.9min
# [Parallel(n_jobs=-1)]: Done 78552 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 78945 tasks      | elapsed: 48.4min
# [Parallel(n_jobs=-1)]: Done 79338 tasks      | elapsed: 48.6min
# [Parallel(n_jobs=-1)]: Done 79733 tasks      | elapsed: 48.9min
# [Parallel(n_jobs=-1)]: Done 80128 tasks      | elapsed: 49.1min
# [Parallel(n_jobs=-1)]: Done 80525 tasks      | elapsed: 49.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1988427901064723s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0363072016348083s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 81021 tasks      | elapsed: 49.6min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19910820146735614s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1040473193095868s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 81519 tasks      | elapsed: 49.9min
# [Parallel(n_jobs=-1)]: Done 81919 tasks      | elapsed: 50.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19856005830830342s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1313982671692275s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 82419 tasks      | elapsed: 50.4min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19639143646472457s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1149231699357895s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19958986756453365s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 82920 tasks      | elapsed: 50.6min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.146623792302183s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 83421 tasks      | elapsed: 50.9min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1988798646563395s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 83827 tasks      | elapsed: 51.2min
# [Parallel(n_jobs=-1)]: Batch computation too slow (11.316527294775181s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1989927042380355s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 84394 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1952773552644276s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 84836 tasks      | elapsed: 51.7min
# [Parallel(n_jobs=-1)]: Done 85244 tasks      | elapsed: 51.9min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19962697635044865s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 85674 tasks      | elapsed: 52.1min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.063109004084941s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19943352003195988s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (4.258384166039531s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 86249 tasks      | elapsed: 52.5min
# [Parallel(n_jobs=-1)]: Done 86669 tasks      | elapsed: 52.7min
# [Parallel(n_jobs=-1)]: Done 87080 tasks      | elapsed: 52.9min
# [Parallel(n_jobs=-1)]: Done 87491 tasks      | elapsed: 53.2min
# [Parallel(n_jobs=-1)]: Done 87904 tasks      | elapsed: 53.4min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19711077472230082s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 88318 tasks      | elapsed: 53.7min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0490828256344837s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 88831 tasks      | elapsed: 53.9min
# [Parallel(n_jobs=-1)]: Done 89247 tasks      | elapsed: 54.2min
# [Parallel(n_jobs=-1)]: Done 89665 tasks      | elapsed: 54.4min
# [Parallel(n_jobs=-1)]: Done 90082 tasks      | elapsed: 54.7min
# [Parallel(n_jobs=-1)]: Done 90501 tasks      | elapsed: 54.9min
# [Parallel(n_jobs=-1)]: Done 90920 tasks      | elapsed: 55.2min
# [Parallel(n_jobs=-1)]: Done 91341 tasks      | elapsed: 55.4min
# [Parallel(n_jobs=-1)]: Done 91762 tasks      | elapsed: 55.7min
# [Parallel(n_jobs=-1)]: Done 92185 tasks      | elapsed: 56.0min
# [Parallel(n_jobs=-1)]: Done 92608 tasks      | elapsed: 56.2min
# [Parallel(n_jobs=-1)]: Done 93033 tasks      | elapsed: 56.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19901485337471703s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0500900592092486s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 93556 tasks      | elapsed: 56.8min
# [Parallel(n_jobs=-1)]: Done 93984 tasks      | elapsed: 57.0min
# [Parallel(n_jobs=-1)]: Done 94412 tasks      | elapsed: 57.3min
# [Parallel(n_jobs=-1)]: Done 94841 tasks      | elapsed: 57.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19804546373726123s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.043647618004333s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 95368 tasks      | elapsed: 57.8min
# [Parallel(n_jobs=-1)]: Done 95801 tasks      | elapsed: 58.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19954038102681165s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.11980208256705s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 96331 tasks      | elapsed: 58.4min
# [Parallel(n_jobs=-1)]: Done 96764 tasks      | elapsed: 58.7min
# [Parallel(n_jobs=-1)]: Done 97197 tasks      | elapsed: 58.9min
# [Parallel(n_jobs=-1)]: Done 97632 tasks      | elapsed: 59.2min
# [Parallel(n_jobs=-1)]: Done 98068 tasks      | elapsed: 59.5min
# [Parallel(n_jobs=-1)]: Done 98505 tasks      | elapsed: 59.8min
# [Parallel(n_jobs=-1)]: Done 98942 tasks      | elapsed: 60.1min
# [Parallel(n_jobs=-1)]: Done 99381 tasks      | elapsed: 60.4min
# [Parallel(n_jobs=-1)]: Done 99820 tasks      | elapsed: 60.6min
# [Parallel(n_jobs=-1)]: Done 100261 tasks      | elapsed: 60.9min
# [Parallel(n_jobs=-1)]: Done 100702 tasks      | elapsed: 61.2min
# [Parallel(n_jobs=-1)]: Done 101145 tasks      | elapsed: 61.5min
# [Parallel(n_jobs=-1)]: Done 101588 tasks      | elapsed: 61.8min
# [Parallel(n_jobs=-1)]: Done 102033 tasks      | elapsed: 62.0min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19966061575745964s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.051080636752601s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 102576 tasks      | elapsed: 62.3min
# [Parallel(n_jobs=-1)]: Done 103024 tasks      | elapsed: 62.6min
# [Parallel(n_jobs=-1)]: Done 103472 tasks      | elapsed: 62.8min
# [Parallel(n_jobs=-1)]: Done 103921 tasks      | elapsed: 63.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19846107488278358s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1076327386983387s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 104468 tasks      | elapsed: 63.3min
# [Parallel(n_jobs=-1)]: Done 104921 tasks      | elapsed: 63.6min
# [Parallel(n_jobs=-1)]: Done 105372 tasks      | elapsed: 63.9min
# [Parallel(n_jobs=-1)]: Done 105825 tasks      | elapsed: 64.2min
# [Parallel(n_jobs=-1)]: Done 106278 tasks      | elapsed: 64.5min
# [Parallel(n_jobs=-1)]: Done 106733 tasks      | elapsed: 64.7min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19963435819883357s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0609354209679895s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 107306 tasks      | elapsed: 65.0min
# [Parallel(n_jobs=-1)]: Done 107764 tasks      | elapsed: 65.2min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19913041688226432s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.018140307495177s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 108293 tasks      | elapsed: 65.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19310070976462518s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.088869887326368s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 108899 tasks      | elapsed: 65.9min
# [Parallel(n_jobs=-1)]: Done 109359 tasks      | elapsed: 66.2min
# [Parallel(n_jobs=-1)]: Done 109820 tasks      | elapsed: 66.5min
# [Parallel(n_jobs=-1)]: Done 110281 tasks      | elapsed: 66.7min
# [Parallel(n_jobs=-1)]: Done 110744 tasks      | elapsed: 67.0min
# [Parallel(n_jobs=-1)]: Done 111208 tasks      | elapsed: 67.3min
# [Parallel(n_jobs=-1)]: Done 111673 tasks      | elapsed: 67.6min
# [Parallel(n_jobs=-1)]: Done 112138 tasks      | elapsed: 67.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19852227497779948s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.188195267840067s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 112703 tasks      | elapsed: 68.1min
# [Parallel(n_jobs=-1)]: Done 113171 tasks      | elapsed: 68.4min
# [Parallel(n_jobs=-1)]: Done 113641 tasks      | elapsed: 68.6min
# [Parallel(n_jobs=-1)]: Done 114110 tasks      | elapsed: 68.9min
# [Parallel(n_jobs=-1)]: Done 114581 tasks      | elapsed: 69.3min
# [Parallel(n_jobs=-1)]: Done 115052 tasks      | elapsed: 69.6min
# [Parallel(n_jobs=-1)]: Done 115525 tasks      | elapsed: 69.9min
# [Parallel(n_jobs=-1)]: Done 115998 tasks      | elapsed: 70.2min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19926937865903935s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0704212599115275s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 116571 tasks      | elapsed: 70.5min
# [Parallel(n_jobs=-1)]: Done 117048 tasks      | elapsed: 70.8min
# [Parallel(n_jobs=-1)]: Done 117525 tasks      | elapsed: 71.2min
# [Parallel(n_jobs=-1)]: Done 118002 tasks      | elapsed: 71.7min
# [Parallel(n_jobs=-1)]: Done 118481 tasks      | elapsed: 72.2min
# [Parallel(n_jobs=-1)]: Done 118960 tasks      | elapsed: 72.7min
# [Parallel(n_jobs=-1)]: Done 119441 tasks      | elapsed: 73.2min
# [Parallel(n_jobs=-1)]: Done 119922 tasks      | elapsed: 73.8min
# [Parallel(n_jobs=-1)]: Done 120405 tasks      | elapsed: 74.3min
# [Parallel(n_jobs=-1)]: Done 120888 tasks      | elapsed: 74.9min
# [Parallel(n_jobs=-1)]: Done 121373 tasks      | elapsed: 75.5min
# [Parallel(n_jobs=-1)]: Done 121858 tasks      | elapsed: 76.0min
# [Parallel(n_jobs=-1)]: Done 122345 tasks      | elapsed: 76.5min
# [Parallel(n_jobs=-1)]: Done 122832 tasks      | elapsed: 77.0min
# [Parallel(n_jobs=-1)]: Done 123321 tasks      | elapsed: 77.6min
# [Parallel(n_jobs=-1)]: Done 123810 tasks      | elapsed: 78.2min
# [Parallel(n_jobs=-1)]: Done 124301 tasks      | elapsed: 78.7min
# [Parallel(n_jobs=-1)]: Done 124792 tasks      | elapsed: 79.3min
# [Parallel(n_jobs=-1)]: Done 125285 tasks      | elapsed: 79.7min
# [Parallel(n_jobs=-1)]: Done 125778 tasks      | elapsed: 80.2min
# [Parallel(n_jobs=-1)]: Done 126273 tasks      | elapsed: 80.8min
# [Parallel(n_jobs=-1)]: Done 126768 tasks      | elapsed: 81.2min
# [Parallel(n_jobs=-1)]: Done 127265 tasks      | elapsed: 81.5min
# [Parallel(n_jobs=-1)]: Done 127762 tasks      | elapsed: 81.8min
# [Parallel(n_jobs=-1)]: Done 128261 tasks      | elapsed: 82.2min
# [Parallel(n_jobs=-1)]: Done 128760 tasks      | elapsed: 82.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19973772004835086s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 129261 tasks      | elapsed: 82.7min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1025904709250205s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 129881 tasks      | elapsed: 83.0min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1980704725477475s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.050977456270389s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 130503 tasks      | elapsed: 83.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19906210829942964s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0675249421253663s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19952244403061134s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 131164 tasks      | elapsed: 83.6min
# [Parallel(n_jobs=-1)]: Batch computation too slow (6.230260563165894s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 131732 tasks      | elapsed: 84.0min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19818882424673656s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.065190177060799s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 132356 tasks      | elapsed: 84.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19951557585791418s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.2782265965891813s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 132982 tasks      | elapsed: 84.6min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19929343175731626s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1598630782831223s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 133589 tasks      | elapsed: 85.0min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19924228670044455s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (3.0590261794060973s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 134178 tasks      | elapsed: 85.3min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19953377375600642s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.096709004570565s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 134789 tasks      | elapsed: 85.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1968182160324796s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1998113270217123s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 135419 tasks      | elapsed: 85.9min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1978510130320737s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.007032841467836s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19807591169253608s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 136053 tasks      | elapsed: 86.1min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1590041592438465s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1993317566058042s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1032129263748103s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 136781 tasks      | elapsed: 86.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19918021493806837s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (12.969671249389648s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 137316 tasks      | elapsed: 86.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19760735402144028s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 137831 tasks      | elapsed: 87.1min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.023296072391721s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19801364133447283s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1064301768141753s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 138565 tasks      | elapsed: 87.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19858929589586757s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0832485611657305s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19860700854230234s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 139183 tasks      | elapsed: 87.7min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.123216965719311s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19651222881316593s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (12.120425701141357s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 139861 tasks      | elapsed: 88.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19889286892151603s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (5.759037891550538s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 140459 tasks      | elapsed: 88.4min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19926783554542352s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (4.391430992510782s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19550478358230114s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.124690945380758s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 141169 tasks      | elapsed: 88.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19969982912639858s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (6.076575288802011s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 141780 tasks      | elapsed: 89.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19983969951135866s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.123600390838641s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19891052735762457s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 142472 tasks      | elapsed: 89.4min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.1184540487894528s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19849684269615503s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.12687268151296s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 143162 tasks      | elapsed: 89.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1985966290002887s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (4.502578588467486s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19765762091309771s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (7.516569641994852s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 143883 tasks      | elapsed: 90.2min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19923236459808386s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.240065167672709s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19761628517090782s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 144551 tasks      | elapsed: 90.5min
# [Parallel(n_jobs=-1)]: Batch computation too slow (6.889450416945239s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1975524331961423s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0600761535537133s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 145294 tasks      | elapsed: 90.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.197122888403638s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.0482085907399714s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1998855491517264s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done 145942 tasks      | elapsed: 91.1min
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.7889096111175538s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 146510 tasks      | elapsed: 91.4min
# [Parallel(n_jobs=-1)]: Done 147040 tasks      | elapsed: 91.8min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19979314134559412s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (20.030594844443396s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 147649 tasks      | elapsed: 92.1min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19968514117103772s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.139796296271369s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19930418577653264s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (11.235771417617798s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19948898582458502s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (2.071889432262274s.) Setting batch_size=1.
# [Parallel(n_jobs=-1)]: Done 148409 tasks      | elapsed: 92.5min
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.19921776820269999s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Batch computation too slow (3.0556960296082525s.) Setting batch_size=1.
# ...
# [Parallel(n_jobs=-1)]: Done 425925 tasks      | elapsed: 226.1min
# [Parallel(n_jobs=-1)]: Done 426832 tasks      | elapsed: 226.4min
# [Parallel(n_jobs=-1)]: Done 427741 tasks      | elapsed: 226.7min
# [Parallel(n_jobs=-1)]: Done 428650 tasks      | elapsed: 227.0min
# [Parallel(n_jobs=-1)]: Done 429561 tasks      | elapsed: 227.3min
# [Parallel(n_jobs=-1)]: Done 430472 tasks      | elapsed: 227.7min
# [Parallel(n_jobs=-1)]: Done 431385 tasks      | elapsed: 228.0min
# [Parallel(n_jobs=-1)]: Done 432298 tasks      | elapsed: 228.3min
# [Parallel(n_jobs=-1)]: Done 433213 tasks      | elapsed: 228.6min
# [Parallel(n_jobs=-1)]: Done 434128 tasks      | elapsed: 229.0min
# [Parallel(n_jobs=-1)]: Done 435045 tasks      | elapsed: 229.3min
# [Parallel(n_jobs=-1)]: Done 435962 tasks      | elapsed: 229.7min
# [Parallel(n_jobs=-1)]: Done 436881 tasks      | elapsed: 230.0min
# [Parallel(n_jobs=-1)]: Done 437800 tasks      | elapsed: 230.3min
# [Parallel(n_jobs=-1)]: Done 438721 tasks      | elapsed: 230.7min
# [Parallel(n_jobs=-1)]: Done 439642 tasks      | elapsed: 231.1min
# [Parallel(n_jobs=-1)]: Done 440565 tasks      | elapsed: 231.4min
# [Parallel(n_jobs=-1)]: Done 441488 tasks      | elapsed: 231.8min
# [Parallel(n_jobs=-1)]: Done 442413 tasks      | elapsed: 232.1min
# [Parallel(n_jobs=-1)]: Done 443338 tasks      | elapsed: 232.5min
# [Parallel(n_jobs=-1)]: Done 444265 tasks      | elapsed: 232.8min
# [Parallel(n_jobs=-1)]: Done 445192 tasks      | elapsed: 233.2min
# [Parallel(n_jobs=-1)]: Done 446121 tasks      | elapsed: 233.5min
# [Parallel(n_jobs=-1)]: Done 447050 tasks      | elapsed: 233.9min
# [Parallel(n_jobs=-1)]: Done 447981 tasks      | elapsed: 234.2min
# [Parallel(n_jobs=-1)]: Done 448912 tasks      | elapsed: 234.6min
# [Parallel(n_jobs=-1)]: Done 449845 tasks      | elapsed: 234.9min
# [Parallel(n_jobs=-1)]: Done 450778 tasks      | elapsed: 235.3min
# [Parallel(n_jobs=-1)]: Done 451713 tasks      | elapsed: 235.6min
# [Parallel(n_jobs=-1)]: Done 452648 tasks      | elapsed: 235.9min
# [Parallel(n_jobs=-1)]: Done 453585 tasks      | elapsed: 236.3min
# [Parallel(n_jobs=-1)]: Done 454522 tasks      | elapsed: 236.7min
# [Parallel(n_jobs=-1)]: Done 455461 tasks      | elapsed: 237.0min
# [Parallel(n_jobs=-1)]: Done 456400 tasks      | elapsed: 237.4min
# [Parallel(n_jobs=-1)]: Done 457341 tasks      | elapsed: 237.8min
# [Parallel(n_jobs=-1)]: Done 458282 tasks      | elapsed: 238.1min
# [Parallel(n_jobs=-1)]: Done 459225 tasks      | elapsed: 238.4min
# [Parallel(n_jobs=-1)]: Done 460168 tasks      | elapsed: 238.8min
# [Parallel(n_jobs=-1)]: Done 461113 tasks      | elapsed: 239.1min
# [Parallel(n_jobs=-1)]: Done 462058 tasks      | elapsed: 239.4min
# [Parallel(n_jobs=-1)]: Done 463005 tasks      | elapsed: 239.8min
# [Parallel(n_jobs=-1)]: Done 463952 tasks      | elapsed: 240.2min
# [Parallel(n_jobs=-1)]: Done 464901 tasks      | elapsed: 240.6min
# [Parallel(n_jobs=-1)]: Done 465850 tasks      | elapsed: 240.9min
# [Parallel(n_jobs=-1)]: Done 466801 tasks      | elapsed: 241.3min
# [Parallel(n_jobs=-1)]: Done 467752 tasks      | elapsed: 241.7min
# [Parallel(n_jobs=-1)]: Done 468705 tasks      | elapsed: 242.0min
# [Parallel(n_jobs=-1)]: Done 469658 tasks      | elapsed: 242.4min
# [Parallel(n_jobs=-1)]: Done 470613 tasks      | elapsed: 242.7min
# [Parallel(n_jobs=-1)]: Done 471568 tasks      | elapsed: 243.1min
# [Parallel(n_jobs=-1)]: Done 472525 tasks      | elapsed: 243.5min
# [Parallel(n_jobs=-1)]: Done 473482 tasks      | elapsed: 243.9min
# [Parallel(n_jobs=-1)]: Done 474441 tasks      | elapsed: 244.2min
# [Parallel(n_jobs=-1)]: Done 475400 tasks      | elapsed: 244.6min
# [Parallel(n_jobs=-1)]: Done 476361 tasks      | elapsed: 244.9min
# [Parallel(n_jobs=-1)]: Done 477322 tasks      | elapsed: 245.3min
# [Parallel(n_jobs=-1)]: Done 478285 tasks      | elapsed: 245.7min
# [Parallel(n_jobs=-1)]: Done 479248 tasks      | elapsed: 246.1min
# [Parallel(n_jobs=-1)]: Done 480213 tasks      | elapsed: 246.5min
# [Parallel(n_jobs=-1)]: Done 481178 tasks      | elapsed: 246.8min
# [Parallel(n_jobs=-1)]: Done 482145 tasks      | elapsed: 247.2min
# [Parallel(n_jobs=-1)]: Done 483112 tasks      | elapsed: 247.5min
# [Parallel(n_jobs=-1)]: Done 484081 tasks      | elapsed: 247.9min
# [Parallel(n_jobs=-1)]: Done 485050 tasks      | elapsed: 248.3min
# [Parallel(n_jobs=-1)]: Done 486021 tasks      | elapsed: 248.7min
# [Parallel(n_jobs=-1)]: Done 486992 tasks      | elapsed: 249.1min
# [Parallel(n_jobs=-1)]: Done 487965 tasks      | elapsed: 249.4min
# [Parallel(n_jobs=-1)]: Done 488938 tasks      | elapsed: 249.8min
# [Parallel(n_jobs=-1)]: Done 489913 tasks      | elapsed: 250.2min
# [Parallel(n_jobs=-1)]: Done 490888 tasks      | elapsed: 250.6min
# [Parallel(n_jobs=-1)]: Done 491865 tasks      | elapsed: 251.0min
# [Parallel(n_jobs=-1)]: Done 492842 tasks      | elapsed: 251.4min
# [Parallel(n_jobs=-1)]: Done 493821 tasks      | elapsed: 251.8min
# [Parallel(n_jobs=-1)]: Done 494800 tasks      | elapsed: 252.1min
# [Parallel(n_jobs=-1)]: Done 495781 tasks      | elapsed: 252.5min
# [Parallel(n_jobs=-1)]: Done 496762 tasks      | elapsed: 252.8min
# [Parallel(n_jobs=-1)]: Done 497745 tasks      | elapsed: 253.3min
# [Parallel(n_jobs=-1)]: Done 498728 tasks      | elapsed: 253.7min
# [Parallel(n_jobs=-1)]: Done 499713 tasks      | elapsed: 254.1min
# [Parallel(n_jobs=-1)]: Done 500698 tasks      | elapsed: 254.4min
# [Parallel(n_jobs=-1)]: Done 501685 tasks      | elapsed: 254.8min
# [Parallel(n_jobs=-1)]: Done 502672 tasks      | elapsed: 255.2min
# [Parallel(n_jobs=-1)]: Done 503661 tasks      | elapsed: 255.7min
# [Parallel(n_jobs=-1)]: Done 504650 tasks      | elapsed: 256.0min
# [Parallel(n_jobs=-1)]: Done 505641 tasks      | elapsed: 256.4min
# [Parallel(n_jobs=-1)]: Done 506632 tasks      | elapsed: 256.7min
# [Parallel(n_jobs=-1)]: Done 507625 tasks      | elapsed: 257.2min
# [Parallel(n_jobs=-1)]: Done 508618 tasks      | elapsed: 257.6min
# [Parallel(n_jobs=-1)]: Done 509613 tasks      | elapsed: 258.0min
# [Parallel(n_jobs=-1)]: Done 510608 tasks      | elapsed: 258.4min
# [Parallel(n_jobs=-1)]: Done 511605 tasks      | elapsed: 258.7min
# [Parallel(n_jobs=-1)]: Done 512602 tasks      | elapsed: 259.2min
# [Parallel(n_jobs=-1)]: Done 513601 tasks      | elapsed: 259.6min
# [Parallel(n_jobs=-1)]: Done 514600 tasks      | elapsed: 259.9min
# [Parallel(n_jobs=-1)]: Done 515601 tasks      | elapsed: 260.3min
# [Parallel(n_jobs=-1)]: Done 516602 tasks      | elapsed: 260.7min
# [Parallel(n_jobs=-1)]: Done 517605 tasks      | elapsed: 261.2min
# [Parallel(n_jobs=-1)]: Done 518608 tasks      | elapsed: 261.6min
# [Parallel(n_jobs=-1)]: Done 519613 tasks      | elapsed: 261.9min
# [Parallel(n_jobs=-1)]: Done 520618 tasks      | elapsed: 262.3min
# [Parallel(n_jobs=-1)]: Done 521625 tasks      | elapsed: 262.7min
# [Parallel(n_jobs=-1)]: Done 522632 tasks      | elapsed: 263.1min
# [Parallel(n_jobs=-1)]: Done 523641 tasks      | elapsed: 263.5min
# [Parallel(n_jobs=-1)]: Done 524650 tasks      | elapsed: 263.9min
# [Parallel(n_jobs=-1)]: Done 525661 tasks      | elapsed: 264.3min
# [Parallel(n_jobs=-1)]: Done 526672 tasks      | elapsed: 264.7min
# [Parallel(n_jobs=-1)]: Done 527685 tasks      | elapsed: 265.1min
# [Parallel(n_jobs=-1)]: Done 528698 tasks      | elapsed: 265.5min
# [Parallel(n_jobs=-1)]: Done 529713 tasks      | elapsed: 266.0min
# [Parallel(n_jobs=-1)]: Done 530728 tasks      | elapsed: 266.4min
# [Parallel(n_jobs=-1)]: Done 531745 tasks      | elapsed: 266.8min
# [Parallel(n_jobs=-1)]: Done 532762 tasks      | elapsed: 267.2min
# [Parallel(n_jobs=-1)]: Done 533781 tasks      | elapsed: 267.6min
# [Parallel(n_jobs=-1)]: Done 534800 tasks      | elapsed: 268.0min
# [Parallel(n_jobs=-1)]: Done 535821 tasks      | elapsed: 268.4min
# [Parallel(n_jobs=-1)]: Done 536842 tasks      | elapsed: 268.8min
# [Parallel(n_jobs=-1)]: Done 537865 tasks      | elapsed: 269.3min
# [Parallel(n_jobs=-1)]: Done 538888 tasks      | elapsed: 269.7min
# [Parallel(n_jobs=-1)]: Done 539913 tasks      | elapsed: 270.1min
# [Parallel(n_jobs=-1)]: Done 540938 tasks      | elapsed: 270.5min
# [Parallel(n_jobs=-1)]: Done 541965 tasks      | elapsed: 271.0min
# [Parallel(n_jobs=-1)]: Done 542992 tasks      | elapsed: 271.3min
# [Parallel(n_jobs=-1)]: Done 544021 tasks      | elapsed: 271.8min
# [Parallel(n_jobs=-1)]: Done 545050 tasks      | elapsed: 272.2min
# [Parallel(n_jobs=-1)]: Done 546081 tasks      | elapsed: 272.6min
# [Parallel(n_jobs=-1)]: Done 547112 tasks      | elapsed: 273.0min
# [Parallel(n_jobs=-1)]: Done 548145 tasks      | elapsed: 273.4min
# [Parallel(n_jobs=-1)]: Done 549178 tasks      | elapsed: 273.8min
# [Parallel(n_jobs=-1)]: Done 550213 tasks      | elapsed: 274.2min
# [Parallel(n_jobs=-1)]: Done 551248 tasks      | elapsed: 274.6min
# [Parallel(n_jobs=-1)]: Done 552285 tasks      | elapsed: 275.1min
# [Parallel(n_jobs=-1)]: Done 553322 tasks      | elapsed: 275.5min
# [Parallel(n_jobs=-1)]: Done 554361 tasks      | elapsed: 275.9min
# [Parallel(n_jobs=-1)]: Done 555400 tasks      | elapsed: 276.4min
# [Parallel(n_jobs=-1)]: Done 556441 tasks      | elapsed: 276.8min
# [Parallel(n_jobs=-1)]: Done 557482 tasks      | elapsed: 277.2min
# [Parallel(n_jobs=-1)]: Done 558525 tasks      | elapsed: 277.7min
# [Parallel(n_jobs=-1)]: Done 559568 tasks      | elapsed: 278.2min
# [Parallel(n_jobs=-1)]: Done 560613 tasks      | elapsed: 278.6min
# [Parallel(n_jobs=-1)]: Done 561658 tasks      | elapsed: 279.0min
# [Parallel(n_jobs=-1)]: Done 562705 tasks      | elapsed: 279.4min
# [Parallel(n_jobs=-1)]: Done 563752 tasks      | elapsed: 279.8min
# [Parallel(n_jobs=-1)]: Done 564801 tasks      | elapsed: 280.4min
# [Parallel(n_jobs=-1)]: Done 565850 tasks      | elapsed: 280.8min
# [Parallel(n_jobs=-1)]: Done 566901 tasks      | elapsed: 281.2min
# [Parallel(n_jobs=-1)]: Done 567952 tasks      | elapsed: 281.7min
# [Parallel(n_jobs=-1)]: Done 569005 tasks      | elapsed: 282.1min
# [Parallel(n_jobs=-1)]: Done 570058 tasks      | elapsed: 282.4min
# [Parallel(n_jobs=-1)]: Done 571113 tasks      | elapsed: 282.9min
# [Parallel(n_jobs=-1)]: Done 572168 tasks      | elapsed: 283.3min
# [Parallel(n_jobs=-1)]: Done 573225 tasks      | elapsed: 283.7min
# [Parallel(n_jobs=-1)]: Done 574282 tasks      | elapsed: 284.2min
# [Parallel(n_jobs=-1)]: Done 575341 tasks      | elapsed: 284.6min
# [Parallel(n_jobs=-1)]: Done 576400 tasks      | elapsed: 285.0min
# [Parallel(n_jobs=-1)]: Done 577461 tasks      | elapsed: 285.5min
# [Parallel(n_jobs=-1)]: Done 578522 tasks      | elapsed: 285.9min
# [Parallel(n_jobs=-1)]: Done 579585 tasks      | elapsed: 286.3min
# [Parallel(n_jobs=-1)]: Done 580648 tasks      | elapsed: 286.8min
# [Parallel(n_jobs=-1)]: Done 581713 tasks      | elapsed: 287.2min
# [Parallel(n_jobs=-1)]: Done 582778 tasks      | elapsed: 287.6min
# [Parallel(n_jobs=-1)]: Done 583845 tasks      | elapsed: 288.1min
# [Parallel(n_jobs=-1)]: Done 584912 tasks      | elapsed: 288.5min
# [Parallel(n_jobs=-1)]: Done 585981 tasks      | elapsed: 289.0min
# [Parallel(n_jobs=-1)]: Done 587050 tasks      | elapsed: 289.4min
# [Parallel(n_jobs=-1)]: Done 588121 tasks      | elapsed: 289.9min
# [Parallel(n_jobs=-1)]: Done 589192 tasks      | elapsed: 290.4min
# [Parallel(n_jobs=-1)]: Done 590265 tasks      | elapsed: 290.8min
# [Parallel(n_jobs=-1)]: Done 591338 tasks      | elapsed: 291.3min
# [Parallel(n_jobs=-1)]: Done 592413 tasks      | elapsed: 291.7min
# [Parallel(n_jobs=-1)]: Done 593488 tasks      | elapsed: 292.1min
# [Parallel(n_jobs=-1)]: Done 594565 tasks      | elapsed: 292.6min
# [Parallel(n_jobs=-1)]: Done 595642 tasks      | elapsed: 293.1min
# [Parallel(n_jobs=-1)]: Done 596721 tasks      | elapsed: 293.6min
# [Parallel(n_jobs=-1)]: Done 597800 tasks      | elapsed: 294.0min
# [Parallel(n_jobs=-1)]: Done 598881 tasks      | elapsed: 294.4min
# [Parallel(n_jobs=-1)]: Done 599962 tasks      | elapsed: 294.9min
# [Parallel(n_jobs=-1)]: Done 601045 tasks      | elapsed: 295.4min
# [Parallel(n_jobs=-1)]: Done 602128 tasks      | elapsed: 295.9min
# [Parallel(n_jobs=-1)]: Done 603213 tasks      | elapsed: 296.3min
# [Parallel(n_jobs=-1)]: Done 604298 tasks      | elapsed: 296.7min
# [Parallel(n_jobs=-1)]: Done 605385 tasks      | elapsed: 297.2min
# [Parallel(n_jobs=-1)]: Done 606472 tasks      | elapsed: 297.6min
# [Parallel(n_jobs=-1)]: Done 607561 tasks      | elapsed: 298.1min
# [Parallel(n_jobs=-1)]: Done 608650 tasks      | elapsed: 298.6min
# [Parallel(n_jobs=-1)]: Done 609741 tasks      | elapsed: 299.1min
# [Parallel(n_jobs=-1)]: Done 610832 tasks      | elapsed: 299.6min
# [Parallel(n_jobs=-1)]: Done 611925 tasks      | elapsed: 300.0min
# [Parallel(n_jobs=-1)]: Done 613018 tasks      | elapsed: 300.5min
# [Parallel(n_jobs=-1)]: Done 614113 tasks      | elapsed: 300.9min
# [Parallel(n_jobs=-1)]: Done 615208 tasks      | elapsed: 301.4min
# [Parallel(n_jobs=-1)]: Done 616305 tasks      | elapsed: 301.9min
# [Parallel(n_jobs=-1)]: Done 617402 tasks      | elapsed: 302.4min
# [Parallel(n_jobs=-1)]: Done 618501 tasks      | elapsed: 302.8min
# [Parallel(n_jobs=-1)]: Done 619600 tasks      | elapsed: 303.2min
# [Parallel(n_jobs=-1)]: Done 620701 tasks      | elapsed: 303.8min
# [Parallel(n_jobs=-1)]: Done 621802 tasks      | elapsed: 304.2min
# [Parallel(n_jobs=-1)]: Done 622905 tasks      | elapsed: 304.7min
# [Parallel(n_jobs=-1)]: Done 624008 tasks      | elapsed: 305.1min
# [Parallel(n_jobs=-1)]: Done 625113 tasks      | elapsed: 305.6min
# [Parallel(n_jobs=-1)]: Done 626218 tasks      | elapsed: 306.1min
# [Parallel(n_jobs=-1)]: Done 627325 tasks      | elapsed: 306.6min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 332
#     329 os.environ.setdefault("OMP_NUM_THREADS", "1")
#     331 # Run grid in parallel
# --> 332 results = Parallel(n_jobs=-1, backend="loky", verbose=10)(
#     333     delayed(solve_point)(U, mu)
#     334     for U in U_vals
#     335     for mu in mu_vals
#     336 )
#     338 # Keep rows ordered (U major, then mu)
#     339 results.sort(key=lambda r: (r[1], r[2]))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:
