# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score
from matplotlib.colors import ListedColormap

import tensorflow as tf
from tensorflow import keras
from scikeras.wrappers import KerasClassifier
from pytorch_tabnet.tab_model import TabNetClassifier


# Callback to ramp lam_phys in model.loss via attribute; implement as example where model has attribute lam_phys
import tensorflow as tf

class LambdaRamp(tf.keras.callbacks.Callback):
    def __init__(self, start_epoch, end_epoch, final_value):
        self.start = start_epoch
        self.end = end_epoch
        self.final = final_value
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            val = 0.0
        elif epoch >= self.end:
            val = self.final
        else:
            val = (epoch - self.start)/(self.end - self.start) * self.final
        # store in model for your physics loss lambda to read
        setattr(self.model, "lam_phys_current", float(val))
        # optional logging
        print(f"Epoch {epoch}: lam_phys_current={val:.6f}")

# Modify physics loss lambda in compile to read model.lam_phys_current; easiest: implement phys loss using closure that reads model attribute
# Example usage:
ramp_cb = LambdaRamp(start_epoch=5, end_epoch=40, final_value=1.0)
# pass ramp_cb to fit callbacks


import numpy as np, pandas as pd

# Label: 1 = Superfluid, 0 = Mott
def label_phase(rho, phi2, tol_rho=1e-3, tol_phi=1e-6):
    """
    Classify phase:
    - Mott insulator if (rho ~ integer) and (phi^2 ~ 0).
    - Superfluid otherwise.
    """
    is_integer_rho = np.isclose(rho, np.round(rho), atol=tol_rho)
    is_zero_phi = phi2 < tol_phi
    
    if is_integer_rho and is_zero_phi:
        return 0  # Mott
    else:
        return 1  # Superflud

# ---------- 1) Load and label ----------
df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# Apply physics-based labeling (optional, but consistent)
df["Phase"] = df.apply(lambda row: label_phase(row["Density"], row["Phi2"]), axis=1)

# # --- 1) Load dataset ---
# df = pd.read_csv("phase_t1.0_U25.0-(0.1)_Mu60.0-(0.1).csv")

# # Phase label
# df["Phase"] = (df["Phi2"] > 1e-6).astype(int)

print(df)



# --- 1) Load data ---
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# # Load dataset
# df = reduced_df

# print(df)

# df_MI = df[
#     (df["Phi2"] < 1e-8) &
#     (np.isclose(df["Density"], np.round(df["Density"]), atol=1e-3))
# ]

# # --- pick deep SF (large phi2) ---
# df_SF = df[df["Phi2"] > 1e-2]

# # --- pick boundary (ambiguous region) ---
# df_boundary = df[
#     (df["Phi2"] > 1e-6) & (df["Phi2"] < 1e-2)
# ]

# ------------------------------
# Smart sampling strategy
# # ------------------------------
# n_MI = min(2000, len(df_MI))             # cap deep MI
# n_SF = min(2000, len(df_SF))             # cap deep SF
# n_boundary = min(6000, len(df_boundary)) # oversample boundary

# # n_MI = min(5000, len(df_MI))
# # n_SF = min(5000, len(df_SF))
# # n_boundary = min(10000, len(df_boundary))

# # n_MI = min(3000, len(df_MI))
# # n_SF = min(3000, len(df_SF))
# # n_boundary = min(6000, len(df_boundary))


# df_reduced = pd.concat([
#     df_MI.sample(n_MI, random_state=42),
#     df_SF.sample(n_SF, random_state=42),
#     df_boundary.sample(n_boundary, random_state=42)
# ])
# print(df)
# df_reduced = df_reduced.reset_index(drop=True)
# # Use reduced dataset
# df = df_reduced.reset_index(drop=True)
# print(df)


# print("Reduced dataset summary:")
# print(df_reduced["Phase"].value_counts())

# Ground truth plots from dataset
plt.figure(figsize=(12,4))

# 1) Phase diagram
plt.subplot(1,3,1)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm"
)
plt.colorbar(label="Phase (0=Mott, 1=SF)")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Phase Diagram")

# 2) Phi²
plt.subplot(1,3,2)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis"
)
plt.colorbar(label="φ²")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Condensate fraction φ²")

# 3) Density
plt.subplot(1,3,3)
plt.tricontourf(
    df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma"
)
plt.colorbar(label="ρ")
plt.xlabel("Ū")
plt.ylabel("μ̄")
plt.title("Ground Truth Density ρ")

plt.tight_layout()
plt.show()
# Features and targets
X = df[["Ubar","Mubar"]].values.astype(np.float32)
y = {
    "phase": df["Phase"].values.astype(np.float32),
    "phi2": df["Phi2"].values.astype(np.float32),
    "rho": df["Density"].values.astype(np.float32),
}

# 1) Bayesian surrogate (with dropout active)
def build_bayesian_surrogate(hidden=(128,64), dropout_rate=0.2):
    inp = keras.Input(shape=(2,))
    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="relu")(x)
        x = layers.Dropout(dropout_rate)(x, training=True)  # key: active dropout
    out = layers.Dense(2, activation="linear")(x)  # [phi2, rho]
    return keras.Model(inp, out)

# bayes_surrogate = build_bayesian_surrogate()
# bayes_surrogate.compile(optimizer="adam", loss="mse")

X_surr = df[["Ubar","Mubar"]].values.astype(np.float32)
y_surr = df[["Phi2","Density"]].values.astype(np.float32)

# surrogate = build_surrogate()
# surrogate.fit(
#     X_surr, y_surr,
#     epochs=200, batch_size=512,
#     validation_split=0.15, verbose=1
# )

bayes_surrogate = build_bayesian_surrogate()
bayes_surrogate.compile(optimizer="adam", loss="mse")
# Train Bayesian surrogate
bayes_surrogate.fit(X_surr, y_surr, epochs=200, batch_size=512,
                    validation_split=0.15, verbose=1)

bayes_surrogate.trainable = False

# 2) PINN with Bayesian surrogate in physics residual
def make_pinn_with_bayesian_surrogate(hidden=(128,64), lam_phase=1.0, lam_phys=1.0):
    inp = keras.Input(shape=(2,), name="input")   # [Ubar, Mubar]
    lam_phys_var = tf.Variable(lam_phys, trainable=False, dtype=tf.float32, name="lam_phys")
    x = inp
    for h in hidden:
        x = layers.Dense(h, activation="tanh")(x)

    phase_out = layers.Dense(1, activation="sigmoid", name="phase")(x)
    phi_out   = layers.Dense(1, activation="relu", name="phi2")(x)
    rho_out   = layers.Dense(1, activation="relu", name="rho")(x)

    # Physics residual (using dropout surrogate)
    def phys_residual(inputs):
        UMb, phi_pred = inputs
        s = bayes_surrogate(UMb, training=True)     # Bayesian surrogate (dropout ON)
        s_phi = tf.expand_dims(s[:,0], -1)
        return phi_pred - s_phi

    phys_out = layers.Lambda(lambda t: phys_residual(t), name="phys_res")([inp, phi_out])

    model = keras.Model(inputs=inp, outputs=[phase_out, phi_out, rho_out, phys_out])

    losses = {
        "phase": "binary_crossentropy",
        "phi2": "mse",
        "rho": "mse",
        "phys_res": lambda y_true, y_pred: lam_phys_var * tf.reduce_mean(tf.square(y_pred))
    }
    loss_weights = {"phase": lam_phase, "phi2": 1.0, "rho": 1.0, "phys_res": 1.0}

    model.compile(
        optimizer=keras.optimizers.Adam(1e-3),
        loss=losses,
        loss_weights=loss_weights,
        metrics={"phase":"accuracy"}
    )
    model.lam_phys = lam_phys_var
    return model

pinn_bnn = make_pinn_with_bayesian_surrogate()

# 3) Train PINN-BNN
y_targets = {
    "phase": df["Phase"].values.reshape(-1,1),
    "phi2":  df["Phi2"].values.reshape(-1,1),
    "rho":   df["Density"].values.reshape(-1,1),
    "phys_res": np.zeros((len(df),1))
}

ramp_cb = LambdaRamp(start_epoch=5, end_epoch=40, final_value=1.0)
pinn_bnn.fit(
    X, y_targets,
    batch_size=256,
    epochs=200,
    validation_split=0.15,
    callbacks=[ramp_cb]
)

# 4) MC Prediction (PINN + Bayesian surrogate uncertainty)
def mc_predict_pinn(model, X, n=50):
    preds_phase, preds_phi2, preds_rho = [], [], []
    for _ in range(n):
        p_phase, p_phi2, p_rho, _ = model(X, training=True)
        preds_phase.append(p_phase.numpy())
        preds_phi2.append(p_phi2.numpy())
        preds_rho.append(p_rho.numpy())
    return (
        np.mean(preds_phase, axis=0), np.std(preds_phase, axis=0),
        np.mean(preds_phi2, axis=0), np.std(preds_phi2, axis=0),
        np.mean(preds_rho, axis=0), np.std(preds_rho, axis=0),
    )

# ramp_cb = LambdaRamp(start_epoch=5, end_epoch=40, final_value=1.0)
# history = pinn_surrogate.fit(
#     X, y_targets,
#     batch_size=256,
#     epochs=200,
#     validation_split=0.15,
#     callbacks=[
#         keras.callbacks.ReduceLROnPlateau(patience=8, factor=0.5),ramp_cb
#         # keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, restore_best_weights=True)
#     ]
# )
# --- 5) Phase diagram prediction (PINN + Bayesian surrogate) ---
U_vals = np.linspace(0, 25, 200)   # Ū axis
mu_vals = np.linspace(0, 60, 200)  # μ̄ axis
UU, MU = np.meshgrid(U_vals, mu_vals)
X_grid = np.stack([UU.ravel(), MU.ravel()], axis=1).astype(np.float32)

# MC prediction over N passes
phase_mean, phase_std, phi2_mean, phi2_std, rho_mean, rho_std = mc_predict_pinn(pinn_bnn, X_grid, n=50)

# Reshape to grid
phase_pred_class = (phase_mean > 0.5).astype(int)
phase_mean = phase_mean.reshape(UU.shape)
phase_std  = phase_std.reshape(UU.shape)
phi2_mean  = phi2_mean.reshape(UU.shape)
rho_mean   = rho_mean.reshape(UU.shape)


# --- reshape outputs properly ---
phase_pred_class = (phase_mean > 0.5).astype(int)
phase_pred_class = phase_pred_class.reshape(UU.shape)  # <-- important fix

# --- Plot predicted phase, φ², ρ and uncertainty ---
plt.figure(figsize=(18,4))

# Phase diagram
plt.subplot(1,4,1)
mappable = plt.contourf(UU, MU, phase_pred_class, levels=[-0.5,0.5,1.5], cmap="coolwarm")
plt.colorbar(mappable, ticks=[0,1], label="Phase (0=Mott,1=SF)")
plt.contour(UU, MU, phase_mean, levels=[0.5], colors="k", linewidths=1.2)
# plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Predicted Phase Diagram")
plt.xlabel("U",fontsize=10,fontweight="bold")
plt.ylabel("μ̄",fontsize=10, fontweight="bold")
plt.title("Phase Diagram",fontsize=12, fontweight="bold")
plt.grid(True)
plt.savefig('Full-Pinn-bayesian', dpi=300, bbox_inches='tight')


# φ² diagram
plt.subplot(1,4,2)
mappable = plt.contourf(UU, MU, phi2_mean, 50, cmap="viridis")
plt.colorbar(mappable, label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Predicted φ²")

# ρ diagram
plt.subplot(1,4,3)
mappable = plt.contourf(UU, MU, rho_mean, 50, cmap="plasma")
plt.colorbar(mappable, label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Predicted ρ")

# Phase uncertainty
plt.subplot(1,4,4)
mappable = plt.contourf(UU, MU, phase_std, 50, cmap="magma")
plt.colorbar(mappable, label="σ(phase)")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Phase Uncertainty")
plt.tight_layout(); plt.show()

# --- Compute errors on grid ---
from scipy.interpolate import griddata
points = df[["Ubar","Mubar"]].values
phi2_true_interp = griddata(points, df["Phi2"].values, (UU, MU), method="linear")
rho_true_interp  = griddata(points, df["Density"].values, (UU, MU), method="linear")

phi2_err = phi2_mean - phi2_true_interp
rho_err  = rho_mean - rho_true_interp

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.contourf(UU, MU, phi2_err, 50, cmap="coolwarm")
plt.colorbar(label="φ² error")
plt.title("φ² prediction error")

plt.subplot(1,2,2)
plt.contourf(UU, MU, rho_err, 50, cmap="coolwarm")
plt.colorbar(label="ρ error")
plt.title("ρ prediction error")
plt.tight_layout(); plt.show()

# --- Ground truth for comparison ---
plt.figure(figsize=(12,4))
plt.subplot(1,3,1)
plt.tricontourf(df["Ubar"], df["Mubar"], df["Phase"], levels=1, cmap="coolwarm")
plt.colorbar(label="Phase (0=Mott,1=SF)")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Ground Truth Phase Diagram")

plt.subplot(1,3,2)
plt.tricontourf(df["Ubar"], df["Mubar"], df["Phi2"], 50, cmap="viridis")
plt.colorbar(label="φ²")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Ground Truth φ²")

plt.subplot(1,3,3)
plt.tricontourf(df["Ubar"], df["Mubar"], df["Density"], 50, cmap="plasma")
plt.colorbar(label="ρ")
plt.xlabel("Ū"); plt.ylabel("μ̄"); plt.title("Ground Truth ρ")
plt.tight_layout(); plt.show()

# # --- Classification report on training data ---
# y_pred_labels = (phase_mean.ravel() > 0.5).astype(int)
# y_true_labels = df["Phase"].astype(int).ravel()

# from sklearn.metrics import classification_report
# print("\n📊 Classification Report (Phase, PINN + Bayesian):")
# print(classification_report(y_true_labels, y_pred_labels, digits=4))
from scipy.interpolate import griddata

phase_true_grid = griddata(
    df[["Ubar","Mubar"]].values, 
    df["Phase"].values, 
    (UU, MU), 
    method="linear"
)

y_true_labels_grid = (phase_true_grid.ravel() > 0.5).astype(int)
y_pred_labels_grid = phase_pred_class.ravel()

from sklearn.metrics import classification_report
print("\n📊 Classification Report (Phase, PINN + Bayesian, Grid):")
print(classification_report(y_true_labels_grid, y_pred_labels_grid, digits=4))
# Out:
#           t  Ubar  Mubar       Density          Phi2        Energy  Iters  \
# 0       1.0   0.0   -5.0  1.048576e-14  1.048576e-14  2.097152e-13      8
# 1       1.0   0.0   -4.9  1.508449e-14  1.508449e-14  2.882646e-13      8
# 2       1.0   0.0   -4.8  2.186340e-14  2.186340e-14  3.987884e-13      8
# 3       1.0   0.0   -4.7  3.193733e-14  3.193733e-14  5.553901e-13      8
# 4       1.0   0.0   -4.6  4.703477e-14  4.703477e-14  7.788958e-13      8
# ...     ...   ...    ...           ...           ...           ...    ...
# 163396  1.0  25.0   59.6  3.000000e+00  8.530376e-13 -1.038000e+02     21
# 163397  1.0  25.0   59.7  3.000000e+00  7.586920e-13 -1.041000e+02     21
# 163398  1.0  25.0   59.8  3.000000e+00  6.791729e-13 -1.044000e+02     21
# 163399  1.0  25.0   59.9  3.000000e+00  6.119027e-13 -1.047000e+02     21
# 163400  1.0  25.0   60.0  3.000000e+00  5.548081e-13 -1.050000e+02     21
#
#         Phase
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 163396      0
# 163397      0
# 163398      0
# 163399      0
# 163400      0
#
# [163401 rows x 8 columns]
# Epoch 1/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7420 - val_loss: 0.0853
# Epoch 2/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5347 - val_loss: 0.1517
# Epoch 3/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3202 - val_loss: 0.0704
# Epoch 4/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2540 - val_loss: 0.0566
# Epoch 5/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1958 - val_loss: 0.0401
# Epoch 6/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1650 - val_loss: 0.0359
# Epoch 7/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1452 - val_loss: 0.0389
# Epoch 8/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1319 - val_loss: 0.0337
# Epoch 9/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1210 - val_loss: 0.0346
# Epoch 10/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1131 - val_loss: 0.0334
# Epoch 11/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1056 - val_loss: 0.0316
# Epoch 12/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0986 - val_loss: 0.0300
# Epoch 13/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0917 - val_loss: 0.0249
# Epoch 14/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0858 - val_loss: 0.0232
# Epoch 15/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0825 - val_loss: 0.0210
# Epoch 16/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0798 - val_loss: 0.0197
# Epoch 17/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0778 - val_loss: 0.0210
# Epoch 18/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0747 - val_loss: 0.0193
# Epoch 19/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0721 - val_loss: 0.0188
# Epoch 20/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0700 - val_loss: 0.0177
# Epoch 21/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0676 - val_loss: 0.0136
# Epoch 22/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0645 - val_loss: 0.0136
# Epoch 23/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0627 - val_loss: 0.0122
# Epoch 24/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0609 - val_loss: 0.0131
# Epoch 25/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0600 - val_loss: 0.0110
# Epoch 26/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0589 - val_loss: 0.0131
# Epoch 27/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0585 - val_loss: 0.0117
# Epoch 28/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0573 - val_loss: 0.0102
# Epoch 29/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0562 - val_loss: 0.0094
# Epoch 30/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554 - val_loss: 0.0122
# Epoch 31/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0545 - val_loss: 0.0111
# Epoch 32/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0541 - val_loss: 0.0085
# Epoch 33/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0535 - val_loss: 0.0104
# Epoch 34/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - val_loss: 0.0077
# Epoch 35/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0527 - val_loss: 0.0086
# Epoch 36/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0524 - val_loss: 0.0091
# Epoch 37/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - val_loss: 0.0082
# Epoch 38/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0509 - val_loss: 0.0064
# Epoch 39/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0502 - val_loss: 0.0080
# Epoch 40/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0501 - val_loss: 0.0086
# Epoch 41/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0499 - val_loss: 0.0090
# Epoch 42/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0498 - val_loss: 0.0063
# Epoch 43/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0490 - val_loss: 0.0084
# Epoch 44/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0489 - val_loss: 0.0088
# Epoch 45/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0489 - val_loss: 0.0107
# Epoch 46/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0487 - val_loss: 0.0089
# Epoch 47/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0488 - val_loss: 0.0109
# Epoch 48/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0487 - val_loss: 0.0076
# Epoch 49/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0483 - val_loss: 0.0088
# Epoch 50/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0478 - val_loss: 0.0108
# Epoch 51/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0482 - val_loss: 0.0101
# Epoch 52/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0476 - val_loss: 0.0123
# Epoch 53/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0470 - val_loss: 0.0069
# Epoch 54/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0469 - val_loss: 0.0081
# Epoch 55/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0466 - val_loss: 0.0070
# Epoch 56/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0461 - val_loss: 0.0061
# Epoch 57/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0456 - val_loss: 0.0068
# Epoch 58/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0456 - val_loss: 0.0077
# Epoch 59/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0449 - val_loss: 0.0076
# Epoch 60/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0447 - val_loss: 0.0077
# Epoch 61/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0450 - val_loss: 0.0065
# Epoch 62/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0444 - val_loss: 0.0069
# Epoch 63/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0442 - val_loss: 0.0063
# Epoch 64/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0442 - val_loss: 0.0055
# Epoch 65/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0439 - val_loss: 0.0056
# Epoch 66/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0446 - val_loss: 0.0092
# Epoch 67/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0439 - val_loss: 0.0058
# Epoch 68/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - val_loss: 0.0079
# Epoch 69/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - val_loss: 0.0047
# Epoch 70/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0439 - val_loss: 0.0066
# Epoch 71/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0436 - val_loss: 0.0063
# Epoch 72/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0441 - val_loss: 0.0096
# Epoch 73/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0440 - val_loss: 0.0060
# Epoch 74/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - val_loss: 0.0070
# Epoch 75/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0437 - val_loss: 0.0059
# Epoch 76/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0438 - val_loss: 0.0070
# Epoch 77/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0438 - val_loss: 0.0052
# Epoch 78/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - val_loss: 0.0079
# Epoch 79/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0438 - val_loss: 0.0068
# Epoch 80/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0437 - val_loss: 0.0087
# Epoch 81/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - val_loss: 0.0062
# Epoch 82/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - val_loss: 0.0081
# Epoch 83/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0431 - val_loss: 0.0086
# Epoch 84/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0433 - val_loss: 0.0069
# Epoch 85/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0431 - val_loss: 0.0061
# Epoch 86/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0433 - val_loss: 0.0067
# Epoch 87/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0432 - val_loss: 0.0059
# Epoch 88/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - val_loss: 0.0094
# Epoch 89/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0431 - val_loss: 0.0074
# Epoch 90/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0430 - val_loss: 0.0076
# Epoch 91/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - val_loss: 0.0049
# Epoch 92/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - val_loss: 0.0088
# Epoch 93/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0428 - val_loss: 0.0083
# Epoch 94/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0432 - val_loss: 0.0084
# Epoch 95/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0058
# Epoch 96/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - val_loss: 0.0052
# Epoch 97/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0432 - val_loss: 0.0062
# Epoch 98/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430 - val_loss: 0.0048
# Epoch 99/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0061
# Epoch 100/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - val_loss: 0.0050
# Epoch 101/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0092
# Epoch 102/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - val_loss: 0.0072
# Epoch 103/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0427 - val_loss: 0.0064
# Epoch 104/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - val_loss: 0.0065
# Epoch 105/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - val_loss: 0.0082
# Epoch 106/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - val_loss: 0.0049
# Epoch 107/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - val_loss: 0.0074
# Epoch 108/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - val_loss: 0.0057
# Epoch 109/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0427 - val_loss: 0.0059
# Epoch 110/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0427 - val_loss: 0.0047
# Epoch 111/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0072
# Epoch 112/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - val_loss: 0.0075
# Epoch 113/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - val_loss: 0.0072
# Epoch 114/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0427 - val_loss: 0.0058
# Epoch 115/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0071
# Epoch 116/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0420 - val_loss: 0.0066
# Epoch 117/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0422 - val_loss: 0.0124
# Epoch 118/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0067
# Epoch 119/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0422 - val_loss: 0.0055
# Epoch 120/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0426 - val_loss: 0.0073
# Epoch 121/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0421 - val_loss: 0.0056
# Epoch 122/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0420 - val_loss: 0.0074
# Epoch 123/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0421 - val_loss: 0.0075
# Epoch 124/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0421 - val_loss: 0.0060
# Epoch 125/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0421 - val_loss: 0.0077
# Epoch 126/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0420 - val_loss: 0.0057
# Epoch 127/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0419 - val_loss: 0.0059
# Epoch 128/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0419 - val_loss: 0.0092
# Epoch 129/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0418 - val_loss: 0.0071
# Epoch 130/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0417 - val_loss: 0.0064
# Epoch 131/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0413 - val_loss: 0.0074
# Epoch 132/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0412 - val_loss: 0.0068
# Epoch 133/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0412 - val_loss: 0.0054
# Epoch 134/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0409 - val_loss: 0.0065
# Epoch 135/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0061
# Epoch 136/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0051
# Epoch 137/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0413 - val_loss: 0.0060
# Epoch 138/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0065
# Epoch 139/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0052
# Epoch 140/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0412 - val_loss: 0.0079
# Epoch 141/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0409 - val_loss: 0.0080
# Epoch 142/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0411 - val_loss: 0.0070
# Epoch 143/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0048
# Epoch 144/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0410 - val_loss: 0.0058
# Epoch 145/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0094
# Epoch 146/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0408 - val_loss: 0.0058
# Epoch 147/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0069
# Epoch 148/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0095
# Epoch 149/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0051
# Epoch 150/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0409 - val_loss: 0.0053
# Epoch 151/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0405 - val_loss: 0.0046
# Epoch 152/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0062
# Epoch 153/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0062
# Epoch 154/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0408 - val_loss: 0.0051
# Epoch 155/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0404 - val_loss: 0.0075
# Epoch 156/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0071
# Epoch 157/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0407 - val_loss: 0.0076
# Epoch 158/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0053
# Epoch 159/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0405 - val_loss: 0.0087
# Epoch 160/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - val_loss: 0.0052
# Epoch 161/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0057
# Epoch 162/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - val_loss: 0.0080
# Epoch 163/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0402 - val_loss: 0.0061
# Epoch 164/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - val_loss: 0.0056
# Epoch 165/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - val_loss: 0.0051
# Epoch 166/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0403 - val_loss: 0.0049
# Epoch 167/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0404 - val_loss: 0.0055
# Epoch 168/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0060
# Epoch 169/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - val_loss: 0.0057
# Epoch 170/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - val_loss: 0.0060
# Epoch 171/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0397 - val_loss: 0.0048
# Epoch 172/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - val_loss: 0.0057
# Epoch 173/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0067
# Epoch 174/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0071
# Epoch 175/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0404 - val_loss: 0.0051
# Epoch 176/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0397 - val_loss: 0.0064
# Epoch 177/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - val_loss: 0.0059
# Epoch 178/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - val_loss: 0.0066
# Epoch 179/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - val_loss: 0.0056
# Epoch 180/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - val_loss: 0.0066
# Epoch 181/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - val_loss: 0.0052
# Epoch 182/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - val_loss: 0.0073
# Epoch 183/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - val_loss: 0.0107
# Epoch 184/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - val_loss: 0.0066
# Epoch 185/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0397 - val_loss: 0.0059
# Epoch 186/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - val_loss: 0.0061
# Epoch 187/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0399 - val_loss: 0.0057
# Epoch 188/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - val_loss: 0.0063
# Epoch 189/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0403 - val_loss: 0.0072
# Epoch 190/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - val_loss: 0.0049
# Epoch 191/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - val_loss: 0.0050
# Epoch 192/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0064
# Epoch 193/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - val_loss: 0.0047
# Epoch 194/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - val_loss: 0.0073
# Epoch 195/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0397 - val_loss: 0.0058
# Epoch 196/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0400 - val_loss: 0.0057
# Epoch 197/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0397 - val_loss: 0.0061
# Epoch 198/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0397 - val_loss: 0.0082
# Epoch 199/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0080
# Epoch 200/200
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - val_loss: 0.0072
# WARNING:tensorflow:From C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0: lam_phys_current=0.000000
# Epoch 1/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.7370 - phase_accuracy: 0.8200 - phase_loss: 0.3820 - phi2_loss: 0.1177 - phys_res_loss: 0.1138 - rho_loss: 0.1231 - val_loss: 0.4956 - val_phase_accuracy: 0.7827 - val_phase_loss: 0.3994 - val_phi2_loss: 0.0405 - val_phys_res_loss: 0.0345 - val_rho_loss: 0.0222
# Epoch 1: lam_phys_current=0.000000
# Epoch 2/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2729 - phase_accuracy: 0.9310 - phase_loss: 0.1801 - phi2_loss: 0.0401 - phys_res_loss: 0.0442 - rho_loss: 0.0085 - val_loss: 0.3038 - val_phase_accuracy: 0.8603 - val_phase_loss: 0.2393 - val_phi2_loss: 0.0253 - val_phys_res_loss: 0.0248 - val_rho_loss: 0.0154
# Epoch 2: lam_phys_current=0.000000
# Epoch 3/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1533 - phase_accuracy: 0.9733 - phase_loss: 0.1004 - phi2_loss: 0.0183 - phys_res_loss: 0.0287 - rho_loss: 0.0057 - val_loss: 0.1801 - val_phase_accuracy: 0.9434 - val_phase_loss: 0.1368 - val_phi2_loss: 0.0138 - val_phys_res_loss: 0.0210 - val_rho_loss: 0.0090
# Epoch 3: lam_phys_current=0.000000
# Epoch 4/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1016 - phase_accuracy: 0.9835 - phase_loss: 0.0644 - phi2_loss: 0.0094 - phys_res_loss: 0.0238 - rho_loss: 0.0040 - val_loss: 0.1032 - val_phase_accuracy: 0.9716 - val_phase_loss: 0.0800 - val_phi2_loss: 0.0051 - val_phys_res_loss: 0.0130 - val_rho_loss: 0.0055
# Epoch 4: lam_phys_current=0.000000
# Epoch 5/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0810 - phase_accuracy: 0.9870 - phase_loss: 0.0485 - phi2_loss: 0.0064 - phys_res_loss: 0.0233 - rho_loss: 0.0029 - val_loss: 0.0871 - val_phase_accuracy: 0.9700 - val_phase_loss: 0.0664 - val_phi2_loss: 0.0044 - val_phys_res_loss: 0.0128 - val_rho_loss: 0.0038
# Epoch 5: lam_phys_current=0.000000
# Epoch 6/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0693 - phase_accuracy: 0.9886 - phase_loss: 0.0398 - phi2_loss: 0.0049 - phys_res_loss: 0.0227 - rho_loss: 0.0020 - val_loss: 0.0773 - val_phase_accuracy: 0.9737 - val_phase_loss: 0.0584 - val_phi2_loss: 0.0035 - val_phys_res_loss: 0.0126 - val_rho_loss: 0.0031
# Epoch 6: lam_phys_current=0.028571
# Epoch 7/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0614 - phase_accuracy: 0.9901 - phase_loss: 0.0337 - phi2_loss: 0.0039 - phys_res_loss: 0.0223 - rho_loss: 0.0015 - val_loss: 0.0658 - val_phase_accuracy: 0.9827 - val_phase_loss: 0.0472 - val_phi2_loss: 0.0038 - val_phys_res_loss: 0.0126 - val_rho_loss: 0.0024
# Epoch 7: lam_phys_current=0.057143
# Epoch 8/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0576 - phase_accuracy: 0.9904 - phase_loss: 0.0300 - phi2_loss: 0.0038 - phys_res_loss: 0.0227 - rho_loss: 0.0012 - val_loss: 0.0612 - val_phase_accuracy: 0.9826 - val_phase_loss: 0.0423 - val_phi2_loss: 0.0037 - val_phys_res_loss: 0.0126 - val_rho_loss: 0.0028
# Epoch 8: lam_phys_current=0.085714
# Epoch 9/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0558 - phase_accuracy: 0.9905 - phase_loss: 0.0280 - phi2_loss: 0.0037 - phys_res_loss: 0.0230 - rho_loss: 0.0012 - val_loss: 0.0488 - val_phase_accuracy: 0.9927 - val_phase_loss: 0.0286 - val_phi2_loss: 0.0040 - val_phys_res_loss: 0.0138 - val_rho_loss: 0.0027
# Epoch 9: lam_phys_current=0.114286
# Epoch 10/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0522 - phase_accuracy: 0.9914 - phase_loss: 0.0252 - phi2_loss: 0.0032 - phys_res_loss: 0.0226 - rho_loss: 0.0012 - val_loss: 0.0905 - val_phase_accuracy: 0.9731 - val_phase_loss: 0.0603 - val_phi2_loss: 0.0084 - val_phys_res_loss: 0.0204 - val_rho_loss: 0.0020
# Epoch 10: lam_phys_current=0.142857
# Epoch 11/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0512 - phase_accuracy: 0.9916 - phase_loss: 0.0240 - phi2_loss: 0.0032 - phys_res_loss: 0.0227 - rho_loss: 0.0013 - val_loss: 0.0467 - val_phase_accuracy: 0.9900 - val_phase_loss: 0.0267 - val_phi2_loss: 0.0039 - val_phys_res_loss: 0.0142 - val_rho_loss: 0.0021
# Epoch 11: lam_phys_current=0.171429
# Epoch 12/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0487 - phase_accuracy: 0.9921 - phase_loss: 0.0222 - phi2_loss: 0.0030 - phys_res_loss: 0.0224 - rho_loss: 0.0010 - val_loss: 0.0522 - val_phase_accuracy: 0.9859 - val_phase_loss: 0.0345 - val_phi2_loss: 0.0032 - val_phys_res_loss: 0.0128 - val_rho_loss: 0.0018
# Epoch 12: lam_phys_current=0.200000
# Epoch 13/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0475 - phase_accuracy: 0.9923 - phase_loss: 0.0210 - phi2_loss: 0.0031 - phys_res_loss: 0.0225 - rho_loss: 9.5109e-04 - val_loss: 0.0437 - val_phase_accuracy: 0.9893 - val_phase_loss: 0.0263 - val_phi2_loss: 0.0024 - val_phys_res_loss: 0.0128 - val_rho_loss: 0.0023
# Epoch 13: lam_phys_current=0.228571
# Epoch 14/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0458 - phase_accuracy: 0.9924 - phase_loss: 0.0200 - phi2_loss: 0.0027 - phys_res_loss: 0.0223 - rho_loss: 8.0035e-04 - val_loss: 0.0451 - val_phase_accuracy: 0.9918 - val_phase_loss: 0.0240 - val_phi2_loss: 0.0038 - val_phys_res_loss: 0.0137 - val_rho_loss: 0.0037
# Epoch 14: lam_phys_current=0.257143
# Epoch 15/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0456 - phase_accuracy: 0.9926 - phase_loss: 0.0197 - phi2_loss: 0.0028 - phys_res_loss: 0.0222 - rho_loss: 8.9026e-04 - val_loss: 0.0380 - val_phase_accuracy: 0.9949 - val_phase_loss: 0.0190 - val_phi2_loss: 0.0034 - val_phys_res_loss: 0.0137 - val_rho_loss: 0.0020
# Epoch 15: lam_phys_current=0.285714
# Epoch 16/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0470 - phase_accuracy: 0.9918 - phase_loss: 0.0208 - phi2_loss: 0.0030 - phys_res_loss: 0.0223 - rho_loss: 9.2219e-04 - val_loss: 0.0385 - val_phase_accuracy: 0.9915 - val_phase_loss: 0.0217 - val_phi2_loss: 0.0025 - val_phys_res_loss: 0.0132 - val_rho_loss: 0.0012
# Epoch 16: lam_phys_current=0.314286
# Epoch 17/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0448 - phase_accuracy: 0.9924 - phase_loss: 0.0193 - phi2_loss: 0.0027 - phys_res_loss: 0.0221 - rho_loss: 7.6051e-04 - val_loss: 0.0377 - val_phase_accuracy: 0.9923 - val_phase_loss: 0.0211 - val_phi2_loss: 0.0020 - val_phys_res_loss: 0.0137 - val_rho_loss: 9.5478e-04
# Epoch 17: lam_phys_current=0.342857
# Epoch 18/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0447 - phase_accuracy: 0.9920 - phase_loss: 0.0192 - phi2_loss: 0.0026 - phys_res_loss: 0.0222 - rho_loss: 7.1890e-04 - val_loss: 0.0436 - val_phase_accuracy: 0.9865 - val_phase_loss: 0.0253 - val_phi2_loss: 0.0033 - val_phys_res_loss: 0.0142 - val_rho_loss: 9.9931e-04
# Epoch 18: lam_phys_current=0.371429
# Epoch 19/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0445 - phase_accuracy: 0.9923 - phase_loss: 0.0192 - phi2_loss: 0.0027 - phys_res_loss: 0.0220 - rho_loss: 6.2370e-04 - val_loss: 0.0498 - val_phase_accuracy: 0.9883 - val_phase_loss: 0.0323 - val_phi2_loss: 0.0031 - val_phys_res_loss: 0.0131 - val_rho_loss: 0.0013
# Epoch 19: lam_phys_current=0.400000
# Epoch 20/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - phase_accuracy: 0.9932 - phase_loss: 0.0174 - phi2_loss: 0.0024 - phys_res_loss: 0.0222 - rho_loss: 6.1540e-04 - val_loss: 0.0598 - val_phase_accuracy: 0.9814 - val_phase_loss: 0.0400 - val_phi2_loss: 0.0030 - val_phys_res_loss: 0.0163 - val_rho_loss: 9.0355e-04
# Epoch 20: lam_phys_current=0.428571
# Epoch 21/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0442 - phase_accuracy: 0.9923 - phase_loss: 0.0185 - phi2_loss: 0.0027 - phys_res_loss: 0.0223 - rho_loss: 7.3031e-04 - val_loss: 0.0340 - val_phase_accuracy: 0.9916 - val_phase_loss: 0.0174 - val_phi2_loss: 0.0028 - val_phys_res_loss: 0.0132 - val_rho_loss: 7.6343e-04
# Epoch 21: lam_phys_current=0.457143
# Epoch 22/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0428 - phase_accuracy: 0.9929 - phase_loss: 0.0177 - phi2_loss: 0.0025 - phys_res_loss: 0.0219 - rho_loss: 6.6061e-04 - val_loss: 0.0395 - val_phase_accuracy: 0.9895 - val_phase_loss: 0.0224 - val_phi2_loss: 0.0029 - val_phys_res_loss: 0.0132 - val_rho_loss: 0.0010
# Epoch 22: lam_phys_current=0.485714
# Epoch 23/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0454 - phase_accuracy: 0.9917 - phase_loss: 0.0196 - phi2_loss: 0.0028 - phys_res_loss: 0.0223 - rho_loss: 6.3537e-04 - val_loss: 0.0323 - val_phase_accuracy: 0.9948 - val_phase_loss: 0.0161 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0132 - val_rho_loss: 0.0015
# Epoch 23: lam_phys_current=0.514286
# Epoch 24/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - phase_accuracy: 0.9929 - phase_loss: 0.0178 - phi2_loss: 0.0024 - phys_res_loss: 0.0218 - rho_loss: 5.2565e-04 - val_loss: 0.0472 - val_phase_accuracy: 0.9862 - val_phase_loss: 0.0289 - val_phi2_loss: 0.0026 - val_phys_res_loss: 0.0151 - val_rho_loss: 8.8256e-04
# Epoch 24: lam_phys_current=0.542857
# Epoch 25/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0423 - phase_accuracy: 0.9928 - phase_loss: 0.0175 - phi2_loss: 0.0024 - phys_res_loss: 0.0217 - rho_loss: 5.8852e-04 - val_loss: 0.0487 - val_phase_accuracy: 0.9860 - val_phase_loss: 0.0284 - val_phi2_loss: 0.0038 - val_phys_res_loss: 0.0160 - val_rho_loss: 8.4085e-04
# Epoch 25: lam_phys_current=0.571429
# Epoch 26/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0434 - phase_accuracy: 0.9922 - phase_loss: 0.0184 - phi2_loss: 0.0026 - phys_res_loss: 0.0219 - rho_loss: 5.7130e-04 - val_loss: 0.0603 - val_phase_accuracy: 0.9810 - val_phase_loss: 0.0394 - val_phi2_loss: 0.0025 - val_phys_res_loss: 0.0175 - val_rho_loss: 0.0012
# Epoch 26: lam_phys_current=0.600000
# Epoch 27/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0434 - phase_accuracy: 0.9926 - phase_loss: 0.0181 - phi2_loss: 0.0026 - phys_res_loss: 0.0222 - rho_loss: 5.2739e-04 - val_loss: 0.1006 - val_phase_accuracy: 0.9722 - val_phase_loss: 0.0801 - val_phi2_loss: 0.0032 - val_phys_res_loss: 0.0167 - val_rho_loss: 0.0012
# Epoch 27: lam_phys_current=0.628571
# Epoch 28/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0463 - phase_accuracy: 0.9914 - phase_loss: 0.0206 - phi2_loss: 0.0030 - phys_res_loss: 0.0220 - rho_loss: 5.8382e-04 - val_loss: 0.1393 - val_phase_accuracy: 0.9676 - val_phase_loss: 0.1102 - val_phi2_loss: 0.0075 - val_phys_res_loss: 0.0209 - val_rho_loss: 0.0014
# Epoch 28: lam_phys_current=0.657143
# Epoch 29/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0429 - phase_accuracy: 0.9926 - phase_loss: 0.0180 - phi2_loss: 0.0024 - phys_res_loss: 0.0219 - rho_loss: 5.4390e-04 - val_loss: 0.0405 - val_phase_accuracy: 0.9888 - val_phase_loss: 0.0237 - val_phi2_loss: 0.0015 - val_phys_res_loss: 0.0147 - val_rho_loss: 8.8126e-04
# Epoch 29: lam_phys_current=0.685714
# Epoch 30/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0421 - phase_accuracy: 0.9928 - phase_loss: 0.0172 - phi2_loss: 0.0024 - phys_res_loss: 0.0219 - rho_loss: 5.4467e-04 - val_loss: 0.0629 - val_phase_accuracy: 0.9808 - val_phase_loss: 0.0432 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0169 - val_rho_loss: 8.2543e-04
# Epoch 30: lam_phys_current=0.714286
# Epoch 31/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - phase_accuracy: 0.9936 - phase_loss: 0.0154 - phi2_loss: 0.0021 - phys_res_loss: 0.0218 - rho_loss: 4.7035e-04 - val_loss: 0.0377 - val_phase_accuracy: 0.9885 - val_phase_loss: 0.0221 - val_phi2_loss: 0.0025 - val_phys_res_loss: 0.0125 - val_rho_loss: 7.2603e-04
# Epoch 31: lam_phys_current=0.742857
# Epoch 32/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0439 - phase_accuracy: 0.9919 - phase_loss: 0.0184 - phi2_loss: 0.0027 - phys_res_loss: 0.0222 - rho_loss: 5.8396e-04 - val_loss: 0.0429 - val_phase_accuracy: 0.9878 - val_phase_loss: 0.0259 - val_phi2_loss: 0.0033 - val_phys_res_loss: 0.0131 - val_rho_loss: 8.0807e-04
# Epoch 32: lam_phys_current=0.771429
# Epoch 33/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0393 - phase_accuracy: 0.9938 - phase_loss: 0.0153 - phi2_loss: 0.0021 - phys_res_loss: 0.0215 - rho_loss: 4.3345e-04 - val_loss: 0.1037 - val_phase_accuracy: 0.9697 - val_phase_loss: 0.0839 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0164 - val_rho_loss: 0.0017
# Epoch 33: lam_phys_current=0.800000
# Epoch 34/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0425 - phase_accuracy: 0.9926 - phase_loss: 0.0175 - phi2_loss: 0.0026 - phys_res_loss: 0.0218 - rho_loss: 6.0400e-04 - val_loss: 0.0449 - val_phase_accuracy: 0.9859 - val_phase_loss: 0.0280 - val_phi2_loss: 0.0019 - val_phys_res_loss: 0.0132 - val_rho_loss: 0.0020
# Epoch 34: lam_phys_current=0.828571
# Epoch 35/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - phase_accuracy: 0.9938 - phase_loss: 0.0152 - phi2_loss: 0.0022 - phys_res_loss: 0.0218 - rho_loss: 4.2816e-04 - val_loss: 0.0647 - val_phase_accuracy: 0.9794 - val_phase_loss: 0.0468 - val_phi2_loss: 0.0021 - val_phys_res_loss: 0.0155 - val_rho_loss: 6.6824e-04
# Epoch 35: lam_phys_current=0.857143
# Epoch 36/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0408 - phase_accuracy: 0.9934 - phase_loss: 0.0164 - phi2_loss: 0.0023 - phys_res_loss: 0.0216 - rho_loss: 4.5983e-04 - val_loss: 0.0387 - val_phase_accuracy: 0.9892 - val_phase_loss: 0.0237 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0128 - val_rho_loss: 8.4168e-04
# Epoch 36: lam_phys_current=0.885714
# Epoch 37/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - phase_accuracy: 0.9936 - phase_loss: 0.0156 - phi2_loss: 0.0023 - phys_res_loss: 0.0218 - rho_loss: 4.7888e-04 - val_loss: 0.0331 - val_phase_accuracy: 0.9915 - val_phase_loss: 0.0180 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0136 - val_rho_loss: 4.6821e-04
# Epoch 37: lam_phys_current=0.914286
# Epoch 38/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0434 - phase_accuracy: 0.9926 - phase_loss: 0.0183 - phi2_loss: 0.0026 - phys_res_loss: 0.0221 - rho_loss: 4.6121e-04 - val_loss: 0.0419 - val_phase_accuracy: 0.9871 - val_phase_loss: 0.0254 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0145 - val_rho_loss: 5.8501e-04
# Epoch 38: lam_phys_current=0.942857
# Epoch 39/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - phase_accuracy: 0.9932 - phase_loss: 0.0163 - phi2_loss: 0.0022 - phys_res_loss: 0.0217 - rho_loss: 4.1198e-04 - val_loss: 0.0545 - val_phase_accuracy: 0.9857 - val_phase_loss: 0.0383 - val_phi2_loss: 0.0028 - val_phys_res_loss: 0.0133 - val_rho_loss: 4.8633e-04
# Epoch 39: lam_phys_current=0.971429
# Epoch 40/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0429 - phase_accuracy: 0.9928 - phase_loss: 0.0178 - phi2_loss: 0.0025 - phys_res_loss: 0.0221 - rho_loss: 5.1986e-04 - val_loss: 0.0479 - val_phase_accuracy: 0.9838 - val_phase_loss: 0.0319 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0140 - val_rho_loss: 8.1834e-04
# Epoch 40: lam_phys_current=1.000000
# Epoch 41/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0396 - phase_accuracy: 0.9935 - phase_loss: 0.0156 - phi2_loss: 0.0021 - phys_res_loss: 0.0215 - rho_loss: 4.2936e-04 - val_loss: 0.0820 - val_phase_accuracy: 0.9782 - val_phase_loss: 0.0615 - val_phi2_loss: 0.0031 - val_phys_res_loss: 0.0162 - val_rho_loss: 0.0017
# Epoch 41: lam_phys_current=1.000000
# Epoch 42/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - phase_accuracy: 0.9936 - phase_loss: 0.0158 - phi2_loss: 0.0022 - phys_res_loss: 0.0215 - rho_loss: 4.1507e-04 - val_loss: 0.0298 - val_phase_accuracy: 0.9957 - val_phase_loss: 0.0133 - val_phi2_loss: 0.0014 - val_phys_res_loss: 0.0146 - val_rho_loss: 6.3929e-04
# Epoch 42: lam_phys_current=1.000000
# Epoch 43/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0386 - phase_accuracy: 0.9940 - phase_loss: 0.0149 - phi2_loss: 0.0021 - phys_res_loss: 0.0213 - rho_loss: 3.7606e-04 - val_loss: 0.0435 - val_phase_accuracy: 0.9904 - val_phase_loss: 0.0232 - val_phi2_loss: 0.0022 - val_phys_res_loss: 0.0168 - val_rho_loss: 0.0016
# Epoch 43: lam_phys_current=1.000000
# Epoch 44/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0413 - phase_accuracy: 0.9932 - phase_loss: 0.0166 - phi2_loss: 0.0024 - phys_res_loss: 0.0219 - rho_loss: 4.4443e-04 - val_loss: 0.0511 - val_phase_accuracy: 0.9835 - val_phase_loss: 0.0348 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0146 - val_rho_loss: 8.6371e-04
# Epoch 44: lam_phys_current=1.000000
# Epoch 45/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - phase_accuracy: 0.9935 - phase_loss: 0.0156 - phi2_loss: 0.0022 - phys_res_loss: 0.0217 - rho_loss: 4.0294e-04 - val_loss: 0.1264 - val_phase_accuracy: 0.9707 - val_phase_loss: 0.1039 - val_phi2_loss: 0.0048 - val_phys_res_loss: 0.0177 - val_rho_loss: 8.0381e-04
# Epoch 45: lam_phys_current=1.000000
# Epoch 46/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0418 - phase_accuracy: 0.9930 - phase_loss: 0.0170 - phi2_loss: 0.0023 - phys_res_loss: 0.0220 - rho_loss: 4.7806e-04 - val_loss: 0.0738 - val_phase_accuracy: 0.9810 - val_phase_loss: 0.0531 - val_phi2_loss: 0.0025 - val_phys_res_loss: 0.0177 - val_rho_loss: 8.6113e-04
# Epoch 46: lam_phys_current=1.000000
# Epoch 47/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0387 - phase_accuracy: 0.9938 - phase_loss: 0.0147 - phi2_loss: 0.0021 - phys_res_loss: 0.0216 - rho_loss: 3.3610e-04 - val_loss: 0.0619 - val_phase_accuracy: 0.9809 - val_phase_loss: 0.0441 - val_phi2_loss: 0.0022 - val_phys_res_loss: 0.0154 - val_rho_loss: 5.4174e-04
# Epoch 47: lam_phys_current=1.000000
# Epoch 48/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0382 - phase_accuracy: 0.9943 - phase_loss: 0.0141 - phi2_loss: 0.0022 - phys_res_loss: 0.0215 - rho_loss: 4.2967e-04 - val_loss: 0.0381 - val_phase_accuracy: 0.9890 - val_phase_loss: 0.0230 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0123 - val_rho_loss: 6.6489e-04
# Epoch 48: lam_phys_current=1.000000
# Epoch 49/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0394 - phase_accuracy: 0.9937 - phase_loss: 0.0150 - phi2_loss: 0.0022 - phys_res_loss: 0.0217 - rho_loss: 4.1320e-04 - val_loss: 0.1328 - val_phase_accuracy: 0.9672 - val_phase_loss: 0.1072 - val_phi2_loss: 0.0057 - val_phys_res_loss: 0.0200 - val_rho_loss: 6.2222e-04
# Epoch 49: lam_phys_current=1.000000
# Epoch 50/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0408 - phase_accuracy: 0.9935 - phase_loss: 0.0162 - phi2_loss: 0.0024 - phys_res_loss: 0.0219 - rho_loss: 4.4162e-04 - val_loss: 0.0552 - val_phase_accuracy: 0.9825 - val_phase_loss: 0.0402 - val_phi2_loss: 8.0362e-04 - val_phys_res_loss: 0.0139 - val_rho_loss: 3.8628e-04
# Epoch 50: lam_phys_current=1.000000
# Epoch 51/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0413 - phase_accuracy: 0.9929 - phase_loss: 0.0169 - phi2_loss: 0.0024 - phys_res_loss: 0.0216 - rho_loss: 4.4393e-04 - val_loss: 0.0420 - val_phase_accuracy: 0.9894 - val_phase_loss: 0.0248 - val_phi2_loss: 0.0014 - val_phys_res_loss: 0.0137 - val_rho_loss: 0.0022
# Epoch 51: lam_phys_current=1.000000
# Epoch 52/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0390 - phase_accuracy: 0.9937 - phase_loss: 0.0152 - phi2_loss: 0.0021 - phys_res_loss: 0.0213 - rho_loss: 3.9588e-04 - val_loss: 0.0397 - val_phase_accuracy: 0.9882 - val_phase_loss: 0.0238 - val_phi2_loss: 0.0015 - val_phys_res_loss: 0.0140 - val_rho_loss: 5.6575e-04
# Epoch 52: lam_phys_current=1.000000
# Epoch 53/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0389 - phase_accuracy: 0.9937 - phase_loss: 0.0150 - phi2_loss: 0.0021 - phys_res_loss: 0.0214 - rho_loss: 3.9482e-04 - val_loss: 0.0406 - val_phase_accuracy: 0.9864 - val_phase_loss: 0.0244 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0145 - val_rho_loss: 3.5087e-04
# Epoch 53: lam_phys_current=1.000000
# Epoch 54/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0402 - phase_accuracy: 0.9936 - phase_loss: 0.0158 - phi2_loss: 0.0023 - phys_res_loss: 0.0216 - rho_loss: 4.2777e-04 - val_loss: 0.0348 - val_phase_accuracy: 0.9911 - val_phase_loss: 0.0183 - val_phi2_loss: 0.0017 - val_phys_res_loss: 0.0146 - val_rho_loss: 3.7255e-04
# Epoch 54: lam_phys_current=1.000000
# Epoch 55/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0386 - phase_accuracy: 0.9940 - phase_loss: 0.0147 - phi2_loss: 0.0021 - phys_res_loss: 0.0214 - rho_loss: 3.8138e-04 - val_loss: 0.0671 - val_phase_accuracy: 0.9809 - val_phase_loss: 0.0466 - val_phi2_loss: 0.0035 - val_phys_res_loss: 0.0168 - val_rho_loss: 4.6368e-04
# Epoch 55: lam_phys_current=1.000000
# Epoch 56/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0387 - phase_accuracy: 0.9937 - phase_loss: 0.0150 - phi2_loss: 0.0021 - phys_res_loss: 0.0213 - rho_loss: 3.7889e-04 - val_loss: 0.0846 - val_phase_accuracy: 0.9755 - val_phase_loss: 0.0654 - val_phi2_loss: 0.0027 - val_phys_res_loss: 0.0164 - val_rho_loss: 6.2071e-04
# Epoch 56: lam_phys_current=1.000000
# Epoch 57/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0390 - phase_accuracy: 0.9938 - phase_loss: 0.0151 - phi2_loss: 0.0021 - phys_res_loss: 0.0214 - rho_loss: 3.7826e-04 - val_loss: 0.0382 - val_phase_accuracy: 0.9902 - val_phase_loss: 0.0220 - val_phi2_loss: 0.0015 - val_phys_res_loss: 0.0142 - val_rho_loss: 7.1283e-04
# Epoch 57: lam_phys_current=1.000000
# Epoch 58/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - phase_accuracy: 0.9933 - phase_loss: 0.0163 - phi2_loss: 0.0023 - phys_res_loss: 0.0216 - rho_loss: 4.8807e-04 - val_loss: 0.0937 - val_phase_accuracy: 0.9761 - val_phase_loss: 0.0727 - val_phi2_loss: 0.0040 - val_phys_res_loss: 0.0163 - val_rho_loss: 0.0012
# Epoch 58: lam_phys_current=1.000000
# Epoch 59/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0393 - phase_accuracy: 0.9935 - phase_loss: 0.0153 - phi2_loss: 0.0023 - phys_res_loss: 0.0214 - rho_loss: 3.6993e-04 - val_loss: 0.0578 - val_phase_accuracy: 0.9826 - val_phase_loss: 0.0397 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0161 - val_rho_loss: 5.5375e-04
# Epoch 59: lam_phys_current=1.000000
# Epoch 60/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0403 - phase_accuracy: 0.9931 - phase_loss: 0.0159 - phi2_loss: 0.0023 - phys_res_loss: 0.0216 - rho_loss: 4.0129e-04 - val_loss: 0.0629 - val_phase_accuracy: 0.9815 - val_phase_loss: 0.0432 - val_phi2_loss: 0.0027 - val_phys_res_loss: 0.0165 - val_rho_loss: 7.8393e-04
# Epoch 60: lam_phys_current=1.000000
# Epoch 61/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0369 - phase_accuracy: 0.9943 - phase_loss: 0.0135 - phi2_loss: 0.0019 - phys_res_loss: 0.0212 - rho_loss: 3.3793e-04 - val_loss: 0.0348 - val_phase_accuracy: 0.9925 - val_phase_loss: 0.0199 - val_phi2_loss: 6.5813e-04 - val_phys_res_loss: 0.0137 - val_rho_loss: 6.9012e-04
# Epoch 61: lam_phys_current=1.000000
# Epoch 62/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0390 - phase_accuracy: 0.9940 - phase_loss: 0.0147 - phi2_loss: 0.0023 - phys_res_loss: 0.0217 - rho_loss: 3.9941e-04 - val_loss: 0.0634 - val_phase_accuracy: 0.9815 - val_phase_loss: 0.0439 - val_phi2_loss: 0.0027 - val_phys_res_loss: 0.0164 - val_rho_loss: 8.9440e-04
# Epoch 62: lam_phys_current=1.000000
# Epoch 63/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - phase_accuracy: 0.9933 - phase_loss: 0.0158 - phi2_loss: 0.0024 - phys_res_loss: 0.0215 - rho_loss: 3.9587e-04 - val_loss: 0.0403 - val_phase_accuracy: 0.9883 - val_phase_loss: 0.0252 - val_phi2_loss: 0.0017 - val_phys_res_loss: 0.0129 - val_rho_loss: 6.7232e-04
# Epoch 63: lam_phys_current=1.000000
# Epoch 64/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0381 - phase_accuracy: 0.9939 - phase_loss: 0.0145 - phi2_loss: 0.0021 - phys_res_loss: 0.0212 - rho_loss: 3.4406e-04 - val_loss: 0.0312 - val_phase_accuracy: 0.9923 - val_phase_loss: 0.0167 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0131 - val_rho_loss: 3.5082e-04
# Epoch 64: lam_phys_current=1.000000
# Epoch 65/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - phase_accuracy: 0.9934 - phase_loss: 0.0155 - phi2_loss: 0.0023 - phys_res_loss: 0.0217 - rho_loss: 4.0956e-04 - val_loss: 0.0480 - val_phase_accuracy: 0.9858 - val_phase_loss: 0.0308 - val_phi2_loss: 0.0024 - val_phys_res_loss: 0.0144 - val_rho_loss: 6.2144e-04
# Epoch 65: lam_phys_current=1.000000
# Epoch 66/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0368 - phase_accuracy: 0.9946 - phase_loss: 0.0134 - phi2_loss: 0.0020 - phys_res_loss: 0.0212 - rho_loss: 2.9357e-04 - val_loss: 0.0358 - val_phase_accuracy: 0.9906 - val_phase_loss: 0.0214 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0129 - val_rho_loss: 3.8662e-04
# Epoch 66: lam_phys_current=1.000000
# Epoch 67/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0374 - phase_accuracy: 0.9944 - phase_loss: 0.0134 - phi2_loss: 0.0021 - phys_res_loss: 0.0215 - rho_loss: 3.4163e-04 - val_loss: 0.0534 - val_phase_accuracy: 0.9856 - val_phase_loss: 0.0366 - val_phi2_loss: 0.0022 - val_phys_res_loss: 0.0134 - val_rho_loss: 0.0014
# Epoch 67: lam_phys_current=1.000000
# Epoch 68/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0378 - phase_accuracy: 0.9939 - phase_loss: 0.0142 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 3.7605e-04 - val_loss: 0.0529 - val_phase_accuracy: 0.9880 - val_phase_loss: 0.0373 - val_phi2_loss: 0.0017 - val_phys_res_loss: 0.0135 - val_rho_loss: 5.0882e-04
# Epoch 68: lam_phys_current=1.000000
# Epoch 69/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0386 - phase_accuracy: 0.9940 - phase_loss: 0.0145 - phi2_loss: 0.0022 - phys_res_loss: 0.0215 - rho_loss: 3.6485e-04 - val_loss: 0.0542 - val_phase_accuracy: 0.9829 - val_phase_loss: 0.0366 - val_phi2_loss: 0.0019 - val_phys_res_loss: 0.0157 - val_rho_loss: 3.4612e-04
# Epoch 69: lam_phys_current=1.000000
# Epoch 70/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0369 - phase_accuracy: 0.9944 - phase_loss: 0.0132 - phi2_loss: 0.0020 - phys_res_loss: 0.0214 - rho_loss: 3.3447e-04 - val_loss: 0.0730 - val_phase_accuracy: 0.9785 - val_phase_loss: 0.0526 - val_phi2_loss: 0.0026 - val_phys_res_loss: 0.0170 - val_rho_loss: 0.0011
# Epoch 70: lam_phys_current=1.000000
# Epoch 71/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0401 - phase_accuracy: 0.9932 - phase_loss: 0.0159 - phi2_loss: 0.0023 - phys_res_loss: 0.0215 - rho_loss: 3.6146e-04 - val_loss: 0.0372 - val_phase_accuracy: 0.9902 - val_phase_loss: 0.0215 - val_phi2_loss: 8.1914e-04 - val_phys_res_loss: 0.0146 - val_rho_loss: 4.4377e-04
# Epoch 71: lam_phys_current=1.000000
# Epoch 72/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0399 - phase_accuracy: 0.9933 - phase_loss: 0.0156 - phi2_loss: 0.0024 - phys_res_loss: 0.0216 - rho_loss: 3.6076e-04 - val_loss: 0.0599 - val_phase_accuracy: 0.9856 - val_phase_loss: 0.0393 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0171 - val_rho_loss: 0.0013
# Epoch 72: lam_phys_current=1.000000
# Epoch 73/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0369 - phase_accuracy: 0.9944 - phase_loss: 0.0134 - phi2_loss: 0.0020 - phys_res_loss: 0.0212 - rho_loss: 3.0652e-04 - val_loss: 0.0548 - val_phase_accuracy: 0.9860 - val_phase_loss: 0.0371 - val_phi2_loss: 0.0017 - val_phys_res_loss: 0.0157 - val_rho_loss: 5.5121e-04
# Epoch 73: lam_phys_current=1.000000
# Epoch 74/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - phase_accuracy: 0.9935 - phase_loss: 0.0156 - phi2_loss: 0.0023 - phys_res_loss: 0.0214 - rho_loss: 3.8650e-04 - val_loss: 0.0319 - val_phase_accuracy: 0.9917 - val_phase_loss: 0.0172 - val_phi2_loss: 0.0010 - val_phys_res_loss: 0.0134 - val_rho_loss: 4.2968e-04
# Epoch 74: lam_phys_current=1.000000
# Epoch 75/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0394 - phase_accuracy: 0.9937 - phase_loss: 0.0153 - phi2_loss: 0.0023 - phys_res_loss: 0.0214 - rho_loss: 4.3041e-04 - val_loss: 0.0322 - val_phase_accuracy: 0.9903 - val_phase_loss: 0.0175 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0124 - val_rho_loss: 1.8280e-04
# Epoch 75: lam_phys_current=1.000000
# Epoch 76/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0384 - phase_accuracy: 0.9941 - phase_loss: 0.0143 - phi2_loss: 0.0023 - phys_res_loss: 0.0214 - rho_loss: 3.6984e-04 - val_loss: 0.0539 - val_phase_accuracy: 0.9851 - val_phase_loss: 0.0366 - val_phi2_loss: 0.0022 - val_phys_res_loss: 0.0147 - val_rho_loss: 7.9670e-04
# Epoch 76: lam_phys_current=1.000000
# Epoch 77/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0374 - phase_accuracy: 0.9941 - phase_loss: 0.0138 - phi2_loss: 0.0021 - phys_res_loss: 0.0212 - rho_loss: 3.1178e-04 - val_loss: 0.0285 - val_phase_accuracy: 0.9945 - val_phase_loss: 0.0141 - val_phi2_loss: 0.0015 - val_phys_res_loss: 0.0125 - val_rho_loss: 4.2941e-04
# Epoch 77: lam_phys_current=1.000000
# Epoch 78/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0373 - phase_accuracy: 0.9944 - phase_loss: 0.0133 - phi2_loss: 0.0021 - phys_res_loss: 0.0215 - rho_loss: 3.7125e-04 - val_loss: 0.0798 - val_phase_accuracy: 0.9795 - val_phase_loss: 0.0584 - val_phi2_loss: 0.0034 - val_phys_res_loss: 0.0178 - val_rho_loss: 7.3549e-04
# Epoch 78: lam_phys_current=1.000000
# Epoch 79/200
# ...
# Epoch 159/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0353 - phase_accuracy: 0.9950 - phase_loss: 0.0118 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 2.6827e-04 - val_loss: 0.0429 - val_phase_accuracy: 0.9885 - val_phase_loss: 0.0282 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0129 - val_rho_loss: 6.9011e-04
# Epoch 159: lam_phys_current=1.000000
# Epoch 160/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0364 - phase_accuracy: 0.9948 - phase_loss: 0.0127 - phi2_loss: 0.0022 - phys_res_loss: 0.0213 - rho_loss: 2.6553e-04 - val_loss: 0.0354 - val_phase_accuracy: 0.9918 - val_phase_loss: 0.0212 - val_phi2_loss: 9.2523e-04 - val_phys_res_loss: 0.0131 - val_rho_loss: 3.1513e-04
# Epoch 160: lam_phys_current=1.000000
# Epoch 161/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0353 - phase_accuracy: 0.9948 - phase_loss: 0.0120 - phi2_loss: 0.0021 - phys_res_loss: 0.0210 - rho_loss: 2.8308e-04 - val_loss: 0.0320 - val_phase_accuracy: 0.9939 - val_phase_loss: 0.0167 - val_phi2_loss: 0.0014 - val_phys_res_loss: 0.0137 - val_rho_loss: 2.9074e-04
# Epoch 161: lam_phys_current=1.000000
# Epoch 162/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0330 - phase_accuracy: 0.9958 - phase_loss: 0.0102 - phi2_loss: 0.0018 - phys_res_loss: 0.0208 - rho_loss: 2.0734e-04 - val_loss: 0.0364 - val_phase_accuracy: 0.9920 - val_phase_loss: 0.0227 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0125 - val_rho_loss: 3.2042e-04
# Epoch 162: lam_phys_current=1.000000
# Epoch 163/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352 - phase_accuracy: 0.9951 - phase_loss: 0.0116 - phi2_loss: 0.0021 - phys_res_loss: 0.0212 - rho_loss: 2.6832e-04 - val_loss: 0.0326 - val_phase_accuracy: 0.9926 - val_phase_loss: 0.0183 - val_phi2_loss: 8.2802e-04 - val_phys_res_loss: 0.0132 - val_rho_loss: 3.7096e-04
# Epoch 163: lam_phys_current=1.000000
# Epoch 164/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0353 - phase_accuracy: 0.9948 - phase_loss: 0.0121 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.6046e-04 - val_loss: 0.0384 - val_phase_accuracy: 0.9899 - val_phase_loss: 0.0211 - val_phi2_loss: 0.0023 - val_phys_res_loss: 0.0148 - val_rho_loss: 2.8287e-04
# Epoch 164: lam_phys_current=1.000000
# Epoch 165/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0345 - phase_accuracy: 0.9953 - phase_loss: 0.0111 - phi2_loss: 0.0021 - phys_res_loss: 0.0211 - rho_loss: 2.4652e-04 - val_loss: 0.0514 - val_phase_accuracy: 0.9859 - val_phase_loss: 0.0356 - val_phi2_loss: 0.0014 - val_phys_res_loss: 0.0144 - val_rho_loss: 3.5065e-04
# Epoch 165: lam_phys_current=1.000000
# Epoch 166/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0357 - phase_accuracy: 0.9949 - phase_loss: 0.0123 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 2.6344e-04 - val_loss: 0.0471 - val_phase_accuracy: 0.9883 - val_phase_loss: 0.0316 - val_phi2_loss: 0.0013 - val_phys_res_loss: 0.0138 - val_rho_loss: 4.0697e-04
# Epoch 166: lam_phys_current=1.000000
# Epoch 167/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352 - phase_accuracy: 0.9948 - phase_loss: 0.0120 - phi2_loss: 0.0021 - phys_res_loss: 0.0208 - rho_loss: 2.8275e-04 - val_loss: 0.0586 - val_phase_accuracy: 0.9832 - val_phase_loss: 0.0414 - val_phi2_loss: 0.0018 - val_phys_res_loss: 0.0153 - val_rho_loss: 3.8897e-04
# Epoch 167: lam_phys_current=1.000000
# Epoch 168/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347 - phase_accuracy: 0.9949 - phase_loss: 0.0117 - phi2_loss: 0.0020 - phys_res_loss: 0.0208 - rho_loss: 2.3781e-04 - val_loss: 0.0494 - val_phase_accuracy: 0.9875 - val_phase_loss: 0.0342 - val_phi2_loss: 0.0020 - val_phys_res_loss: 0.0122 - val_rho_loss: 9.7003e-04
# Epoch 168: lam_phys_current=1.000000
# Epoch 169/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347 - phase_accuracy: 0.9950 - phase_loss: 0.0114 - phi2_loss: 0.0021 - phys_res_loss: 0.0210 - rho_loss: 2.5546e-04 - val_loss: 0.0335 - val_phase_accuracy: 0.9925 - val_phase_loss: 0.0192 - val_phi2_loss: 0.0013 - val_phys_res_loss: 0.0125 - val_rho_loss: 7.3051e-04
# Epoch 169: lam_phys_current=1.000000
# Epoch 170/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0351 - phase_accuracy: 0.9949 - phase_loss: 0.0117 - phi2_loss: 0.0021 - phys_res_loss: 0.0210 - rho_loss: 2.5846e-04 - val_loss: 0.0301 - val_phase_accuracy: 0.9944 - val_phase_loss: 0.0164 - val_phi2_loss: 8.5778e-04 - val_phys_res_loss: 0.0127 - val_rho_loss: 2.5837e-04
# Epoch 170: lam_phys_current=1.000000
# Epoch 171/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347 - phase_accuracy: 0.9953 - phase_loss: 0.0112 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 2.7112e-04 - val_loss: 0.0383 - val_phase_accuracy: 0.9929 - val_phase_loss: 0.0241 - val_phi2_loss: 9.4603e-04 - val_phys_res_loss: 0.0128 - val_rho_loss: 4.3877e-04
# Epoch 171: lam_phys_current=1.000000
# Epoch 172/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0342 - phase_accuracy: 0.9954 - phase_loss: 0.0112 - phi2_loss: 0.0020 - phys_res_loss: 0.0208 - rho_loss: 2.2151e-04 - val_loss: 0.0731 - val_phase_accuracy: 0.9837 - val_phase_loss: 0.0562 - val_phi2_loss: 0.0019 - val_phys_res_loss: 0.0149 - val_rho_loss: 5.3226e-04
# Epoch 172: lam_phys_current=1.000000
# Epoch 173/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347 - phase_accuracy: 0.9951 - phase_loss: 0.0115 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.2342e-04 - val_loss: 0.0737 - val_phase_accuracy: 0.9826 - val_phase_loss: 0.0540 - val_phi2_loss: 0.0027 - val_phys_res_loss: 0.0166 - val_rho_loss: 7.8263e-04
# Epoch 173: lam_phys_current=1.000000
# Epoch 174/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0346 - phase_accuracy: 0.9954 - phase_loss: 0.0113 - phi2_loss: 0.0020 - phys_res_loss: 0.0211 - rho_loss: 2.2196e-04 - val_loss: 0.0469 - val_phase_accuracy: 0.9895 - val_phase_loss: 0.0312 - val_phi2_loss: 0.0019 - val_phys_res_loss: 0.0134 - val_rho_loss: 5.2463e-04
# Epoch 174: lam_phys_current=1.000000
# Epoch 175/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0358 - phase_accuracy: 0.9949 - phase_loss: 0.0120 - phi2_loss: 0.0022 - phys_res_loss: 0.0213 - rho_loss: 2.8431e-04 - val_loss: 0.0825 - val_phase_accuracy: 0.9787 - val_phase_loss: 0.0664 - val_phi2_loss: 0.0021 - val_phys_res_loss: 0.0140 - val_rho_loss: 3.3054e-04
# Epoch 175: lam_phys_current=1.000000
# Epoch 176/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0345 - phase_accuracy: 0.9952 - phase_loss: 0.0116 - phi2_loss: 0.0020 - phys_res_loss: 0.0206 - rho_loss: 2.3343e-04 - val_loss: 0.0382 - val_phase_accuracy: 0.9933 - val_phase_loss: 0.0239 - val_phi2_loss: 0.0013 - val_phys_res_loss: 0.0128 - val_rho_loss: 3.0700e-04
# Epoch 176: lam_phys_current=1.000000
# Epoch 177/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0337 - phase_accuracy: 0.9954 - phase_loss: 0.0109 - phi2_loss: 0.0019 - phys_res_loss: 0.0207 - rho_loss: 2.3983e-04 - val_loss: 0.0418 - val_phase_accuracy: 0.9900 - val_phase_loss: 0.0246 - val_phi2_loss: 0.0029 - val_phys_res_loss: 0.0142 - val_rho_loss: 3.2827e-04
# Epoch 177: lam_phys_current=1.000000
# Epoch 178/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0336 - phase_accuracy: 0.9956 - phase_loss: 0.0106 - phi2_loss: 0.0020 - phys_res_loss: 0.0208 - rho_loss: 2.3055e-04 - val_loss: 0.0447 - val_phase_accuracy: 0.9885 - val_phase_loss: 0.0288 - val_phi2_loss: 0.0026 - val_phys_res_loss: 0.0133 - val_rho_loss: 1.9023e-04
# Epoch 178: lam_phys_current=1.000000
# Epoch 179/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0362 - phase_accuracy: 0.9946 - phase_loss: 0.0126 - phi2_loss: 0.0022 - phys_res_loss: 0.0211 - rho_loss: 2.6298e-04 - val_loss: 0.0572 - val_phase_accuracy: 0.9852 - val_phase_loss: 0.0412 - val_phi2_loss: 0.0024 - val_phys_res_loss: 0.0134 - val_rho_loss: 4.9571e-04
# Epoch 179: lam_phys_current=1.000000
# Epoch 180/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0360 - phase_accuracy: 0.9948 - phase_loss: 0.0124 - phi2_loss: 0.0022 - phys_res_loss: 0.0212 - rho_loss: 2.3881e-04 - val_loss: 0.0677 - val_phase_accuracy: 0.9825 - val_phase_loss: 0.0462 - val_phi2_loss: 0.0035 - val_phys_res_loss: 0.0179 - val_rho_loss: 3.4783e-04
# Epoch 180: lam_phys_current=1.000000
# Epoch 181/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0340 - phase_accuracy: 0.9955 - phase_loss: 0.0108 - phi2_loss: 0.0021 - phys_res_loss: 0.0209 - rho_loss: 2.2191e-04 - val_loss: 0.0657 - val_phase_accuracy: 0.9860 - val_phase_loss: 0.0494 - val_phi2_loss: 0.0020 - val_phys_res_loss: 0.0136 - val_rho_loss: 6.8156e-04
# Epoch 181: lam_phys_current=1.000000
# Epoch 182/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352 - phase_accuracy: 0.9950 - phase_loss: 0.0118 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 2.5418e-04 - val_loss: 0.0376 - val_phase_accuracy: 0.9907 - val_phase_loss: 0.0235 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0127 - val_rho_loss: 3.7036e-04
# Epoch 182: lam_phys_current=1.000000
# Epoch 183/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0343 - phase_accuracy: 0.9954 - phase_loss: 0.0111 - phi2_loss: 0.0020 - phys_res_loss: 0.0210 - rho_loss: 2.4070e-04 - val_loss: 0.0450 - val_phase_accuracy: 0.9891 - val_phase_loss: 0.0298 - val_phi2_loss: 0.0026 - val_phys_res_loss: 0.0125 - val_rho_loss: 2.6693e-04
# Epoch 183: lam_phys_current=1.000000
# Epoch 184/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0340 - phase_accuracy: 0.9956 - phase_loss: 0.0106 - phi2_loss: 0.0021 - phys_res_loss: 0.0210 - rho_loss: 2.1921e-04 - val_loss: 0.0329 - val_phase_accuracy: 0.9947 - val_phase_loss: 0.0186 - val_phi2_loss: 7.8900e-04 - val_phys_res_loss: 0.0131 - val_rho_loss: 3.9819e-04
# Epoch 184: lam_phys_current=1.000000
# Epoch 185/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0343 - phase_accuracy: 0.9953 - phase_loss: 0.0112 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.6260e-04 - val_loss: 0.0366 - val_phase_accuracy: 0.9906 - val_phase_loss: 0.0210 - val_phi2_loss: 0.0018 - val_phys_res_loss: 0.0136 - val_rho_loss: 2.5844e-04
# Epoch 185: lam_phys_current=1.000000
# Epoch 186/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0334 - phase_accuracy: 0.9956 - phase_loss: 0.0104 - phi2_loss: 0.0019 - phys_res_loss: 0.0209 - rho_loss: 2.1511e-04 - val_loss: 0.0321 - val_phase_accuracy: 0.9912 - val_phase_loss: 0.0185 - val_phi2_loss: 0.0020 - val_phys_res_loss: 0.0114 - val_rho_loss: 2.9083e-04
# Epoch 186: lam_phys_current=1.000000
# Epoch 187/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0362 - phase_accuracy: 0.9949 - phase_loss: 0.0123 - phi2_loss: 0.0023 - phys_res_loss: 0.0213 - rho_loss: 2.6531e-04 - val_loss: 0.0399 - val_phase_accuracy: 0.9888 - val_phase_loss: 0.0257 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0128 - val_rho_loss: 3.5394e-04
# Epoch 187: lam_phys_current=1.000000
# Epoch 188/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0354 - phase_accuracy: 0.9950 - phase_loss: 0.0119 - phi2_loss: 0.0022 - phys_res_loss: 0.0210 - rho_loss: 2.7581e-04 - val_loss: 0.0443 - val_phase_accuracy: 0.9889 - val_phase_loss: 0.0302 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0125 - val_rho_loss: 6.1424e-04
# Epoch 188: lam_phys_current=1.000000
# Epoch 189/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0340 - phase_accuracy: 0.9954 - phase_loss: 0.0111 - phi2_loss: 0.0020 - phys_res_loss: 0.0207 - rho_loss: 2.5568e-04 - val_loss: 0.0383 - val_phase_accuracy: 0.9920 - val_phase_loss: 0.0241 - val_phi2_loss: 9.1728e-04 - val_phys_res_loss: 0.0131 - val_rho_loss: 2.0873e-04
# Epoch 189: lam_phys_current=1.000000
# Epoch 190/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0348 - phase_accuracy: 0.9951 - phase_loss: 0.0116 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.1569e-04 - val_loss: 0.0377 - val_phase_accuracy: 0.9923 - val_phase_loss: 0.0224 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0135 - val_rho_loss: 2.8568e-04
# Epoch 190: lam_phys_current=1.000000
# Epoch 191/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0351 - phase_accuracy: 0.9950 - phase_loss: 0.0118 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.3152e-04 - val_loss: 0.0434 - val_phase_accuracy: 0.9898 - val_phase_loss: 0.0295 - val_phi2_loss: 0.0013 - val_phys_res_loss: 0.0126 - val_rho_loss: 2.0494e-04
# Epoch 191: lam_phys_current=1.000000
# Epoch 192/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0343 - phase_accuracy: 0.9953 - phase_loss: 0.0112 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.2857e-04 - val_loss: 0.0440 - val_phase_accuracy: 0.9882 - val_phase_loss: 0.0299 - val_phi2_loss: 0.0010 - val_phys_res_loss: 0.0128 - val_rho_loss: 4.0976e-04
# Epoch 192: lam_phys_current=1.000000
# Epoch 193/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0352 - phase_accuracy: 0.9948 - phase_loss: 0.0119 - phi2_loss: 0.0021 - phys_res_loss: 0.0210 - rho_loss: 2.6363e-04 - val_loss: 0.0494 - val_phase_accuracy: 0.9870 - val_phase_loss: 0.0335 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0139 - val_rho_loss: 5.2627e-04
# Epoch 193: lam_phys_current=1.000000
# Epoch 194/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0336 - phase_accuracy: 0.9953 - phase_loss: 0.0107 - phi2_loss: 0.0019 - phys_res_loss: 0.0207 - rho_loss: 2.4220e-04 - val_loss: 0.0685 - val_phase_accuracy: 0.9838 - val_phase_loss: 0.0512 - val_phi2_loss: 0.0022 - val_phys_res_loss: 0.0147 - val_rho_loss: 6.4068e-04
# Epoch 194: lam_phys_current=1.000000
# Epoch 195/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0342 - phase_accuracy: 0.9952 - phase_loss: 0.0109 - phi2_loss: 0.0020 - phys_res_loss: 0.0210 - rho_loss: 2.3708e-04 - val_loss: 0.0587 - val_phase_accuracy: 0.9842 - val_phase_loss: 0.0448 - val_phi2_loss: 0.0011 - val_phys_res_loss: 0.0128 - val_rho_loss: 2.7946e-04
# Epoch 195: lam_phys_current=1.000000
# Epoch 196/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0336 - phase_accuracy: 0.9957 - phase_loss: 0.0105 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.2554e-04 - val_loss: 0.0291 - val_phase_accuracy: 0.9956 - val_phase_loss: 0.0158 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0116 - val_rho_loss: 2.0144e-04
# Epoch 196: lam_phys_current=1.000000
# Epoch 197/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0340 - phase_accuracy: 0.9954 - phase_loss: 0.0109 - phi2_loss: 0.0020 - phys_res_loss: 0.0209 - rho_loss: 2.2106e-04 - val_loss: 0.0314 - val_phase_accuracy: 0.9925 - val_phase_loss: 0.0167 - val_phi2_loss: 0.0015 - val_phys_res_loss: 0.0130 - val_rho_loss: 3.6631e-04
# Epoch 197: lam_phys_current=1.000000
# Epoch 198/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0343 - phase_accuracy: 0.9953 - phase_loss: 0.0111 - phi2_loss: 0.0020 - phys_res_loss: 0.0210 - rho_loss: 2.4576e-04 - val_loss: 0.0809 - val_phase_accuracy: 0.9789 - val_phase_loss: 0.0651 - val_phi2_loss: 0.0016 - val_phys_res_loss: 0.0141 - val_rho_loss: 5.9831e-04
# Epoch 198: lam_phys_current=1.000000
# Epoch 199/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0338 - phase_accuracy: 0.9955 - phase_loss: 0.0108 - phi2_loss: 0.0019 - phys_res_loss: 0.0209 - rho_loss: 2.4538e-04 - val_loss: 0.0360 - val_phase_accuracy: 0.9905 - val_phase_loss: 0.0224 - val_phi2_loss: 0.0012 - val_phys_res_loss: 0.0124 - val_rho_loss: 1.9073e-04
# Epoch 199: lam_phys_current=1.000000
# Epoch 200/200
# 543/543 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0347 - phase_accuracy: 0.9952 - phase_loss: 0.0114 - phi2_loss: 0.0020 - phys_res_loss: 0.0211 - rho_loss: 2.2663e-04 - val_loss: 0.0474 - val_phase_accuracy: 0.9888 - val_phase_loss: 0.0303 - val_phi2_loss: 0.0020 - val_phys_res_loss: 0.0149 - val_rho_loss: 3.1674e-04
# 📊 Classification Report (Phase, PINN + Bayesian, Grid):
#               precision    recall  f1-score   support
#
#            0     0.9990    0.9894    0.9942     23172
#            1     0.9856    0.9987    0.9921     16828
#
#     accuracy                         0.9933     40000
#    macro avg     0.9923    0.9941    0.9932     40000
# weighted avg     0.9934    0.9933    0.9933     40000

# %%
import pandas as pd
import numpy as np

def extract_boundaries_and_compare(df, U_vals, mu_vals, phase_map, U_targets=[10, 15, 20, 25]):
    """
    Extract actual and predicted boundaries from dataset & phase_map, then compare.
    
    Parameters
    ----------
    df : pd.DataFrame
        Original dataset with 'Ubar', 'Mubar', 'Phase' columns.
    U_vals : np.ndarray
        Grid values of U used for prediction.
    mu_vals : np.ndarray
        Grid values of μ used for prediction.
    phase_map : np.ndarray
        Predicted phase map on grid (shape: len(mu_vals) x len(U_vals)).
    U_targets : list
        Specific U values for which to extract boundaries.
    
    Returns
    -------
    actual_boundary_df : pd.DataFrame
    predicted_boundary_df : pd.DataFrame
    comparison_df : pd.DataFrame
    """
    
    # ---------- 1) Actual boundaries ----------
    boundary_points_true = []
    for U, group in df.groupby("Ubar"):
        group_sorted = group.sort_values("Mubar")
        phase_vals = group_sorted["Phase"].values
        mu_vals_sorted = group_sorted["Mubar"].values
        transitions = np.where(np.diff(phase_vals) != 0)[0]
        for t in transitions:
            mu_b = (mu_vals_sorted[t] + mu_vals_sorted[t+1]) / 2
            boundary_points_true.append((U, mu_b))
    
    actual_boundary_df = pd.DataFrame(boundary_points_true, columns=["Ubar", "Mubar"])
    actual_phase_list = []
    pred_phase_list = []
    
    for _, row in actual_boundary_df.iterrows():
        U, mu = row["Ubar"], row["Mubar"]
        # Nearest actual phase
        nearest = df.iloc[((df["Ubar"] - U)**2 + (df["Mubar"] - mu)**2).argmin()]
        actual_phase_list.append(nearest["Phase"])
        # Predicted phase from phase_map
        i = np.abs(U_vals - U).argmin()
        j = np.abs(mu_vals - mu).argmin()
        pred_phase_list.append(phase_map[j, i])
    
    actual_boundary_df["Actual_Phase"] = actual_phase_list
    actual_boundary_df["Predicted_Phase"] = pred_phase_list
    actual_boundary_df["Type"] = "Actual"
    
    # ---------- 2) Predicted boundaries ----------
    boundary_pred_points = []
    for i, U in enumerate(U_vals):
        phase_col = phase_map[:, i]
        transitions = np.where(np.diff(phase_col) != 0)[0]
        for t in transitions:
            mu_b = (mu_vals[t] + mu_vals[t+1]) / 2
            boundary_pred_points.append((U, mu_b))
    
    predicted_boundary_df = pd.DataFrame(boundary_pred_points, columns=["Ubar", "Mubar"])
    actual_phase_list_pred = []
    pred_phase_list_pred = []
    
    for _, row in predicted_boundary_df.iterrows():
        U, mu = row["Ubar"], row["Mubar"]
        # Nearest actual phase
        nearest = df.iloc[((df["Ubar"] - U)**2 + (df["Mubar"] - mu)**2).argmin()]
        actual_phase_list_pred.append(nearest["Phase"])
        # Predicted phase from phase_map
        i = np.abs(U_vals - U).argmin()
        j = np.abs(mu_vals - mu).argmin()
        pred_phase_list_pred.append(phase_map[j, i])
    
    predicted_boundary_df["Actual_Phase"] = actual_phase_list_pred
    predicted_boundary_df["Predicted_Phase"] = pred_phase_list_pred
    predicted_boundary_df["Type"] = "Predicted"
    
    # ---------- 3) Filter and align selected U boundaries ----------
    actual_boundary_selected = actual_boundary_df[actual_boundary_df["Ubar"].isin(U_targets)].sort_values(["Ubar", "Mubar"])
    predicted_boundary_selected = predicted_boundary_df[predicted_boundary_df["Ubar"].isin(U_targets)].sort_values(["Ubar", "Mubar"])
    
    # Remove negative μ
    actual_boundary_pos = actual_boundary_selected[actual_boundary_selected["Mubar"] >= 0].copy()
    predicted_boundary_pos = predicted_boundary_selected[predicted_boundary_selected["Mubar"] >= 0].copy()
    
    # Align boundaries and compute delta
    comparison_rows = []
    for U in U_targets:
        mu_actual = np.sort(actual_boundary_pos[actual_boundary_pos["Ubar"]==U]["Mubar"].values)
        mu_pred = np.sort(predicted_boundary_pos[predicted_boundary_pos["Ubar"]==U]["Mubar"].values)
        n_points = min(len(mu_actual), len(mu_pred))
        for i in range(n_points):
            mu_a, mu_p = mu_actual[i], mu_pred[i]
            actual_phase = actual_boundary_pos[(actual_boundary_pos["Ubar"]==U) & (actual_boundary_pos["Mubar"]==mu_a)]["Actual_Phase"].values[0]
            predicted_phase = predicted_boundary_pos[(predicted_boundary_pos["Ubar"]==U) & (predicted_boundary_pos["Mubar"]==mu_p)]["Predicted_Phase"].values[0]
            comparison_rows.append([U, mu_a, mu_p, actual_phase, predicted_phase, mu_a - mu_p])
    
    comparison_df = pd.DataFrame(comparison_rows, columns=["Ubar", "Actual_Mu", "Predicted_Mu", "Actual_Phase", "Predicted_Phase", "Delta_Mu"])
    comparison_df = comparison_df.sort_values(["Ubar", "Actual_Mu"])
    
    return actual_boundary_df, predicted_boundary_df, comparison_df

# %%
actual_df, predicted_df, comparison_df = extract_boundaries_and_compare(
    df=df,
    U_vals=U_vals,
    mu_vals=mu_vals,
    phase_map=phase_pred_class,  # <- use this
    U_targets=[10, 15, 20, 25]
)

# %%
actual_df.to_csv("actual_boundary_points-pinn-by.csv", index=False)
predicted_df.to_csv("predicted_boundary_points-pinn-by.csv", index=False)
comparison_df.to_csv("boundary_mu_comparison_aligned-pinn-by.csv", index=False)

# %%
actual_df, predicted_df, comparison_df = extract_boundaries_and_compare(
    df=df,
    U_vals=U_vals,
    mu_vals=mu_vals,
    phase_map=phase_pred_class,  # <- use this
    U_targets=[5.9]
)

print("actual",actual_df)
print("predicted",predicted_df)
print(comparison_df)
# Out:
# actual       Ubar  Mubar  Actual_Phase  Predicted_Phase    Type
# 0      0.0  -1.05           0.0                1  Actual
# 1      0.0   5.05           1.0                0  Actual
# 2      0.1  -1.05           0.0                1  Actual
# 3      0.1   5.45           1.0                1  Actual
# 4      0.2  -1.05           0.0                1  Actual
# ...    ...    ...           ...              ...     ...
# 1258  25.0   1.05           0.0                1  Actual
# 1259  25.0  22.95           0.0                1  Actual
# 1260  25.0  27.35           1.0                0  Actual
# 1261  25.0  46.65           1.0                1  Actual
# 1262  25.0  53.65           0.0                1  Actual
#
# [1263 rows x 5 columns]
# predicted           Ubar      Mubar  Actual_Phase  Predicted_Phase       Type
# 0     0.000000   4.974874           1.0                1  Predicted
# 1     0.125628   5.577889           0.0                1  Predicted
# 2     0.251256   6.180905           1.0                1  Predicted
# 3     0.376884   6.482412           1.0                1  Predicted
# 4     0.502513   7.085427           0.0                1  Predicted
# ..         ...        ...           ...              ...        ...
# 797  25.000000   1.055276           0.0                1  Predicted
# 798  25.000000  22.462312           0.0                1  Predicted
# 799  25.000000  27.286432           1.0                0  Predicted
# 800  25.000000  46.281407           0.0                0  Predicted
# 801  25.000000  54.120603           0.0                0  Predicted
#
# [802 rows x 5 columns]
# Empty DataFrame
# Columns: [Ubar, Actual_Mu, Predicted_Mu, Actual_Phase, Predicted_Phase, Delta_Mu]
# Index: []
